# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from Akvo import Flow
from selenium import webdriver
from time import sleep
import os.path
import pandas as pd
import urllib.parse
import requests as r
import json

# %%
instanceURL = "https://anu.akvolumen.org/api"
workdir = "../charts-generator/"
jsondir = "new-json/"
cachedir = "lumen-cache/"
server = "http://localhost:4000/"

# %%
dboard = Flow.getData(instanceURL + '/library', Flow.getToken())
visual = dboard.get('visualisations')
df = pd.DataFrame(visual)
sl = pd.read_csv('list-of-images-with-lumen-2019-11-30.csv')
cm = sl[sl['source'] == 'Custom']
sl = sl[sl['source'] != 'Custom']

# %%
df['specstr'] = df['spec'].astype('str')

# %%
def parseString(x):
    x = x.replace("'",'"').replace('None','null').replace('False','false').replace('True','true')
    x = urllib.parse.unquote(x)
    x = urllib.parse.quote(x)
    return x

# %%
df['specurls'] = df['specstr'].apply(parseString)
df['endpoints'] = '/aggregation/' + df['datasetId'] + '/' + df['visualisationType'] + '?query=' + df['specurls']

# %%
df = df.merge(sl, left_on='id', right_on='source')

# %%
df
# Out:
#                                                author        created  \
# 0   {'typ': 'Bearer', 'iat': '2019-05-09T11:53:15Z...  1557402994136
# 1   {'typ': 'Bearer', 'iat': '2019-03-26T01:09:18Z...  1553562669253
# 2   {'typ': 'Bearer', 'iat': '2019-03-26T01:53:26Z...  1553565206829
# 3   {'typ': 'Bearer', 'iat': '2019-03-28T02:53:19Z...  1553741642015
# 4   {'typ': 'Bearer', 'iat': '2019-05-13T04:56:38Z...  1557723404598
# 5   {'typ': 'Bearer', 'iat': '2019-05-13T09:09:51Z...  1557738592153
# 6   {'typ': 'Bearer', 'iat': '2019-03-26T05:42:44Z...  1553578980294
# 7   {'typ': 'Bearer', 'iat': '2019-03-28T01:07:01Z...  1553735334532
# 8   {'typ': 'Bearer', 'iat': '2019-03-28T08:02:24Z...  1553760316256
# 9   {'typ': 'Bearer', 'iat': '2019-05-14T09:49:59Z...  1557827507331
# 10  {'typ': 'Bearer', 'iat': '2019-04-10T09:16:46Z...  1554888044732
# 11  {'typ': 'Bearer', 'iat': '2019-03-26T00:50:25Z...  1553561431873
# 12  {'typ': 'Bearer', 'iat': '2019-04-02T03:18:07Z...  1554175120687
# 13  {'typ': 'Bearer', 'iat': '2019-05-13T09:56:18Z...  1557741538121
# 14  {'typ': 'Bearer', 'iat': '2019-03-28T07:55:25Z...  1553759733737
# 15  {'typ': 'Bearer', 'iat': '2019-03-28T08:06:32Z...  1553760394974
# 16  {'typ': 'Bearer', 'iat': '2019-05-06T04:26:04Z...  1557116765073
# 17  {'typ': 'Bearer', 'iat': '2019-05-07T01:01:58Z...  1557191080761
# 18  {'typ': 'Bearer', 'iat': '2019-05-07T01:33:37Z...  1557193061148
# 19  {'typ': 'Bearer', 'iat': '2019-04-10T06:31:06Z...  1554877900480
# 20  {'typ': 'Bearer', 'iat': '2019-05-06T06:42:39Z...  1557124970921
# 21  {'typ': 'Bearer', 'iat': '2019-05-14T09:45:03Z...  1557827380358
# 22  {'typ': 'Bearer', 'iat': '2019-05-06T04:35:57Z...  1557117536858
# 23  {'typ': 'Bearer', 'iat': '2019-05-07T01:38:38Z...  1557193238426
# 17       Do you think there should be more women MPs?
# 18  2.1.25 Heard of candidates/agents handing over...
# 19                     Candidate promises to families
# 20  (5.1.27) Do you think you need your voter regi...
# 21  5.2.22 Most important factors that influenced ...
# 22  Did you attempt to change your registration to...
# 23        Heard of candidates/agents handing out cash
# 24  (5.1.27) Do you think you need your voter regi...
# 25  Did you change your voter registration before ...
# 26  (4.1.3) Were the ballot boxes transported dire...
# 27       Do you think there should be more women MPs?
# 28  How would you describe the law and order situa...
# 29  Did you see any election related tension or vi...
# ..                                                ...
# 34        (3.1.1) Did the polling commence at 7.00am?
# 35  (4.1.12) In your opinion, were the POs unbiase...
# 36  (5.2.23)What is the most important quality you...
# 37  (5.2.21) Who had the most influence over how y...
# 38  Heard about candidates moving around on Devil'...
# 39     Seen candidates moving around on Devil's Night
# 40  2.1.47 Heard about candidates moving around on...
# 41  (5.2.21) Who had the most influence over how y...
# 42  (3.1.18) Did the polling assistants have diffi...
# 43          (3.1.47) Did you see any underage voting?
# 44        (3.1.1) Did the polling commence at 7.00am?
# 45  (3.1.19) Did you see any WOMEN turned away bec...
# 46  (3.1.21) Did you see any MEN turned away becau...
# 47  (4.2.17) Was the count conducted in an open an...
# 48  (3.1.5) Were the compartments positioned to sc...
# 49  (4.1.39) Was there any minor post-election vio...
# 50                (4.2.3) Accounting of ballots by RO
# 51  (5.1.13) Do you know anyone who registered in ...
# 52  (5.1.13) Do you know anyone who registered in ...
# 53  (5.1.14) Did anyone ask you to register in a d...
# 54              5.1.34 Candidate promises to families
# 55  (4.2.6) When determining the validity of votes...
# 56  (4.2.21) Candidates/Counting agents influence ...
# 57  2.1.3 Did you see any election related tension...
# 58  5.1.7 Did you check your name at the voter reg...
# 59  (5.2.23)What is the most important quality you...
# 60    5.1.19 Have you seen ANY SIEC media / awareness
# 61  5.2.36 In which election was intimidation grea...
# 62  5.1.30 Do you think there should be more women...
# 63  5.1.28 Would you vote for a woman candidate? (...
#
#                                                  spec visualisationType  \
# 0   {'sort': None, 'filters': [], 'version': 1, 's...               pie
# 1   {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 2   {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 3   {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 4   {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 5   {'filters': [{'value': None, 'column': 'c11000...               bar
# 6   {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 7   {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 8   {'sort': None, 'colors': {'No': '#bf360c', 'Ye...               pie
# 9   {'filters': [{'value': None, 'column': 'd23', ...               bar
# 10  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 11  {'metricLabelFromUser': False, 'filters': [], ...               bar
# 12  {'sort': None, 'colors': {'No': '#bf360c', 'Ye...               pie
# 13  {'sort': None, 'filters': [], 'version': 1, 's...               pie
# 14  {'sort': None, 'colors': {'Yes': '#388e3c'}, '...               pie
# 15  {'sort': None, 'colors': {'No': '#bf360c', 'Ye...               pie
# 16  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 17  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...               pie
# 18  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...               pie
# 19  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 20  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 21  {'filters': [{'value': None, 'column': 'd22', ...               bar
# 22  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 23  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 24  {'sort': None, 'colors': {'No': '#d32f2f', 'Ye...               pie
# 25  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 26  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...               pie
# 27  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 28  {'sort': None, 'colors': {'few or no problems'...               pie
# 29  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# ..                                                ...               ...
# 34  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...               pie
# 35  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 36  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 37  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 38  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 39  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 40  {'sort': None, 'colors': {'No': '#d32f2f', 'Ye...               pie
# 41  {'sort': None, 'colors': {'Me': '#388e3c', 'My...               pie
# 42  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 43  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 44  {'filters': [{'value': None, 'column': 'c10040...               bar
# 45  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...               pie
# 46  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...               pie
# 47  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...               pie
# 48  {'filters': [{'value': None, 'column': 'c20400...               bar
# 49  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...               pie
# 50  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 51  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 52  {'sort': None, 'filters': [], 'version': 1, 's...               pie
# 53  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 54  {'sort': None, 'colors': {'Yes': '#388e3c'}, '...               pie
# 55  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 56  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...               pie
# 57  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...               pie
# 58  {'sort': None, 'filters': [], 'version': 1, 's...               pie
# 59  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 60  {'sort': None, 'colors': {'Yes': '#388e3c'}, '...               pie
# 61  {'sort': None, 'colors': {'2010': '#d32f2f', '...               pie
# 62  {'filters': [], 'sort': None, 'subBucketColumn...               bar
# 63  {'filters': [], 'sort': None, 'subBucketColumn...               bar
#
#                                               specstr  \
# 0   {'sort': None, 'filters': [], 'version': 1, 's...
# 1   {'filters': [], 'sort': None, 'subBucketColumn...
# 2   {'filters': [], 'sort': None, 'subBucketColumn...
# 3   {'filters': [], 'sort': None, 'subBucketColumn...
# 4   {'filters': [], 'sort': None, 'subBucketColumn...
# 5   {'filters': [{'value': None, 'column': 'c11000...
# 6   {'filters': [], 'sort': None, 'subBucketColumn...
# 7   {'filters': [], 'sort': None, 'subBucketColumn...
# 8   {'sort': None, 'colors': {'No': '#bf360c', 'Ye...
# 9   {'filters': [{'value': None, 'column': 'd23', ...
# 10  {'filters': [], 'sort': None, 'subBucketColumn...
# 11  {'metricLabelFromUser': False, 'filters': [], ...
# 12  {'sort': None, 'colors': {'No': '#bf360c', 'Ye...
# 13  {'sort': None, 'filters': [], 'version': 1, 's...
# 14  {'sort': None, 'colors': {'Yes': '#388e3c'}, '...
# 15  {'sort': None, 'colors': {'No': '#bf360c', 'Ye...
# 16  {'filters': [], 'sort': None, 'subBucketColumn...
# 17  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...
# 18  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...
# 19  {'filters': [], 'sort': None, 'subBucketColumn...
# 20  {'filters': [], 'sort': None, 'subBucketColumn...
# 21  {'filters': [{'value': None, 'column': 'd22', ...
# 22  {'filters': [], 'sort': None, 'subBucketColumn...
# 23  {'filters': [], 'sort': None, 'subBucketColumn...
# 24  {'sort': None, 'colors': {'No': '#d32f2f', 'Ye...
# 25  {'filters': [], 'sort': None, 'subBucketColumn...
# 26  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...
# 27  {'filters': [], 'sort': None, 'subBucketColumn...
# 28  {'sort': None, 'colors': {'few or no problems'...
# 29  {'filters': [], 'sort': None, 'subBucketColumn...
# ..                                                ...
# 34  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...
# 35  {'filters': [], 'sort': None, 'subBucketColumn...
# 36  {'filters': [], 'sort': None, 'subBucketColumn...
# 37  {'filters': [], 'sort': None, 'subBucketColumn...
# 38  {'filters': [], 'sort': None, 'subBucketColumn...
# 39  {'filters': [], 'sort': None, 'subBucketColumn...
# 40  {'sort': None, 'colors': {'No': '#d32f2f', 'Ye...
# 41  {'sort': None, 'colors': {'Me': '#388e3c', 'My...
# 42  {'filters': [], 'sort': None, 'subBucketColumn...
# 43  {'filters': [], 'sort': None, 'subBucketColumn...
# 44  {'filters': [{'value': None, 'column': 'c10040...
# 45  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...
# 46  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...
# 47  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...
# 48  {'filters': [{'value': None, 'column': 'c20400...
# 49  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...
# 50  {'filters': [], 'sort': None, 'subBucketColumn...
# 51  {'filters': [], 'sort': None, 'subBucketColumn...
# 52  {'sort': None, 'filters': [], 'version': 1, 's...
# 53  {'filters': [], 'sort': None, 'subBucketColumn...
# 54  {'sort': None, 'colors': {'Yes': '#388e3c'}, '...
# 55  {'filters': [], 'sort': None, 'subBucketColumn...
# 56  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...
# 57  {'sort': None, 'colors': {'Yes': '#388e3c', 'N...
# 58  {'sort': None, 'filters': [], 'version': 1, 's...
# 59  {'filters': [], 'sort': None, 'subBucketColumn...
# 60  {'sort': None, 'colors': {'Yes': '#388e3c'}, '...
# 61  {'sort': None, 'colors': {'2010': '#d32f2f', '...
# 62  {'filters': [], 'sort': None, 'subBucketColumn...
# 63  {'filters': [], 'sort': None, 'subBucketColumn...
#
#                                              specurls  \
# 0   %7B%22sort%22%3A%20null%2C%20%22filters%22%3A%...
# 1   %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 2   %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 3   %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 4   %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 5   %7B%22filters%22%3A%20%5B%7B%22value%22%3A%20n...
# 6   %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 7   %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 8   %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 9   %7B%22filters%22%3A%20%5B%7B%22value%22%3A%20n...
# 10  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 11  %7B%22metricLabelFromUser%22%3A%20false%2C%20%...
# 12  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 13  %7B%22sort%22%3A%20null%2C%20%22filters%22%3A%...
# 14  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 15  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 16  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 17  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 18  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 19  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 20  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 21  %7B%22filters%22%3A%20%5B%7B%22value%22%3A%20n...
# 22  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 23  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 24  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 25  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 26  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 27  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 28  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 29  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# ..                                                ...
# 34  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 35  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 36  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 37  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 38  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 39  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 40  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 41  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 42  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 43  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 44  %7B%22filters%22%3A%20%5B%7B%22value%22%3A%20n...
# 45  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 46  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 47  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 48  %7B%22filters%22%3A%20%5B%7B%22value%22%3A%20n...
# 49  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 50  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 51  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 52  %7B%22sort%22%3A%20null%2C%20%22filters%22%3A%...
# 53  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 54  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 55  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 56  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 57  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 58  %7B%22sort%22%3A%20null%2C%20%22filters%22%3A%...
# 59  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 60  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 61  %7B%22sort%22%3A%20null%2C%20%22colors%22%3A%2...
# 62  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
# 63  %7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3...
#
#                                             endpoints    Fid  \
# 0   /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    3.3
# 1   /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    4.4
# 2   /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.27
# 3   /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...   3.10
# 4   /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...   4.20
# 5   /aggregation/5cad67a5-f1ef-4f44-9a19-ae52f4fcc...    5.4
# 6   /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.12
# 7   /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...    5.3
# 8   /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    4.3
# 9   /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...   4.9B
# 10  /aggregation/5cad67fa-d87b-49ed-9b82-662fb643d...   5.12
# 11  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.16
# 12  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...    3.9
# 13  /aggregation/5cad67d8-d6dc-4362-b827-281455ec6...    5.6
# 14  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.15
# 15  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.26
# 16  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    3.2
# 17  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.23
# 18  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...   3.31
# 19  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.30
# 20  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    4.6
# 21  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...   4.9A
# 22  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    3.5
# 23  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...   3.32
# 24  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    4.5
# 25  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...    3.6
# 26  /aggregation/5cad67a5-f1ef-4f44-9a19-ae52f4fcc...    5.1
# 27  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.24
# 28  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...   3.19
# 29  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...   3.20
# ..                                                ...    ...
# 34  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...   4.13
# 35  /aggregation/5cad67a5-f1ef-4f44-9a19-ae52f4fcc...    5.2
# 36  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...   4.11
# 37  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...   4.7B
# 38  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...  3.33B
# 39  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...   3.34
# 40  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...   3.33
# 41  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...    4.7
# 42  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...   4.16
# 43  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...   4.19
# 44  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...   4.14
# 45  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...   4.17
# 46  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...   4.18
# 47  /aggregation/5cad67d8-d6dc-4362-b827-281455ec6...   5.10
# 48  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...   4.15
# 49  /aggregation/5cad67a5-f1ef-4f44-9a19-ae52f4fcc...    5.5
# 50  /aggregation/5cad67d8-d6dc-4362-b827-281455ec6...    5.7
# 51  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    3.8
# 52  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    3.7
# 53  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    3.4
# 54  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.29
# 55  /aggregation/5cad67d8-d6dc-4362-b827-281455ec6...    5.8
# 56  /aggregation/5cad67d8-d6dc-4362-b827-281455ec6...   5.11
# 57  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...   3.21
# 58  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...    3.1
# 59  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...   4.12
# 60  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.11
# 61  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...   3.22
# 62  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.25
# 63  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...   3.28
#
#                                                 Fname  \
# 0   Citizens asked to register in another constitu...
# 1   Winning candidate will find out who citizens v...
# 2   Would vote for a woman candidate. + By constit...
# 3    Accuracy of the electoral roll + By constituency
# 4   Overall assessment of voter conduct at polling...
# 5   Priority at polling station for people with di...
# 6   Citizens that have seen any SIEC media or awar...
# 7   Polling station accommodates needs of those wi...
# 8   Winning candidate will find out who citizens v...
# 9   Most important factors that influenced voting ...
# 10  Formal court challenge by candidate + by const...
# 11  Shared or received information about the elect...
# 12  Accuracy of the electoral roll + All constitue...
# 13  Was the count completed in one day + all const...
# 14  Shared or received information about the elect...
# 15  Would vote for a woman candidate. + All consti...
# 16  Voters checked name at Voter Registration Cent...
# 17     Should be more women MPs. + All constituencies
# 18  Heard reports of candidates or candidate agent...
# 19  Candidates promised support to respondent or f...
# 20  Voter ID card is required to vote + All consti...
# 21  Most important factors that influenced voting ...
# 22  Citizens who attempted to change their registr...
# 23  Heard reports of candidates or candidate agent...
# 24            Voter ID card is required to vote + All
# 25  Citizens changed registration to another const...
# 26  Transportation of ballot boxes to counting cen...
# 27        Should be more women MPs. + By constituency
# 28  Law and order situation during the campaign pe...
# 29  Election related tension or violence observed ...
# ..                                                ...
# 34  Polling station opened on time + All constitue...
# 35  Was the PO unbiased and impartial + by constit...
# 36  Most important qualities voters want in candid...
# 37  Most influence in deciding on how to vote + By...
# 38  Hear about candidates soliciting votes on the ...
# 39  Hear about candidates soliciting votes on the ...
# 40  Hear about candidates soliciting votes on the ...
# 41  Most influence in deciding on how to vote + Al...
# 42  Polling assistants had difficulty locating nam...
# 43              Observed instances of underage voting
# 44   Polling station opened on time + By constituency
# 45  Women turned away because names could not be f...
# 46  Men turned away because names could not be fou...
# 47         Transparency of count + all constituencies
# 48  Compartments positioned to screen voters from ...
# 49  Incidents of minor post-election violence + al...
# 50    Accounting of ballots by RO + by constituencies
# 51  Citizens know of voters registered in their co...
# 52  Citizens know of voters registered in their co...
# 53  Citizens asked to register in another constitu...
# 54  Candidates promised support to respondent or f...
# 55  Detsrmining validity of votes + by constituencies
# 56  Candidates-Counting agents influencing the cou...
# 57  Election-related tension or violence heard abo...
# 58  Voters checked name at Voter Registration Cent...
# 59  Most important qualities voters want in candid...
# 60  Citizens that have seen any SIEC media or awar...
# 61  Election where intimidation was greatest? + Al...
# 62  Do you think there should be more women MPs? +...
# 63  Would vote for a woman candidate. + All consti...
#
#                                   source
# 0   5cd41572-242c-4a06-8f4f-c283376d8689
# 1   5c997c2d-d4fa-4492-9b6c-348d590c3472
# 2   5c998616-f56f-40b5-b806-2eb3a3e12801
# 3   5c9c374a-8d58-4838-9ca5-c8f404015f12
# 4   5cd8f90c-68e5-42e8-a88a-c34621108176
# 5   5cd93460-eb50-4717-b912-920ba60df024
# 6   5c99bbe4-d49a-47ef-a143-4e40994adc40
# 7   5c9c1ea6-11c9-4644-a29d-6257debcf075
# 8   5c9c803c-099b-4013-8d6c-1149551dffd0
# 9   5cda8fb3-831c-45ed-bc2b-b698ae40df92
# 10  5cadb56c-3ae1-4bcd-9fd6-fae8fe35cbf8
# 11  5c997757-a7c9-4b9b-aab1-f3a6cc9463fc
# 12  5ca2d490-9fdc-4b93-a836-d4d08ad57f77
# 13  5cd93fe2-a9c2-4543-9182-a78a81c3d949
# 14  5c9c7df5-6b93-4379-b440-7e8ed8af97fb
# 15  5c9c808a-15d5-41e0-b57b-bc8a86ed22c8
# 16  5ccfb75d-da71-43a8-b022-cb302e96d72b
# 17  5cd0d9a8-cbed-490a-986e-6cdd3debff4b
# 18  5cd0e165-946a-4e26-ab8e-9ab66f7f1e42
# 19  5cad8dcc-93ee-49ab-ac2c-5a98ddcc7ac0
# 20  5ccfd76a-2f5e-4ee5-afd9-190a9e6e8173
# 21  5cda8f34-156b-4537-93be-0a2869876915
# 22  5ccfba60-85ab-4308-9ff7-f518ab25ff63
# 23  5cd0e216-68ee-4dfc-a91d-751377d9410e
# 24  5ccfd7b4-29bd-472c-9920-3adc88d9e61c
# 25  5ccfbb2d-b044-47bc-b980-709d07d72cb6
# 26  5cd92486-5146-440a-88ff-b0d98665243f
# 27  5cad9570-ac92-468c-bc60-3bfccc0eb7a7
# 28  5ccfbc29-6c1f-41b8-822b-5ea661d84db8
# 29  5ccfc09c-f946-4cb2-b611-d3aee2d17d92
# ..                                   ...
# 34  5cd4066f-8093-4e8e-a91a-a102b8f5e902
# 35  5cd92f8e-a652-4268-9615-69eb02f191e8
# 36  5cda86a3-5d01-4549-a20e-b6598f213fa8
# 37  5cd284be-87d4-42b4-b5f1-94f8fc5d4210
# 38  5cd0f08e-39a0-4c78-906b-c88d7039144c
# 39  5cd0ef8b-920f-4eb3-8d5e-a8c15e29263f
# 40  5cd0effc-7aa5-4699-b00d-7c7f694afb5e
# 41  5cd2850c-ce84-4faa-a274-1107ee0beef0
# 42  5cd8ea5c-80a4-420a-bb4e-934ddd288863
# 43  5cd8f49d-1d1f-4a7d-a3d8-5556b95abd30
# 44  5cd29988-4e5f-40b2-8554-bd3cb20200a4
# 45  5cd8ea88-078b-44b2-90b5-30db4383b771
# 46  5cd8eaeb-03cd-40db-8e17-a410d8abb6ee
# 47  5cd9455f-7e83-4e83-b1f2-7abecffe251e
# 48  5cd29a39-a410-47b9-99ba-fe514d83d128
# 49  5cd93b1f-b2c9-4311-8100-2c7d006ac95e
# 50  5cd93e0d-85a4-4607-aca5-e6ac2873ea7f
# 51  5cd414ca-882e-4ef0-9530-6a306e4c9649
# 52  5cd414ac-66b1-4ed8-b27c-b91894c9ef21
# 53  5cd41506-bf3d-4c6f-a2d0-77a5fc77c145
# 54  5cd1080a-9e97-4d5d-b156-5719d993beb6
# 55  5cd93fa5-2871-4444-9177-a356a7cc65ee
# 56  5cd9467e-825a-482a-8318-36550ae98244
# 57  5ccfc050-41a3-43b9-9a5b-21f15c74a17e
# 58  5ccfb6cb-00c5-44f7-90e5-597d71789640
# 59  5cda87f9-2b81-4c15-b93e-f5a58601320d
# 60  5c9c7b97-9865-4923-8d2b-5826ed02ce31
# 61  5ca2d89e-3394-4cbb-92ab-5ad4e5b40b36
# 62  5cdcfe02-8aa8-4531-a113-d510fdeb132a
# 63  5cdcfeba-af85-4001-9d3d-0be08f18a915
#
# [64 rows x 14 columns]

# %%
ds = df[['Fid','Fname','endpoints','visualisationType','id']]

# %%
ds = ds.rename(columns={
    'Fid':'id',
    'Fname':'name',
    'endpoints':'endpoint',
    'visualisationType':'type',
    'id':'lumenid'
})

# %%
# Debug
# ds['endpoint'][1]
# testendpoint = '/aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2518/bar?query=%7B%22filters%22%3A%20%5B%5D%2C%20%22sort%22%3A%20null%2C%20%22subBucketColumn%22%3A%20%22c26020003%22%2C%20%22showLabels%22%3A%20false%2C%20%22metricAggregation%22%3A%20%22count%22%2C%20%22axisLabelXFromUser%22%3A%20false%2C%20%22legendTitle%22%3A%20%22%285.1.26%29%20Do%20you%20think%20that%20the%20winning%20candidate%20will%20be%20able%20to%20find%20out%20afterwards%20who%20you%20voted%20for%3F%22%2C%20%22axisLabelY%22%3A%20%22%20-%20count%22%2C%20%22horizontal%22%3A%20false%2C%20%22version%22%3A%201%2C%20%22metricColumnX%22%3A%20null%2C%20%22bucketColumn%22%3A%20%22d2%22%2C%20%22metricColumnY%22%3A%20null%2C%20%22showValueLabels%22%3A%20true%2C%20%22legendPosition%22%3A%20%22top%22%2C%20%22colors%22%3A%20%7B%22No%22%3A%20%22%23bf360c%22%2C%20%22Yes%22%3A%20%22%23388e3c%22%2C%20%22Not%20Sure%22%3A%20%22%23795548%22%7D%2C%20%22subBucketMethod%22%3A%20%22stack_percentage%22%2C%20%22axisLabelX%22%3A%20%22constituency-2%22%2C%20%22truncateSize%22%3A%20null%2C%20%22axisLabelYFromUser%22%3A%20false%7D'
# Flow.getData(instanceURL + testendpoint, Flow.getToken())

# %%
def renameProvince(x):
    renamedLabel = ''
    if x == "Maringe Kokota":
        renamedLabel = "Maringe / Kokota"
    elif x == "Gao Bugotu":
        renamedLabel = "Gao / Bugotu"
    elif x == "Russell Savo":
        renamedLabel = "Russells / Savo"
    elif x == "Lau Mbaelelea":
        renamedLabel = "Lau / Mbaelelea"
    elif x == "Aoke Langalanga":
        renamedLabel = "Aoke / Langalanga"
    else:
        renamedLabel = x
    return renamedLabel

# %%
getLegend = lambda x : [y['key'] for y in x]
getLabel = lambda x : [y['label'] for y in x]
getData = lambda x : [y['value'] for y in x]
ordered_province = pd.DataFrame([
    {'ordered':'Central Makira'},
    {'ordered':'East Guadalcanal'},
    {'ordered':'Central Guadalcanal'},
    {'ordered':'East Honiara'},
    {'ordered':'Central Honiara'},
    {'ordered':'West Honiara'},
    {'ordered':'Aoke Langalanga'},
    {'ordered':'Small Malaita'},
    {'ordered':'Lau Mbaelelea'},
    {'ordered':'Russell Savo'},
    {'ordered':'Gao Bugotu'},
    {'ordered':'Maringe Kokota'},
    {'ordered':'Gizo Kolombangara'},
    {'ordered':'North Vella Lavella'},
    {'ordered':'North West Choiseul'}
])
ordered_province['renamed'] = ordered_province['ordered'].apply(lambda x:renameProvince(x))
ordered_province.reset_index(level=0, inplace=True)

# %%
def checkPercentage(allValues):
    index = 0
    diff = 0
    total = sum(allValues)
    if total < 100:
        index = allValues.index(min(allValues))
        diff = 100 - total
    elif sum(allValues) > 100:
        index = allValues.index(max(allValues))
        diff = 100 - total
    else:
        pass
    return [index,diff]

# %%
yesno = ['Yes','No']
def checkColorOrder(dataSeries, dataCommon, graphType, legends):
    opt = ['Yes', 'No']
    if set(['Not Sure']).issubset(legends):
        opt.insert(2, 'Not Sure')
    legend_df = pd.Series(legends).to_frame('legend').reset_index()
    opt_df = pd.Series(opt).to_frame('order').reset_index()
    opt_df = opt_df.merge(legend_df, left_on='order', right_on='legend', suffixes=['_a', '_b'], how='outer')
    ordered_legends = list(opt_df.sort_values(by='index_a')['index_b'])
    ordered_series = []
    ordered_keys = []
    for i in ordered_legends:
        if graphType == 'bar':
            ordered_series.append(dataSeries[i])
        else:
            ordered_series.append(dataSeries[0]['data'][i])
            ordered_keys.append(dataCommon['data'][i])
    transformed = {
        "series": ordered_series,
        "keys": ordered_keys
    }
    return transformed

# %%
def createBarChart(b,ids):
    ordered = ordered_province
    data = b
    output = r.get(server + 'draft/results-barchart.json').json()
    unordered = pd.DataFrame(data['common']['data'])
    unordered.reset_index(level=0, inplace=True)
    ordered_index = unordered.merge(ordered,left_on='key',right_on='ordered')
    ordered_index = ordered_index.sort_values(by=['index_x'], ascending=True)
    available_province = ordered_index[['ordered','index_y']]
    available_province['ordered'] = available_province['ordered'].apply(renameProvince)
    available_province = list(available_province.sort_values(by=['index_y'], ascending=True)['ordered'])
    ordered_index = list(ordered_index['index_y'])
    legends = getLegend(data['series'])
    if set(yesno).issubset(legends):
        transformed = checkColorOrder(data['series'], None, 'bar', legends)
        data['series'] = transformed['series']
    output['legend']['data'] = getLegend(data['series'])
    output['xAxis']['data'] = available_province
    for i,l in enumerate(output['legend']['data']):
        if i == 0:
            df = pd.DataFrame(data['series'][i]['data']).rename(columns={'value':i})
        else:
            df[i] = pd.DataFrame(data['series'][i]['data']).rename(columns={'value':i})[i]
    df['sum'] = df.sum(axis = 1, skipna = True)
    df['order'] = pd.Series(ordered_index)
    df = df.sort_values(by=['order'], ascending=True).reset_index()
    for i,l in enumerate(output['legend']['data']):
        df[i] = round(df[i] / df['sum'] * 100).astype(int)
    df = df.drop(columns=['sum'])
    series = list(range(len(output["legend"]["data"])))
    for i, rows in df.iterrows():
        new_list = []
        for a in series:
            new_list.append(rows[a])
        adjust = checkPercentage(new_list)
        df[adjust[0]][i] = df[adjust[0]][i] + adjust[1]
    output['series'] = []
    for i,l in enumerate(output["legend"]["data"]):
        dataList = [None if di is 0 else di for di in list(df[i])]
        output["series"].append({"name": l,
                                 "type": "bar",
                                 "stack": "total",
                                 "label": {
                                     "normal": {
                                         "fontSize": 20,
                                         "fontWeight": "bold",
                                         "show": True,
                                         "position": "inside",
                                         "formatter": "{c}%"
                                     }
                                },"data": dataList})
    json_output = json.dumps(output)
    jname = ids.replace(".","-")
    f = open(workdir + jsondir + jname +".json","w")
    f.write(json_output)
    f.close()
    return jname

# %%
def createPieChart(b,ids):
    data = b
    output = r.get(server + 'draft/results-piechart.json').json()
    legends = getLegend(data['common']['data'])
    if set(yesno).issubset(legends):
        transformed = checkColorOrder(data['series'], data['common'],'pie', legends)
        data['series'][0]['data'] = transformed['series']
        data['common']['data'] = transformed['keys']
    ## Total
    ## output['title']['text'] = str(sum(getData(data['series'][0]['data'])))
    output['series'][0]['data'] = []
    for i,d in enumerate(data['series'][0]['data']):
        output['series'][0]['data'].append({'value':d['value'],'name':data['common']['data'][i]['key']})
    getName = lambda x : [y['name'] for y in x]
    output['legend']['data'] = getName(output['series'][0]['data'])
    json_output = json.dumps(output)
    jname = ids.replace(".","-")
    f = open(workdir + jsondir + jname +".json","w")
    f.write(json_output)
    f.close()
    return jname

# %%
def generateChart(endpoint,charttype,ids,lumenid):
    cachename = lumenid + '.json'
    jsoncache = workdir + cachedir + cachename
    if os.path.exists(jsoncache):
        data = r.get(server + cachedir + cachename).json()
    else:
        data = Flow.getData(instanceURL + endpoint, Flow.getToken())
        f = open(jsoncache,"w")
        f.write(json.dumps(data))
        f.close()
    if charttype == 'pie':
        result = createPieChart(data,ids)
    else:
        result = createBarChart(data,ids)
    return result

# %%
# Debug
# ds = ds.iloc[:5]

# %%
ds['json'] =  ds.apply(lambda x: generateChart(x['endpoint'],x['type'],x['id'],x['lumenid']), axis=1)
# Out:
# /Users/dedenbangkit/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/dedenbangkit/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Debug ga ngepek
skipchart = ['2.19','4.7.A','4.7.B','2.14','2.18.A','2.18.B']
print(list(ds[ds['id'].isin(skipchart)]['name']))
# Out:
# []

# %%
ds['endpoint'][0].split('/')[2]
# Out:
# '5c980e26-be25-47ee-9fe1-13eb6bdc2518'

# %%
def takeScreenShot(x,y):
    options = webdriver.ChromeOptions()
    options.add_argument('--ignore-certificate-errors')
    options.add_argument("--test-type")
    options.add_argument("--window-size=1920,1080")
    driver = webdriver.Chrome(chrome_options=options)
    driver.get('http://localhost:4000/#'+x)
    sleep(3)
    imagename = x + '-' + y.lower().replace('?',' ').replace('(','').replace(')','').replace(' ','-').replace('/','-')
    driver.save_screenshot('screenshots-0615/'+ imagename +'.png')
    driver.close()
    return imagename + '.png'

# %%
#ds = ds[ds['type'] == 'bar']

# %%
ds.append({'id',})
# Out:
#        id                                               name  \
# 0     3.3  Citizens asked to register in another constitu...
# 1     4.4  Winning candidate will find out who citizens v...
# 2    3.27  Would vote for a woman candidate. + By constit...
# 3    3.10   Accuracy of the electoral roll + By constituency
# 4    4.20  Overall assessment of voter conduct at polling...
# 5     5.4  Priority at polling station for people with di...
# 6    3.12  Citizens that have seen any SIEC media or awar...
# 7     5.3  Polling station accommodates needs of those wi...
# 8     4.3  Winning candidate will find out who citizens v...
# 9    4.9B  Most important factors that influenced voting ...
# 10   5.12  Formal court challenge by candidate + by const...
# 11   3.16  Shared or received information about the elect...
# 12    3.9  Accuracy of the electoral roll + All constitue...
# 13    5.6  Was the count completed in one day + all const...
# 14   3.15  Shared or received information about the elect...
# 15   3.26  Would vote for a woman candidate. + All consti...
# 16    3.2  Voters checked name at Voter Registration Cent...
# 17   3.23     Should be more women MPs. + All constituencies
# 18   3.31  Heard reports of candidates or candidate agent...
# 19   3.30  Candidates promised support to respondent or f...
# 20    4.6  Voter ID card is required to vote + All consti...
# 21   4.9A  Most important factors that influenced voting ...
# 22    3.5  Citizens who attempted to change their registr...
# 23   3.32  Heard reports of candidates or candidate agent...
# 24    4.5            Voter ID card is required to vote + All
# 25    3.6  Citizens changed registration to another const...
# 26    5.1  Transportation of ballot boxes to counting cen...
# 27   3.24        Should be more women MPs. + By constituency
# 28   3.19  Law and order situation during the campaign pe...
# 29   3.20  Election related tension or violence observed ...
# ..    ...                                                ...
# 34   4.13  Polling station opened on time + All constitue...
# 35    5.2  Was the PO unbiased and impartial + by constit...
# 36   4.11  Most important qualities voters want in candid...
# 37   4.7B  Most influence in deciding on how to vote + By...
# 38  3.33B  Hear about candidates soliciting votes on the ...
# 39   3.34  Hear about candidates soliciting votes on the ...
# 40   3.33  Hear about candidates soliciting votes on the ...
# 41    4.7  Most influence in deciding on how to vote + Al...
# 42   4.16  Polling assistants had difficulty locating nam...
# 43   4.19              Observed instances of underage voting
# 44   4.14   Polling station opened on time + By constituency
# 45   4.17  Women turned away because names could not be f...
# 46   4.18  Men turned away because names could not be fou...
# 47   5.10         Transparency of count + all constituencies
# 48   4.15  Compartments positioned to screen voters from ...
# 49    5.5  Incidents of minor post-election violence + al...
# 50    5.7    Accounting of ballots by RO + by constituencies
# 51    3.8  Citizens know of voters registered in their co...
# 52    3.7  Citizens know of voters registered in their co...
# 53    3.4  Citizens asked to register in another constitu...
# 54   3.29  Candidates promised support to respondent or f...
# 55    5.8  Detsrmining validity of votes + by constituencies
# 56   5.11  Candidates-Counting agents influencing the cou...
# 57   3.21  Election-related tension or violence heard abo...
# 58    3.1  Voters checked name at Voter Registration Cent...
# 59   4.12  Most important qualities voters want in candid...
# 60   3.11  Citizens that have seen any SIEC media or awar...
# 61   3.22  Election where intimidation was greatest? + Al...
# 62   3.25  Do you think there should be more women MPs? +...
# 63   3.28  Would vote for a woman candidate. + All consti...
#
#                                              endpoint type  \
# 0   /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  pie
# 1   /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 2   /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 3   /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...  bar
# 4   /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...  bar
# 5   /aggregation/5cad67a5-f1ef-4f44-9a19-ae52f4fcc...  bar
# 6   /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 7   /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...  bar
# 8   /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  pie
# 9   /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...  bar
# 10  /aggregation/5cad67fa-d87b-49ed-9b82-662fb643d...  bar
# 11  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 12  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...  pie
# 13  /aggregation/5cad67d8-d6dc-4362-b827-281455ec6...  pie
# 14  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  pie
# 15  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  pie
# 16  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 17  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  pie
# 18  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...  pie
# 19  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 20  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 21  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...  bar
# 22  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 23  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...  bar
# 24  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  pie
# 25  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...  bar
# 26  /aggregation/5cad67a5-f1ef-4f44-9a19-ae52f4fcc...  pie
# 27  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 28  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...  pie
# 29  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...  bar
# ..                                                ...  ...
# 34  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...  pie
# 35  /aggregation/5cad67a5-f1ef-4f44-9a19-ae52f4fcc...  bar
# 36  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...  bar
# 37  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...  bar
# 38  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...  bar
# 39  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...  bar
# 40  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...  pie
# 41  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...  pie
# 42  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...  bar
# 43  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...  bar
# 44  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...  bar
# 45  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...  pie
# 46  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...  pie
# 47  /aggregation/5cad67d8-d6dc-4362-b827-281455ec6...  pie
# 48  /aggregation/5c9c1e4d-acf7-4b88-92b0-4a06c9be5...  bar
# 49  /aggregation/5cad67a5-f1ef-4f44-9a19-ae52f4fcc...  pie
# 50  /aggregation/5cad67d8-d6dc-4362-b827-281455ec6...  bar
# 51  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 52  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  pie
# 53  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 54  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  pie
# 55  /aggregation/5cad67d8-d6dc-4362-b827-281455ec6...  bar
# 56  /aggregation/5cad67d8-d6dc-4362-b827-281455ec6...  pie
# 57  /aggregation/5c9c15de-864a-49a6-931a-5b081d33d...  pie
# 58  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  pie
# 59  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...  bar
# 60  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  pie
# 61  /aggregation/5c91ad95-f929-41dd-bbec-1436d56e9...  pie
# 62  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
# 63  /aggregation/5c980e26-be25-47ee-9fe1-13eb6bdc2...  bar
#
#                                  lumenid   json
# 0   5cd41572-242c-4a06-8f4f-c283376d8689    3-3
# 1   5c997c2d-d4fa-4492-9b6c-348d590c3472    4-4
# 2   5c998616-f56f-40b5-b806-2eb3a3e12801   3-27
# 3   5c9c374a-8d58-4838-9ca5-c8f404015f12   3-10
# 4   5cd8f90c-68e5-42e8-a88a-c34621108176   4-20
# 5   5cd93460-eb50-4717-b912-920ba60df024    5-4
# 6   5c99bbe4-d49a-47ef-a143-4e40994adc40   3-12
# 7   5c9c1ea6-11c9-4644-a29d-6257debcf075    5-3
# 8   5c9c803c-099b-4013-8d6c-1149551dffd0    4-3
# 9   5cda8fb3-831c-45ed-bc2b-b698ae40df92   4-9B
# 10  5cadb56c-3ae1-4bcd-9fd6-fae8fe35cbf8   5-12
# 11  5c997757-a7c9-4b9b-aab1-f3a6cc9463fc   3-16
# 12  5ca2d490-9fdc-4b93-a836-d4d08ad57f77    3-9
# 13  5cd93fe2-a9c2-4543-9182-a78a81c3d949    5-6
# 14  5c9c7df5-6b93-4379-b440-7e8ed8af97fb   3-15
# 15  5c9c808a-15d5-41e0-b57b-bc8a86ed22c8   3-26
# 16  5ccfb75d-da71-43a8-b022-cb302e96d72b    3-2
# 17  5cd0d9a8-cbed-490a-986e-6cdd3debff4b   3-23
# 18  5cd0e165-946a-4e26-ab8e-9ab66f7f1e42   3-31
# 19  5cad8dcc-93ee-49ab-ac2c-5a98ddcc7ac0   3-30
# 20  5ccfd76a-2f5e-4ee5-afd9-190a9e6e8173    4-6
# 21  5cda8f34-156b-4537-93be-0a2869876915   4-9A
# 22  5ccfba60-85ab-4308-9ff7-f518ab25ff63    3-5
# 23  5cd0e216-68ee-4dfc-a91d-751377d9410e   3-32
# 24  5ccfd7b4-29bd-472c-9920-3adc88d9e61c    4-5
# 25  5ccfbb2d-b044-47bc-b980-709d07d72cb6    3-6
# 26  5cd92486-5146-440a-88ff-b0d98665243f    5-1
# 27  5cad9570-ac92-468c-bc60-3bfccc0eb7a7   3-24
# 28  5ccfbc29-6c1f-41b8-822b-5ea661d84db8   3-19
# 29  5ccfc09c-f946-4cb2-b611-d3aee2d17d92   3-20
# ..                                   ...    ...
# 34  5cd4066f-8093-4e8e-a91a-a102b8f5e902   4-13
# 35  5cd92f8e-a652-4268-9615-69eb02f191e8    5-2
# 36  5cda86a3-5d01-4549-a20e-b6598f213fa8   4-11
# 37  5cd284be-87d4-42b4-b5f1-94f8fc5d4210   4-7B
# 38  5cd0f08e-39a0-4c78-906b-c88d7039144c  3-33B
# 39  5cd0ef8b-920f-4eb3-8d5e-a8c15e29263f   3-34
# 40  5cd0effc-7aa5-4699-b00d-7c7f694afb5e   3-33
# 41  5cd2850c-ce84-4faa-a274-1107ee0beef0    4-7
# 42  5cd8ea5c-80a4-420a-bb4e-934ddd288863   4-16
# 43  5cd8f49d-1d1f-4a7d-a3d8-5556b95abd30   4-19
# 44  5cd29988-4e5f-40b2-8554-bd3cb20200a4   4-14
# 45  5cd8ea88-078b-44b2-90b5-30db4383b771   4-17
# 46  5cd8eaeb-03cd-40db-8e17-a410d8abb6ee   4-18
# 47  5cd9455f-7e83-4e83-b1f2-7abecffe251e   5-10
# 48  5cd29a39-a410-47b9-99ba-fe514d83d128   4-15
# 49  5cd93b1f-b2c9-4311-8100-2c7d006ac95e    5-5
# 50  5cd93e0d-85a4-4607-aca5-e6ac2873ea7f    5-7
# 51  5cd414ca-882e-4ef0-9530-6a306e4c9649    3-8
# 52  5cd414ac-66b1-4ed8-b27c-b91894c9ef21    3-7
# 53  5cd41506-bf3d-4c6f-a2d0-77a5fc77c145    3-4
# 54  5cd1080a-9e97-4d5d-b156-5719d993beb6   3-29
# 55  5cd93fa5-2871-4444-9177-a356a7cc65ee    5-8
# 56  5cd9467e-825a-482a-8318-36550ae98244   5-11
# 57  5ccfc050-41a3-43b9-9a5b-21f15c74a17e   3-21
# 58  5ccfb6cb-00c5-44f7-90e5-597d71789640    3-1
# 59  5cda87f9-2b81-4c15-b93e-f5a58601320d   4-12
# 60  5c9c7b97-9865-4923-8d2b-5826ed02ce31   3-11
# 61  5ca2d89e-3394-4cbb-92ab-5ad4e5b40b36   3-22
# 62  5cdcfe02-8aa8-4531-a113-d510fdeb132a   3-25
# 63  5cdcfeba-af85-4001-9d3d-0be08f18a915   3-28
#
# [64 rows x 6 columns]

# %%
#ds

# %%
#ds['img'] = ds.apply(lambda x: takeScreenShot(x['json'],x['name']),axis=1)

# %%
retakes = [
    '3.7',
    '3.13',
    '4.8',
    '4.9A',
    '4.9B',
    '4.10',
    '4.11',
    '4.12',
]
for retake in retakes:
    #replacer = list(ds[ds['id'] == retake]['name'])[0]
    takeScreenShot(retake.replace('.','-'),retake.replace('.','-')+'_new-')

# %%
#takeScreenShot('3-28','gender')
