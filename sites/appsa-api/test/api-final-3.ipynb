# %% [markdown]
# ## Init Dependencies

# %%
import requests
import os
import pandas as pd
from datetime import datetime
import json
import numpy as np

# %% [markdown]
# ### Workspace Setup

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %% [markdown]
# ## Set Static Variables

# %%
URL = 'http://rsr.akvo.org/rest/v1/'
RSR_TOKEN = os.environ['RSR_TOKEN']
FMT = '/?format=json&limit=1'
FMT100 = '/?format=json&limit=100'

# %% [markdown]
# ## Set Filter

# %%
project_id = '7950'
project_type = 'parent' #grand_parent
filter_date = '2017' #'2017-01-01 - 2017-12-31'
filter_date_type = 'yearly' #semester
filter_country = ['Malawi','Mozambique','Zambia']

# %% [markdown]
# ## Set Authentication

# %%
headers = {
    'content-type': 'application/json',
    'Authorization': RSR_TOKEN
}

# %% [markdown]
# ## Helper Functions

# %%
def get_response(endpoint, param, value):
    uri = '{}{}{}&{}={}'.format(URL, endpoint, FMT100, param, value)
    print(get_time() + ' Fetching - ' + uri)
    data = requests.get(uri, headers=headers)
    data = data.json()
    return data

# %%
def get_time():
    now = datetime.now().time().strftime("%H:%M:%S")
    return now

# %%
def get_sibling_id(x):
    for k,v in x.items():
        return k

# %%
def get_report_type(ps,pe):
    rt = {'is_yearly':False,'latest':False}
    try:
        psm = ps.split('-')[1]
        pem = pe.split('-')[1]
        if psm == '01' and pem == '12':
            rt = {'is_yearly':True,'period_latest':True}
        if psm == '01' and pem == '01':
            rt = {'is_yearly':True,'period_latest':True}
        if psm == '01' and pem == '06':
            rt = {'is_yearly':False,'period_latest':False}
        if psm == '07' and pem == '12':
            rt = {'is_yearly':False,'period_latest':True}
    except:
        pass
    return rt

# %%
def get_dimension_country(dv):
    dp = dv['value'].split(' - ')
    tt = dv['project_title'].split(' ')[1]
    dv = {}
    if dp[0].lower() in ['zambia','malawi','mozambique']:
        dv.update({
            'commodity':'',
            'country':dp[0]
        })
    else:
        dv.update({
            'commodity':dp[0],
            'country': tt
        })
    if len(dp) == 2:
        dv.update({
            'commodity':dp[0],
            'country':dp[1]
        })
    return dv

# %% [markdown]
# ## Find Related Project

# %%
related_project = get_response('related_project','related_project',PROJECT_ID)
# Out:
# 20:32:38 Fetching - http://rsr.akvo.org/rest/v1/related_project/?format=json&limit=100&related_project=7950

# %%
results_framework_list = [project_id]
if project_type == 'parent':
    results_framework_list = list(pd.DataFrame(related_project['results'])['project'])
if project_type == 'grand_parent':
    parent_list = list(pd.DataFrame(related_project['results'])['project'])
    results_framwork_list = []
    for second_level in parent_list:
        second_list = get_response('related_project','related_project',second_level)
        try:
            second_list = list(pd.DataFrame(second_list['results'])['project'])
            for third_level in second_list:
                results_framework_list.append(third_level)
        except:
            pass

# %%
results_framework_list
# Out:
# [8019, 7924, 7858]

# %% [markdown]
# ### Trace All Children (Alternative)

# %%
def trace_all_childrens(project_id, all_childs, level):
    related = get_response('related_project','related_project',project_id)        
    if len(related['results']) > 0:
        for result in related['results']:
            level = level + 1
            print(level)
            all_childs.append(result)
            trace_all_childrens(result['project'], all_childs, level)
    return all_childs

# %% [markdown]
# ### Trace All Children Results(Alternative)

# %%
def trace_all_results(all_childs):
    results_framework = []
    for child in all_childs:
        res = get_response('results_framework','project',child['project'])
        for rf in res['results']:
            results_framework.append(rf)
    return results_framework

# %% [markdown]
# ### Concat Results Frameworks (Alternative)

# %%
def trace_onechildren():
    results_framework = []
    for i, rf in enumerate(results_framework_list):
        result_framework = get_response('results_framework','project',rf)['results']
        if i == 0:
            results_framework = result_framework
        else:
            for res in result_framework:
                results_framework.append(res)
    return results_framework

# %% [markdown]
# ### Only Parents

# %%
results_framework = []
def no_trace():
    results_framework = get_response('results_framework','project',PROJECT_ID)['results']
    return results_framework

# %% [markdown]
# ### Choose Trace Level

# %%
if project_type == 'child':
    results_framework = no_trace()
if project_type == 'parent':
    results_framework = trace_onechildren()
if project_type == 'grand_parent':
    #all_childrens = trace_all_childrens(PROJECT_ID, [],1)
    results_framework = trace_onechildren()
# Out:
# 20:32:46 Fetching - http://rsr.akvo.org/rest/v1/results_framework/?format=json&limit=100&project=8019
# 20:32:51 Fetching - http://rsr.akvo.org/rest/v1/results_framework/?format=json&limit=100&project=7924
# 20:32:55 Fetching - http://rsr.akvo.org/rest/v1/results_framework/?format=json&limit=100&project=7858

# %% [markdown]
# ## Begin Transformations

# %%
results_framework = pd.DataFrame(results_framework)

# %% [markdown]
# ### Generate List of All Objects

# %%
results_framework['child_projects'] = results_framework['child_projects'].apply(get_sibling_id)

# %%
if project_type == 'grand_parent':
    results_framwork = results_framework[results_framework['child_projects'].isnull()].reset_index().drop(columns=['index'])

# %%
results_framework = results_framework.to_dict('records')

# %%
indicators = []
periods = []
dimension_names = []
dimension_values = []
disaggregations = []
disaggregation_targets = []
for result_framework in results_framework:
    rf_id = {'result':result_framework['id']}
    rf_project = {'project':result_framework['project_title']}
    rf_title = {'project_title':result_framework['title']}
    for indicator in result_framework['indicators']:
        indicator_id = indicator['id']
        indicator_title = {'indicator':indicator['title']}
        for period in indicator['periods']:
            is_yearly = get_report_type(period['period_start'],period['period_end'])
            period.update({'year':period['period_start'].split('-')[0]})
            period.update({'period_date' : period['period_start'] + ' - ' + period['period_end']})
            period.update(rf_title)
            period.update(rf_project)
            period.update(is_yearly)
            period.update(rf_id)
            period.update({'indicator':indicator_id})
            periods.append(period)
            for data in period['data']:
                if len(data) > 0:
                    actual_value = {'actual_value':data['value']}
                    for disaggregation in data['disaggregations']:
                        disaggregation.update({'period':period['id']})
                        disaggregation.update({'parent_period':period['parent_period']})
                        disaggregation.update({'result_id':result_framework['id']})
                        disaggregation.update(rf_title)
                        disaggregation.update(rf_project)
                        disaggregation.update({'indicator_id':indicator_id})
                        disaggregation.update(actual_value)
                        disaggregation.update(indicator_title)
                        disaggregations.append(disaggregation)
            if len(period['disaggregation_targets']) > 0:
                target_value = {'target_value':period['target_value']}
                for disaggregation_target in period['disaggregation_targets']:
                    disaggregation_target.update({'period':period['id']})
                    disaggregation_target.update({'parent_period':period['parent_period']})
                    disaggregation_target.update({'indicator_id':indicator_id})
                    disaggregation_target.update(indicator_title)
                    disaggregation_target.update({'result_id':result_framework['id']})
                    disaggregation_target.update(rf_title)
                    disaggregation_target.update(rf_project)
                    disaggregation_target.update(target_value)
                    disaggregation_targets.append(disaggregation_target)
        #del indicator['periods']
        for dimension_name in indicator['dimension_names']:
            for dimension_value in dimension_name['values']:
                dimension_value.update(rf_id)
                dimension_value.update({'project_title':result_framework['project_title']})
                dimension_update = get_dimension_country(dimension_value)
                dimension_value.update(dimension_update)
                dimension_value.update({'dimension_name':dimension_name['name']})
                dimension_values.append(dimension_value)
            # del dimension_name['values']
            dimension_name.update(rf_id)
            dimension_name.update({'indicator':indicator_id})
            dimension_names.append(dimension_name)
        #del indicator['dimension_names']
        indicators.append(indicator)

# %% [markdown]
# ## Filters & Joins

# %% [markdown]
# ### Filter Periods

# %%
period_df = pd.DataFrame(periods)
if filter_date_type == 'yearly':
    period_df = period_df[period_df['year'] == filter_date]
    period_df = period_df[(period_df['is_yearly']) & (period_df['period_latest'])]
else:
    period_df = period_df[period_df['period_date'] == filter_date]
    period_df = period_df[~(period_df['is_yearly']) & (period_df['period_latest'])]

# %%
disaggregations_df = pd.DataFrame(disaggregations)
disaggregations_df = pd.merge(disaggregations_df, 
                           period_df, 
                           left_on='period', 
                           right_on='id', 
                           suffixes=['_dm','_period'],
                           how='inner')

# %%
dropdm = [
    'actual_value_dm',
    'denominator_dm',
    'parent_period_dm',
    'project_title_dm',
    'project_dm',
    'numerator_dm',
    'narrative_dm'
]
droplist = [
    'incomplete_data',
    'indicator_period',
    'parent_period_period',
    'denominator_period',
    'disaggregation_targets',
    'result_id',
    'locked',
    'update',
    'created_at',
    'last_modified_at',
    'data',
    'narrative_period',
    'numerator_period',
    'period_latest',
    'year',
    'is_yearly',
    'period_start',
    'period_end',
    'percent_accomplishment',
    'period'
]
droplist = droplist + dropdm
disaggregations_list = list(disaggregations_df)
disaggregations_df = disaggregations_df[disaggregations_list].drop(columns=droplist)
rename_columns = {x:x.replace('_period','') for x in list(disaggregations_df)}
disaggregations_df = disaggregations_df.rename(columns=rename_columns)

# %% [markdown]
# ### Dimension Names

# %%
dimension_values_df = pd.DataFrame(dimension_values)

# %%
dimension_values_df = dimension_values_df.drop(columns=['result','project_title','name','parent_dimension_value']).groupby([
    'id','dimension_name','value','commodity','country'
]).first().reset_index()

# %%
disaggregations_df = pd.merge(
    dimension_values_df,
    disaggregations_df,
    left_on='id',
    right_on='dimension_value',
    suffixes=['_dsg','_dms'],
    how='inner').rename(columns={
    'dimension_name_dms':'dimension_id',
    'dimension_name_dsg':'dimension_name',
    'indicator_dm':'indicator_name',
    'id_dms':'period_id',
    'id_dsg':'data_id',
    'value_dms':'value',
    'country_dsg':'country',
    'commodity_dsg':'commodity'
    }).drop(columns=[
    'data_id',
    'period_id',
    'value_dsg',
    'result',
    'project',
    'id_dm'
    ])

# %%
disaggregations_df
# Out:
#                dimension_name  \
# 0          Type of technology
# 1          Type of technology
# 2          Type of technology
# 3          Type of technology
# 4          Type of technology
# 5          Type of technology
# 6          Type of technology
# 7          Type of technology
# 8          Type of technology
# 9          Type of technology
# 10         Type of technology
# 11         Type of technology
# 12         Type of technology
# 13         Type of technology
# 14         Type of technology
# 15         Type of technology
# 16         Type of technology
# 17         Type of technology
# 18         Type of technology
# 19         Type of technology
# 20         Type of technology
# 21                      IRI 7
# 22                      IRI 7
# 23                      IRI 7
# 24                      IRI 7
# 25                      IRI 7
# 26                      IRI 7
# 27                      IRI 7
# 28                Gender RCoL
# 29                Gender RCoL
# 30                Gender RCoL
# 31                Gender RCoL
# 32         Type of technology
# 33         Type of technology
# 34         Type of technology
# 35         Type of technology
# 36         Type of technology
# 37         Type of technology
# 38         Type of technology
# 39         Type of technology
# 40         Type of technology
# 41         Type of technology
# 42         Type of technology
# 43         Type of technology
# 44         Type of technology
# 45         Type of technology
# 46         Type of technology
# 47         Type of technology
# 48         Type of technology
# 49                      IRI 7
# 50                      IRI 7
# 51                      IRI 7
# 52                      IRI 7
# 53                      IRI 7
# 54                      IRI 7
# 55                      IRI 7
# 56                Gender RCoL
# 57                Gender RCoL
# 58                Gender RCoL
# 59                Gender RCoL
# 60         Type of technology
# 61         Type of technology
# 62         Type of technology
# 63         Type of technology
# 64         Type of technology
# 65         Type of technology
# 66         Type of technology
# 67         Type of technology
# 68         Type of technology
# 69         Type of technology
# 70         Type of technology
# 71         Type of technology
# 72         Type of technology
# 73         Type of technology
# 74         Type of technology
# 75         Type of technology
# 76         Type of technology
# 77         Type of technology
# 78         Type of technology
# 79         Type of technology
# 80         Type of technology
# 81                      IRI 7
# 82                      IRI 7
# 83                      IRI 7
# 84                      IRI 7
# 85                      IRI 7
# 86                      IRI 7
# 87                      IRI 7
# 88                Gender RCoL
# 89                Gender RCoL
# 90                Gender RCoL
# 91                Gender RCoL
# 92           Type of training
# 93           Type of training
# 94           Type of training
# 95           Type of training
# 96           Type of training
# 97           Type of training
# 98           Type of training
# 99           Type of training
# 100          Type of training
# 101          Type of training
# 102          Type of training
# 103          Type of training
# 104          Type of training
# 105          Type of training
# 106          Type of training
# 107  Type of research project
# 108  Type of research project
# 109  Type of research project
# 110  Type of research project
# 111  Type of research project
# 112  Type of research project
# 113  Type of research project
# 114  Type of research project
# 115  Type of research project
# 116  Type of research project
# 117  Type of research project
# 118  Type of research project
# 119       Type of scholarship
# 120       Type of scholarship
# 121       Type of scholarship
# 122       Type of scholarship
# 123       Type of scholarship
# 124       Type of scholarship
# 125       Type of scholarship
# 126       Type of scholarship
# 127       Type of scholarship
# 128       Type of scholarship
# 129       Type of scholarship
# 130       Type of scholarship
# 131       Type of scholarship
# 132       Type of scholarship
# 133       Type of scholarship
# 134       Type of scholarship
# 135       Type of scholarship
# 136       Type of scholarship
#
#                                              commodity     country  \
# 0                    Number of improved seed varieties  Mozambique
# 1                    Number of improved seed varieties  Mozambique
# 2                    Number of improved seed varieties  Mozambique
# 3                                                Maize  Mozambique
# 4                                                Maize  Mozambique
# 5                                                Maize  Mozambique
# 6                                                 Rice  Mozambique
# 7                                                 Rice  Mozambique
# 8                                                 Rice  Mozambique
# 9                                              Legumes  Mozambique
# 10                                             Legumes  Mozambique
# 11                                             Legumes  Mozambique
# 12                                             Cassava  Mozambique
# 13                                             Cassava  Mozambique
# 14                                             Cassava  Mozambique
# 15   Number of improved agronomic, pest and disease...  Mozambique
# 97                training in administrative processes  Mozambique
# 98                training in administrative processes  Mozambique
# 99                training in administrative processes      Zambia
# 100               training in administrative processes      Malawi
# 101               training in administrative processes      Malawi
# 102      technical research and dissemination training  Mozambique
# 103      technical research and dissemination training  Mozambique
# 104      technical research and dissemination training      Zambia
# 105      technical research and dissemination training      Malawi
# 106      technical research and dissemination training      Malawi
# 107                              Technology generation  Mozambique
# 108                              Technology generation  Mozambique
# 109                           Technology dissemination  Mozambique
# 110                           Technology dissemination  Mozambique
# 111                              Technology generation      Zambia
# 112                              Technology generation      Zambia
# 113                           Technology dissemination      Zambia
# 114                           Technology dissemination      Zambia
# 115                              Technology generation      Malawi
# 116                              Technology generation      Malawi
# 117                           Technology dissemination      Malawi
# 118                           Technology dissemination      Malawi
# 119                                      Number of PhD  Mozambique
# 120                               Number of female PhD  Mozambique
# 121                                      Number of MSc  Mozambique
# 122                               Number of female MSc  Mozambique
# 123                                      Number of BSc  Mozambique
# 124                               Number of female BSc  Mozambique
# 125                                      Number of PhD      Zambia
# 126                               Number of female PhD      Zambia
# 127                                      Number of MSc      Zambia
# 128                               Number of female MSc      Zambia
# 129                                      Number of BSc      Zambia
# 130                               Number of female BSc      Zambia
# 131                                      Number of PhD      Malawi
# 132                               Number of female PhD      Malawi
# 133                                      Number of MSc      Malawi
# 134                               Number of female MSc      Malawi
# 135                                      Number of BSc      Malawi
# 136                               Number of female BSc      Malawi
#
#      dimension_id    value  dimension_value  indicator_id  \
# 0             554    51.00             1291         80750
# 1             554    10.00             1291         80752
# 2             554    51.00             1291         80757
# 3             554    12.00             1292         80750
# 4             554     0.00             1292         80752
# 5             554     6.00             1292         80757
# 6             554    10.00             1293         80750
# 7             554     2.00             1293         80752
# 8             554    10.00             1293         80757
# 9             554    23.00             1294         80750
# 10            554     8.00             1294         80752
# 11            554    23.00             1294         80757
# 12            554     6.00             1295         80750
# 13            554     0.00             1295         80752
# 14            554     6.00             1295         80757
# 15            554    19.00             1296         80750
# 16            554     7.00             1296         80752
# 17            554    19.00             1296         80757
# 18            554    45.00             1297         80750
# 19            554    11.00             1297         80752
# 20            554    45.00             1297         80757
# 21            556     2.00             1301         80756
# 22            556     0.00             1302         80756
# 23            556     2.00             1303         80756
# 24            556     0.00             1304         80756
# 25            556     0.00             1305         80756
# 26            556    12.00             1306         80756
# 27            556     0.00             1307         80756
# 28            557  1070.00             1308         80759
# 29            557   591.00             1308         80760
# 30            557   774.00             1309         80759
# 31            557   253.00             1309         80760
# 32            565    43.00             1338         80769
# 33            565     5.00             1338         80771
# 34            565     0.00             1338         80776
# 35            565     9.00             1339         80769
# 36            565     0.00             1339         80776
# 37            565     4.00             1340         80769
# 38            565     0.00             1340         80776
# 39            565    22.00             1341         80769
# 40            565     0.00             1341         80776
# 41            565     7.00             1342         80769
# 42            565     0.00             1342         80776
# 43            565    15.00             1343         80769
# 44            565     0.00             1343         80771
# 45            565     0.00             1343         80776
# 46            565    33.00             1344         80769
# 47            565     0.00             1344         80771
# 48            565     0.00             1344         80776
# 49            567    11.00             1348         80775
# 4    PDO 3 Number of technologies generated or prom...            7
# 5    8. Total number of improved technologies forma...            7
# 6    PDO 1 Number of technologies that are being ma...           27
# 7    PDO 3 Number of technologies generated or prom...            7
# 8    8. Total number of improved technologies forma...            7
# 9    PDO 1 Number of technologies that are being ma...           27
# 10   PDO 3 Number of technologies generated or prom...            7
# 11   8. Total number of improved technologies forma...            7
# 12   PDO 1 Number of technologies that are being ma...           27
# 13   PDO 3 Number of technologies generated or prom...            7
# 14   8. Total number of improved technologies forma...            7
# 15   PDO 1 Number of technologies that are being ma...           27
# 16   PDO 3 Number of technologies generated or prom...            7
# 17   8. Total number of improved technologies forma...            7
# 18   PDO 1 Number of technologies that are being ma...           27
# 19   PDO 3 Number of technologies generated or prom...            7
# 20   8. Total number of improved technologies forma...            7
# 21           7. Total number of technologies generated           20
# 22           7. Total number of technologies generated           20
# 23           7. Total number of technologies generated           20
# 24           7. Total number of technologies generated           20
# 25           7. Total number of technologies generated           20
# 26           7. Total number of technologies generated           20
# 27           7. Total number of technologies generated           20
# 28   10. (a) Number of clients (research and adviso...         2100
# 29   10. (b) Number of staff trained per research c...           70
# 30   10. (a) Number of clients (research and adviso...         2100
# 31   10. (b) Number of staff trained per research c...           70
# 32   PDO 1 Number of technologies that are being ma...           88
# 33   PDO 3 Number of technologies generated or prom...           14
# 34   8. Total number of improved technologies forma...           47
# 35   PDO 1 Number of technologies that are being ma...           88
# 36   8. Total number of improved technologies forma...           47
# 37   PDO 1 Number of technologies that are being ma...           88
# 38   8. Total number of improved technologies forma...           47
# 39   PDO 1 Number of technologies that are being ma...           88
# 40   8. Total number of improved technologies forma...           47
# 41   PDO 1 Number of technologies that are being ma...           88
# 42   8. Total number of improved technologies forma...           47
# 43   PDO 1 Number of technologies that are being ma...           88
# 44   PDO 3 Number of technologies generated or prom...           14
# 45   8. Total number of improved technologies forma...           47
# 46   PDO 1 Number of technologies that are being ma...           88
# 47   PDO 3 Number of technologies generated or prom...           14
# 48   8. Total number of improved technologies forma...           47
# 49           7. Total number of technologies generated           47
# 50           7. Total number of technologies generated           47
# 51           7. Total number of technologies generated           47
# 52           7. Total number of technologies generated           47
# 53           7. Total number of technologies generated           47
# 54           7. Total number of technologies generated           47
# 55           7. Total number of technologies generated           47
# 56   10. (a) Number of clients (research and adviso...         2170
# 57   10. (b) Number of staff trained per research c...           88
# 58   10. (a) Number of clients (research and adviso...         2170
# 59   10. (b) Number of staff trained per research c...           88
# 60   PDO 1 Number of technologies that are being ma...           76
# 61   PDO 3 Number of technologies generated or prom...           15
# 62   8. Total number of improved technologies forma...           43
# 63   PDO 1 Number of technologies that are being ma...           76
# 64   PDO 3 Number of technologies generated or prom...           15
# 65   8. Total number of improved technologies forma...           43
# 66   PDO 1 Number of technologies that are being ma...           76
# 67   PDO 3 Number of technologies generated or prom...           15
# 68   8. Total number of improved technologies forma...           43
# 69   PDO 1 Number of technologies that are being ma...           76
# 70   PDO 3 Number of technologies generated or prom...           15
# 71   8. Total number of improved technologies forma...           43
# 72   PDO 1 Number of technologies that are being ma...           76
# 73   PDO 3 Number of technologies generated or prom...           15
# 74   8. Total number of improved technologies forma...           43
# 75   PDO 1 Number of technologies that are being ma...           76
# 76   PDO 3 Number of technologies generated or prom...           15
# 77   8. Total number of improved technologies forma...           43
# 78   PDO 1 Number of technologies that are being ma...           76
# 79   PDO 3 Number of technologies generated or prom...           15
# 80   8. Total number of improved technologies forma...           43
# 81           7. Total number of technologies generated           43
# 82           7. Total number of technologies generated           43
# 83           7. Total number of technologies generated           43
# 84           7. Total number of technologies generated           43
# 85           7. Total number of technologies generated           43
# 86           7. Total number of technologies generated           43
# 87           7. Total number of technologies generated           43
# 88   10. (a) Number of clients (research and adviso...          412
# 89   10. (b) Number of staff trained per research c...           47
# 90   10. (a) Number of clients (research and adviso...          412
# 91   10. (b) Number of staff trained per research c...           47
# 92   10. (a) Number of clients (research and adviso...         2100
# 93   10. (b) Number of staff trained per research c...           70
# 94   10. (b) Number of staff trained per research c...           88
# 95   10. (a) Number of clients (research and adviso...          412
# 96   10. (b) Number of staff trained per research c...           47
# 97   10. (a) Number of clients (research and adviso...         2100
# 98   10. (b) Number of staff trained per research c...           70
# 99   10. (b) Number of staff trained per research c...           88
# 100  10. (a) Number of clients (research and adviso...          412
# 101  10. (b) Number of staff trained per research c...           47
# 102  10. (a) Number of clients (research and adviso...         2100
# 103  10. (b) Number of staff trained per research c...           70
# 104  10. (b) Number of staff trained per research c...           88
# 105  10. (a) Number of clients (research and adviso...          412
# 106  10. (b) Number of staff trained per research c...           47
# 107  5. Number of collaborative research and develo...           36
# 108  6. Percentage of collaborative research and de...           40
# 109  5. Number of collaborative research and develo...           36
# 110  6. Percentage of collaborative research and de...           40
# 111  5. Number of collaborative research and develo...           32
# 112  6. Percentage of collaborative research and de...           75
# 113  5. Number of collaborative research and develo...           32
# 114  6. Percentage of collaborative research and de...           75
# 115  5. Number of collaborative research and develo...           30
# 116  6. Percentage of collaborative research and de...           80
# 117  5. Number of collaborative research and develo...           30
# 118  6. Percentage of collaborative research and de...           80
# 119  11. Total # of funded scholarship holder that ...            5
# 120  11. Total # of funded scholarship holder that ...            5
# 121  11. Total # of funded scholarship holder that ...            5
# 122  11. Total # of funded scholarship holder that ...            5
# 123  11. Total # of funded scholarship holder that ...            5
# 124  11. Total # of funded scholarship holder that ...            5
# 125  11. Total # of funded scholarship holder that ...           43
# 126  11. Total # of funded scholarship holder that ...           43
# 127  11. Total # of funded scholarship holder that ...           43
# 128  11. Total # of funded scholarship holder that ...           43
# 129  11. Total # of funded scholarship holder that ...           43
# 130  11. Total # of funded scholarship holder that ...           43
# 131  11. Total # of funded scholarship holder that ...           25
# 132  11. Total # of funded scholarship holder that ...           25
# 133  11. Total # of funded scholarship holder that ...           25
# 134  11. Total # of funded scholarship holder that ...           25
# 135  11. Total # of funded scholarship holder that ...           25
# 136  11. Total # of funded scholarship holder that ...           25
#
#     target_comment actual_value  \
# 0                        115.00
# 1                         28.00
# 2                        115.00
# 3                        115.00
# 4                         28.00
# 5                        115.00
# 6                        115.00
# 7                         28.00
# 123  Intermediate Result 2: Improved technical capa...
# 124  Intermediate Result 2: Improved technical capa...
# 125  Intermediate Result 2: Improved technical capa...
# 126  Intermediate Result 2: Improved technical capa...
# 127  Intermediate Result 2: Improved technical capa...
# 128  Intermediate Result 2: Improved technical capa...
# 129  Intermediate Result 2: Improved technical capa...
# 130  Intermediate Result 2: Improved technical capa...
# 131  Intermediate Result 2: Improved technical capa...
# 132  Intermediate Result 2: Improved technical capa...
# 133  Intermediate Result 2: Improved technical capa...
# 134  Intermediate Result 2: Improved technical capa...
# 135  Intermediate Result 2: Improved technical capa...
# 136  Intermediate Result 2: Improved technical capa...

# %%
disaggregations_df.fillna(0).groupby([
    'period_date',
    'project_title',
    'indicator_id',
    'indicator_name',
    'target_value',
    'target_comment',
    'actual_value',
    'actual_comment',
    'dimension_id',
    'dimension_name',
    'dimension_value',
    'commodity',
    'country'
]).sum().sort_index().unstack('country')
# Out:
#                                                                                                                                                                                                                                                                                                                                                    value  \
# country                                                                                                                                                                                                                                                                                                                                           Malawi
# period_date             project_title                                      indicator_id indicator_name                                     target_value target_comment actual_value actual_comment                                     dimension_id dimension_name           dimension_value commodity
# 2017-01-01 - 2017-12-31 Intermediate Result 2: Improved technical capac... 80759        10. (a) Number of clients (research and advisor... 2100                        1844.00                                                         553          Type of training         7377            management and leadership training                      NaN
#                                                                                                                                                                                                                                                                              7383            training in administrative processes                    NaN
#                                                                                                                                                                                                                                                                              7388            technical research and dissemination training           NaN
#                                                                                                                                                                                                                                        557          Gender RCoL              1308            Male                                                    NaN
#                                                                                                                                                                                                                                                                              1309            Female                                                  NaN
#                                                                            80760        10. (b) Number of staff trained per research ce... 70                          844.00                                                          553          Type of training         7377            management and leadership training                      NaN
#                                                                                                                                                                                                                                                                              7383            training in administrative processes                    NaN
#                                                                                                                                                                                                                                                                              7388            technical research and dissemination training           NaN
#                                                                                                                                                                                                                                        557          Gender RCoL              1308            Male                                                    NaN
#                                                                                                                                                                                                                                                                              1309            Female                                                  NaN
#                                                                            80761        11. Total # of funded scholarship holder that h... 5                           9.00                                                            1659         Type of scholarship      9912            Number of PhD                                           NaN
#                                                                                                                                                                                                                                                                              9913            Number of female PhD                                    NaN
#                                                                                                                                                                                                                                                                              9914            Number of MSc                                           NaN
#                                                                                                                                                                                                                                                                              9915            Number of female MSc                                    NaN
#                                                                                                                                                                                                                                                                              9916            Number of BSc                                           NaN
#                                                                                                                                                                                                                                                                              9917            Number of female BSc                                    NaN
#                                                                            80778        10. (a) Number of clients (research and advisor... 2170                        1066.00                                                         568          Gender RCoL              1355            Male                                                    NaN
#                                                                                                                                                                                                                                                                              1356            Female                                                  NaN
#                                                                            80779        10. (b) Number of staff trained per research ce... 88                          215.00                                                          564          Type of training         7378            management and leadership training                      NaN
#                                                                                                                                                                                                                                                                              7384            training in administrative processes                    NaN
#                                                                                                                                                                                                                                                                              7389            technical research and dissemination training           NaN
#                                                                                                                                                                                                                                        568          Gender RCoL              1355            Male                                                    NaN
#                                                                                                                                                                                                                                                                              1356            Female                                                  NaN
#                                                                            80780        11. Total # of funded scholarship holder that h... 43                          20.00                                                           1660         Type of scholarship      9918            Number of PhD                                           NaN
#                                                                                                                                                                                                                                                                              9919            Number of female PhD                                    NaN
#                                                                                                                                                                                                                                                                              9920            Number of MSc                                           NaN
#                                                                                                                                                                                                                                                                              9921            Number of female MSc                                    NaN
#                                                                                                                                                                                                                                                                              9922            Number of BSc                                           NaN
#                                                                                                                                                                                                                                                                              9923            Number of female BSc                                    NaN
#                                                                            80797        10. (a) Number of clients (research and advisor... 412                         6158.00                                                         575          Type of training         7379            management and leadership training                   993.00
#                                                                                                                                                                                                                                                                              7385            training in administrative processes                 210.00
#                                                                                                                                                                                                                                                                              7390            technical research and dissemination training       4955.00
#                                                                                                                                                                                                                                        579          Gender RCoL              1402            Male                                                3756.00
#                                                                                                                                                                                                                                                                              1403            Female                                              2402.00
#                                                                            80798        10. (b) Number of staff trained per research ce... 47                          2399.00                                                         575          Type of training         7379            management and leadership training                    23.00
#                                                                                                                                                                                                                                                                              7385            training in administrative processes                 460.00
#                                                                                                                                                                                                                                                                              7390            technical research and dissemination training       1916.00
#                                                                                                                                                                                                                                        579          Gender RCoL              1402            Male                                                1391.00
#                                                                                                                                                                                                                                                                              1403            Female                                              1008.00
#                                                                            80799        11. Total # of funded scholarship holder that h... 25                          4.00                                                            1661         Type of scholarship      9924            Number of PhD                                          0.00
#                                                                                                                                                                                                                                                                              9925            Number of female PhD                                   0.00
#                                                                                                                                                                                                                                                                              9926            Number of MSc                                          2.00
#                                                                                                                                                                                                                                                                              9927            Number of female MSc                                   0.00
#                                                                                                                                                                                                                                                                              9928            Number of BSc                                          2.00
#                                                                                                                                                                                                                                                                              9929            Number of female BSc                                   0.00
#                         Intermediate result 1: Improved collaborative t... 80754        5. Number of collaborative research and develop... 36                          21.00                                                           1654         Type of research project 9894            Technology generation                                   NaN
#                                                                                                                                                                                                                                                                              9895            Technology dissemination                                NaN
#                                                                            80755        6. Percentage of collaborative research and dev... 40                          0.0                                                             1654         Type of research project 9894            Technology generation                                   NaN
#                                                                                                                                                                                                                                                                              9895            Technology dissemination                                NaN
#                                                                            80756        7. Total number of technologies generated          20                          14.00                                                           556          IRI 7                    1301            Total improved varieties newly released                 NaN
#                                                                                                                                                                                                                                                                              1302            Maize                                                   NaN
#                                                                                                                                                                                                                                                                              1303            Rice                                                    NaN
#                                                                                                                                                                                                                                                                              1304            Legumes                                                 NaN
#                                                                                                                                                                                                                                                                              1305            Cassava                                                 NaN
#                                                                                                                                                                                                                                                                              1306            improved agronomic, pests /disease, and water  ...      NaN
#                                                                                                                                                                                                                                                                              1307            Improved postharvest storage, processing, labor...      NaN
#                                                                            80757        8. Total number of improved technologies formal... 7                           115.00                                                          554          Type of technology       1291            Number of improved seed varieties                       NaN
#                                                                                                                                                                                                                                                                              1292            Maize                                                   NaN
#                                                                                                                                                                                                                                                                              1293            Rice                                                    NaN
#                                                                                                                                                                                                                                                                              1294            Legumes                                                 NaN
#                                                                                                                                                                                                                                                                              1295            Cassava                                                 NaN
#                                                                                                                                                                                                                                                                              1296            Number of improved agronomic, pest and disease,...      NaN
#                                                                                                                                                                                                                                                                              1297            Number of improved post-harvest storage, labor-...      NaN
#                                                                            80773        5. Number of collaborative research and develop... 32                          32.00                                                           1655         Type of research project 9896            Technology generation                                   NaN
#                                                                                                                                                                                                                                                                              9897            Technology dissemination                                NaN
#                                                                            80774        6. Percentage of collaborative research and dev... 75                          28.0                                                            1655         Type of research project 9896            Technology generation                                   NaN
#                                                                                                                                                                                                                                                                              9897            Technology dissemination                                NaN
#                                                                            80775        7. Total number of technologies generated          47                          11.00                                                           567          IRI 7                    1348            Total improved varieties newly released                 NaN
#                                                                                                                                                                                                                                                                              1349            Maize                                                   NaN
#                                                                                                                                                                                                                                                                              1350            Rice                                                    NaN
#                                                                                                                                                                                                                                                                              1351            Legumes                                                 NaN
#                                                                                                                                                                                                                                                                              1352            Cassava                                                 NaN
#                                                                                                                                                                                                                                                                              1353            improved agronomic, pests /disease, and water  ...      NaN
#                                                                                                                                                                                                                                                                              1354            Improved postharvest storage, processing, labor...      NaN
#                                                                            80776        8. Total number of improved technologies formal... 47                          0.00                                                            565          Type of technology       1338            Number of improved seed varieties                       NaN
#                                                                                                                                                                                                                                                                              1339            Maize                                                   NaN
#                                                                                                                                                                                                                                                                              1340            Rice                                                    NaN
#                                                                                                                                                                                                                                                                              1341            Legumes                                                 NaN
#                                                                                                                                                                                                                                                                              1342            Cassava                                                 NaN
#                                                                                                                                                                                                                                                                              1343            Number of improved agronomic, pest and disease,...      NaN
#                                                                                                                                                                                                                                                                              1344            Number of improved post-harvest storage, labor-...      NaN
#                                                                            80792        5. Number of collaborative research and develop... 30                          22.00                                                           1656         Type of research project 9898            Technology generation                                 13.00
#                                                                                                                                                                                                                                                                              9899            Technology dissemination                               9.00
#                                                                            80793        6. Percentage of collaborative research and dev... 80                          48.0                                                            1656         Type of research project 9898            Technology generation                                 33.00
#                                                                                                                                                                                                                                                                              9899            Technology dissemination                              46.00
#                                                                            80794        7. Total number of technologies generated          43                          21.00                                                           578          IRI 7                    1395            Total improved varieties newly released               16.00
#                                                                                                                                                                                                                                                                              1396            Maize                                                  8.00
#                                                                                                                                                                                                                                                                              1397            Rice                                                   2.00
#                                                                                                                                                                                                                                                                              1398            Legumes                                                6.00
#                                                                                                                                                                                                                                                                              1399            Cassava                                                0.00
#                                                                                                                                                                                                                                                                              1400            improved agronomic, pests /disease, and water  ...     5.00
#                                                                                                                                                                                                                                                                              1401            Improved postharvest storage, processing, labor...     0.00
#                                                                            80795        8. Total number of improved technologies formal... 43                          3.00                                                            576          Type of technology       1385            Number of improved seed varieties                      3.00
#                                                                                                                                                                                                                                                                              1386            Maize                                                  0.00
#                                                                                                                                                                                                                                                                              1387            Rice                                                   2.00
#                                                                                                                                                                                                                                                                              1388            Legumes                                                0.00
#                                                                                                                                                                                                                                                                              1389            Cassava                                                0.00
#                                                                                                                                                                                                                                                                              1390            Number of improved agronomic, pest and disease,...     1.00
#                                                                                                                                                                                                                                                                              1391            Number of improved post-harvest storage, labor-...     0.00
#                         Project Development Objective: Increase the ava... 80750        PDO 1 Number of technologies that are being mad... 27                          115.00       25-09-2019: Improved seed varieties: 51, improv... 554          Type of technology       1291            Number of improved seed varieties                       NaN
#                                                                                                                                                                                                                                                                              1292            Maize                                                   NaN
#                                                                                                                                                                                                                                                                              1293            Rice                                                    NaN
#                                                                                                                                                                                                                                                                              1294            Legumes                                                 NaN
#                                                                                                                                                                                                                                                                              1295            Cassava                                                 NaN
#                                                                                                                                                                                                                                                                              1296            Number of improved agronomic, pest and disease,...      NaN
#                                                                                                                                                                                                                                                                              1297            Number of improved post-harvest storage, labor-...      NaN
#                                                                            80752        PDO 3 Number of technologies generated or promo... 7                           28.00        25-09-2019: Improved seed varieties: 10, improv... 554          Type of technology       1291            Number of improved seed varieties                       NaN
#                                                                                                                                                                                                                                                                              1292            Maize                                                   NaN
#                                                                                                                                                                                                                                                                              1293            Rice                                                    NaN
#                                                                                                                                                                                                                                                                              1294            Legumes                                                 NaN
#                                                                                                                                                                                                                                                                              1295            Cassava                                                 NaN
#                                                                                                                                                                                                                                                                              1296            Number of improved agronomic, pest and disease,...      NaN
#                                                                                                                                                                                                                                                                              1297            Number of improved post-harvest storage, labor-...      NaN
#                                                                            80769        PDO 1 Number of technologies that are being mad... 88                          91.00        25-09-2019: Improved seed varieties: 43, Improv... 565          Type of technology       1338            Number of improved seed varieties                       NaN
#                                                                                                                                                                                                                                                                              1339            Maize                                                   NaN
#                                                                                                                                                                                                                                                                              1340            Rice                                                    NaN
#                                                                                                                                                                                                                                                                              1341            Legumes                                                 NaN
#                                                                                                                                                                                                                                                                              1342            Cassava                                                 NaN
#                                                                                                                                                                                                                                                                              1343            Number of improved agronomic, pest and disease,...      NaN
#                                                                                                                                                                                                                                                                              1344            Number of improved post-harvest storage, labor-...      NaN
#                                                                            80771        PDO 3 Number of technologies generated or promo... 14                          5.00         25-09-2019: Improved seed varieties: 5             565          Type of technology       1338            Number of improved seed varieties                       NaN
#                                                                                                                                                                                                                                                                              1343            Number of improved agronomic, pest and disease,...      NaN
#                                                                                                                                                                                                                                                                              1344            Number of improved post-harvest storage, labor-...      NaN
#                                                                            80788        PDO 1 Number of technologies that are being mad... 76                          72.00        25-09-2019: Improved seed varieties: 55, improv... 576          Type of technology       1385            Number of improved seed varieties                     55.00
#                                                                                                                                                                                                                                                                              1386            Maize                                                 12.00
#                                                                                                                                                                                                                                                                              1387            Rice                                                   9.00
#                                                                                                                                                                                                                                                                              1388            Legumes                                               34.00
#                                                                                                                                                                                                                                                                              1389            Cassava                                                0.00
#                                                                                                                                                                                                                                                                              1390            Number of improved agronomic, pest and disease,...    15.00
#                                                                                                                                                                                                                                                                              1391            Number of improved post-harvest storage, labor-...     2.00
#                                                                            80790        PDO 3 Number of technologies generated or promo... 15                          18.00        25-09-2019: Improved seed varieties: 11, improv... 576          Type of technology       1385            Number of improved seed varieties                     11.00
#                                                                                                                                                                                                                                                                              1386            Maize                                                  4.00
#                                                                                                                                                                                                                                                                              1387            Rice                                                   3.00
#                                                                                                                                                                                                                                                                              1388            Legumes                                                4.00
# ...
#                                                                                                                                                                                                                                                                              1401            Improved postharvest storage, processing, labor...     NaN
#                                                                            80795        8. Total number of improved technologies formal... 43                          3.00                                                            576          Type of technology       1385            Number of improved seed varieties                      NaN
#                                                                                                                                                                                                                                                                              1386            Maize                                                  NaN
#                                                                                                                                                                                                                                                                              1387            Rice                                                   NaN
#                                                                                                                                                                                                                                                                              1388            Legumes                                                NaN
#                                                                                                                                                                                                                                                                              1389            Cassava                                                NaN
#                                                                                                                                                                                                                                                                              1390            Number of improved agronomic, pest and disease,...     NaN
#                                                                                                                                                                                                                                                                              1391            Number of improved post-harvest storage, labor-...     NaN
#                         Project Development Objective: Increase the ava... 80750        PDO 1 Number of technologies that are being mad... 27                          115.00       25-09-2019: Improved seed varieties: 51, improv... 554          Type of technology       1291            Number of improved seed varieties                      NaN
#                                                                                                                                                                                                                                                                              1292            Maize                                                  NaN
#                                                                                                                                                                                                                                                                              1293            Rice                                                   NaN
#                                                                                                                                                                                                                                                                              1294            Legumes                                                NaN
#                                                                                                                                                                                                                                                                              1295            Cassava                                                NaN
#                                                                                                                                                                                                                                                                              1296            Number of improved agronomic, pest and disease,...     NaN
#                                                                                                                                                                                                                                                                              1297            Number of improved post-harvest storage, labor-...     NaN
#                                                                            80752        PDO 3 Number of technologies generated or promo... 7                           28.00        25-09-2019: Improved seed varieties: 10, improv... 554          Type of technology       1291            Number of improved seed varieties                      NaN
#                                                                                                                                                                                                                                                                              1292            Maize                                                  NaN
#                                                                                                                                                                                                                                                                              1293            Rice                                                   NaN
#                                                                                                                                                                                                                                                                              1294            Legumes                                                NaN
#                                                                                                                                                                                                                                                                              1295            Cassava                                                NaN
#                                                                                                                                                                                                                                                                              1296            Number of improved agronomic, pest and disease,...     NaN
#                                                                                                                                                                                                                                                                              1297            Number of improved post-harvest storage, labor-...     NaN
#                                                                            80769        PDO 1 Number of technologies that are being mad... 88                          91.00        25-09-2019: Improved seed varieties: 43, Improv... 565          Type of technology       1338            Number of improved seed varieties                    43.00
#                                                                                                                                                                                                                                                                              1339            Maize                                                 9.00
#                                                                                                                                                                                                                                                                              1340            Rice                                                  4.00
#                                                                                                                                                                                                                                                                              1341            Legumes                                              22.00
#                                                                                                                                                                                                                                                                              1342            Cassava                                               7.00
#                                                                                                                                                                                                                                                                              1343            Number of improved agronomic, pest and disease,...   15.00
#                                                                                                                                                                                                                                                                              1344            Number of improved post-harvest storage, labor-...   33.00
#                                                                            80771        PDO 3 Number of technologies generated or promo... 14                          5.00         25-09-2019: Improved seed varieties: 5             565          Type of technology       1338            Number of improved seed varieties                     5.00
#                                                                                                                                                                                                                                                                              1343            Number of improved agronomic, pest and disease,...    0.00
#                                                                                                                                                                                                                                                                              1344            Number of improved post-harvest storage, labor-...    0.00
#                                                                            80788        PDO 1 Number of technologies that are being mad... 76                          72.00        25-09-2019: Improved seed varieties: 55, improv... 576          Type of technology       1385            Number of improved seed varieties                      NaN
#                                                                                                                                                                                                                                                                              1386            Maize                                                  NaN
#                                                                                                                                                                                                                                                                              1387            Rice                                                   NaN
#                                                                                                                                                                                                                                                                              1388            Legumes                                                NaN
#                                                                                                                                                                                                                                                                              1389            Cassava                                                NaN
#                                                                                                                                                                                                                                                                              1390            Number of improved agronomic, pest and disease,...     NaN
#                                                                                                                                                                                                                                                                              1391            Number of improved post-harvest storage, labor-...     NaN
#                                                                            80790        PDO 3 Number of technologies generated or promo... 15                          18.00        25-09-2019: Improved seed varieties: 11, improv... 576          Type of technology       1385            Number of improved seed varieties                      NaN
#                                                                                                                                                                                                                                                                              1386            Maize                                                  NaN
#                                                                                                                                                                                                                                                                              1387            Rice                                                   NaN
#                                                                                                                                                                                                                                                                              1388            Legumes                                                NaN
#                                                                                                                                                                                                                                                                              1389            Cassava                                                NaN
#                                                                                                                                                                                                                                                                              1390            Number of improved agronomic, pest and disease,...     NaN
#                                                                                                                                                                                                                                                                              1391            Number of improved post-harvest storage, labor-...     NaN

# %% [markdown]
# ### Merge Dimension Values & Disaggregations

# %%
dimension_values = pd.DataFrame(dimension_values).groupby(['id']).first().reset_index()

# %% [markdown]
# ## DN

# %%
dimension_names = pd.DataFrame(dimension_names).groupby(['id']).first()
dimension_names = dimension_names.drop(columns=['values','project','parent_dimension_name','result','indicator']).reset_index()
dimension_names = dimension_names.rename(columns={'id':'dimension_id','name':'dimension_name'})
dimension_values = dimension_values.merge(dimension_names,left_on='name',right_on='dimension_id',how='outer')

# %%
def fill_country(x):
    country = x['country']
    if country.lower() not in  ['zambia','malawi','mozambique']:
        country = x['project'].split(' ')[1]
    return country

# %% [markdown]
# ### Disaggregation Values

# %%
remove_columns = [
    'created_at',
    'last_modified_at',
    'numerator',
    'denominator',
    'narrative',
    'dimension_value',
    'incomplete_data',
    'update',
    'dimension_name_disaggregation',
    'dimension_id'
]
rename_columns = {
    'value_dimension_values': 'disaggregation_name',
    'value_disaggregation': 'disaggregation_value',
    'dimension_name_dimension_values':'dimension_name'
}
fill_values = {
    'disaggregation_value':0,
    'incomplete_data':True
}
column_order = ['parent_dimension_value',
                'parent_period',
                'result',
                'country',
                'dimension_'
                'dimension_name',
                'disaggregation_name',
                'id',
                'commodity',
                'has_country',
                'has_commodity',
                'incomplete_data',
                'disaggregation_value',
                'period',
                'project_title',
                'project',
                'indicator',
                'indicator_id'
]
disaggregation_value = ['disaggregation_value']
disaggregations_merged = pd.DataFrame(disaggregations).drop(columns=['id']).merge(
    dimension_values, 
    how='outer', 
    left_on='dimension_value', 
    right_on='id', 
    suffixes=('_disaggregation','_dimension_values'))
disaggregations_merged = disaggregations_merged.drop(columns=remove_columns)
disaggregations_merged = disaggregations_merged.rename(columns=rename_columns)
disaggregations_merged = disaggregations_merged.fillna(value=fill_values)
disaggregations_merged['value'] = disaggregations_merged['disaggregation_value'].apply(lambda x:int(float(x)))
disaggregations_merged = disaggregations_merged.drop(columns=['disaggregation_value'])
disaggregations_merged = disaggregations_merged.dropna(subset=['parent_period'])
disaggregations_merged['parent_period'] = disaggregations_merged['parent_period'].astype(int)
disaggregations_merged['period'] = disaggregations_merged['period'].apply(lambda x: int(float(x)))
disaggregations_merged['indicator_id'] = disaggregations_merged['indicator_id'].apply(lambda x: int(float(x)))
disaggregations_merged['type'] = 'Cumulative Actual Values'
disaggregations_merged['country'] = disaggregations_merged.apply(fill_country , axis = 1)

# %% [markdown]
# #### Country R&D

# %%
if PROJECT_ID == '7282':
    disaggregations_merged['project'] = 'APPSA Zambia'
    disaggregations_merged['commodity'] = disaggregations_merged['commodity'].apply(lambda x: x.replace('-',' ').title())
    disaggregations_merged['commodity'] = disaggregations_merged['commodity'].apply(lambda x: "Country Project" if x == "" else x)
    disaggregations_merged['country'] = disaggregations_merged.apply(fill_country, axis=1)
    disaggregations_merged = disaggregations_merged.drop(columns=['project'])

# %% [markdown]
# ### Target Values

# %%
targets = pd.DataFrame(disaggregation_targets).fillna(0).drop(columns=['id']).merge(
    dimension_values, 
    how='outer', 
    left_on='dimension_value', 
    right_on='id', 
    suffixes=('_target','_dimension_values'))
targets = targets.dropna(subset=['parent_period','id'])
targets['has_commodity'] = False
targets['has_country'] = True
fill_values = {
    'value_target':0
}
targets  = targets.fillna(value=fill_values)
targets['value'] =  targets['value_target'].apply(lambda x:int(float(x)))
targets = targets.drop(columns=['value_target'])
integer_list = ['id','name','parent_dimension_value','result','parent_period','dimension_value','dimension_id','period']
targets[integer_list] = targets[integer_list].astype(int)
rename_columns = {'value_dimension_values': 'disaggregation_name'}
unavailable_columns = ['disaggregation_value', 'incomplete_data','dimension_value','dimension_dimension_name']
column_order = [x for x in column_order if x not in unavailable_columns]
column_order = column_order + ['value','dimension_name','dimension_id']

# %%
targets = targets.rename(columns=rename_columns)[column_order]
targets['indicator_id'] = targets['indicator_id'].apply(lambda x: int(float(x)))
targets['type'] = 'Y4 RCoLs Targets'
if PROJECT_ID == '7282':
    targets['project'] = 'APPSA Zambia'
    targets['commodity'] = targets['commodity'].apply(lambda x: x.replace('-',' ').title())
    targets['commodity'] = targets['commodity'].apply(lambda x: "Country Project" if x == "" else x)
    targets['country'] = targets.apply(fill_country, axis=1)
    targets = targets.drop(columns=['project'])
else:
    targets['country'] = ''
    targets['country'] = targets.apply(fill_country, axis = 1)

# %%
disaggregations_merged = disaggregations_merged.rename(columns={'name':'dimension_id'})

# %%
order_columns = ['id','result','indicator_id','dimension_id','project_title','indicator','dimension_name','commodity','period','country','type','value']

# %%
targets = targets[order_columns]
disaggregations_merged = disaggregations_merged[order_columns]

# %% [markdown]
# ## Ajax

# %% [markdown]
# ### Redefining Period

# %%
periods_short = pd.DataFrame(periods)
periods_short = periods_short[['id','is_yearly','period_start','period_end']]
periods_short['period_date'] = periods_short['period_start'] + ' - ' + periods_short['period_end']

# %% [markdown]
# ### Defining Values

# %%
ajax = pd.concat([disaggregations_merged,targets],sort=False)
ajax = ajax.sort_values(by=['result','indicator_id','dimension_id','id'])
ajax = ajax.merge(periods_short,how='inner',left_on='period',right_on='id',suffixes=('_data','_period')).sort_values(['id_data','indicator_id','dimension_name'])
remove_columns = [
    'period_end',
    'period_start',
    'id_period',
    'period',
    'is_yearly'
]
ajax = ajax[pd.notnull(ajax['period_end'])]

# %%
ajax['cumulative'] = ajax['period_end'].apply(lambda x: True if x.split('-')[1] == '12' else False)
ajax = ajax[ajax['cumulative'] == True].drop(columns=['cumulative'])
ajax = ajax.drop(columns=remove_columns)
if FILTER_DATE_TYPE == 'yearly':
    ajax['year'] = ajax['period_date'].apply(lambda x: x.split(' - ')[0].split('-')[0])
    ajax = ajax[ajax['year'] == FILTER_DATE].drop(columns=['year','period_date'])
else:
    pass
    #ajax = ajax[ajax['period_date'] == FILTER_DATE].drop(columns=['period_date'])

# %%
order_columns = ['result','project_title','indicator_id','indicator','dimension_id','dimension_name','commodity','type','country','value','id_data']
ajax = ajax[order_columns]
ajax_group = ['result','project_title','indicator_id','indicator','dimension_id','dimension_name','id_data','commodity','country','type']
ajax_sort = ['result','indicator_id','dimension_id','id_data']
ajax = ajax.groupby(ajax_group).sum()
ajax = ajax.unstack('type').unstack('country').sort_values(ajax_sort)
ajax = ajax.groupby(level=[1,3,5,7],sort=False).sum().astype(int)
ajax = pd.DataFrame(ajax['value'].to_records())
ajax = ajax.rename(columns={
    "('Cumulative Actual Values', 'Malawi')": "CA-MW",
    "('Cumulative Actual Values', 'Mozambique')": "CA-MZ",
    "('Cumulative Actual Values', 'Zambia')": "CA-ZA",
    "('Y4 RCoLs Targets', 'Malawi')":"TG-MW",
    "('Y4 RCoLs Targets', 'Mozambique')":"TG-MZ",
    "('Y4 RCoLs Targets', 'Zambia')":"TG-ZA"
})
ajax['TG-TTL'] = ajax['TG-MW'] + ajax['TG-MZ'] + ajax['TG-ZA']
ajax['CA-TTL'] = ajax['CA-MW'] + ajax['CA-MZ'] + ajax['CA-ZA']

# %%
ajax
# Out:
#                                          project_title  \
# 0    Project Development Objective: Increase the av...
# 1    Project Development Objective: Increase the av...
# 2    Project Development Objective: Increase the av...
# 3         Promising technologies identified and tested
# 4         Promising technologies identified and tested
# 5         Promising technologies identified and tested
# 6         Promising technologies identified and tested
# 7         Promising technologies identified and tested
# 8         Promising technologies identified and tested
# 9         Promising technologies identified and tested
# 10        Promising technologies identified and tested
# 11        Promising technologies identified and tested
# 12        Promising technologies identified and tested
# 13        Promising technologies identified and tested
# 14   New dissemination packages and tools designed,...
# 15   New dissemination packages and tools designed,...
# 16   New dissemination packages and tools designed,...
# 17   New dissemination packages and tools designed,...
# 18   New dissemination packages and tools designed,...
# 19   New dissemination packages and tools designed,...
# 20   New dissemination packages and tools designed,...
# 21   New dissemination packages and tools designed,...
# 22   New dissemination packages and tools designed,...
# 23   New dissemination packages and tools designed,...
# 24   New dissemination packages and tools designed,...
# 25   New dissemination packages and tools designed,...
# 26   New dissemination packages and tools designed,...
# 27   New dissemination packages and tools designed,...
# 28   New dissemination packages and tools designed,...
# 29   New dissemination packages and tools designed,...
# 30   New dissemination packages and tools designed,...
# 31   New dissemination packages and tools designed,...
# 32   New dissemination packages and tools designed,...
# 33   New dissemination packages and tools designed,...
# 34   New dissemination packages and tools designed,...
# 35   New dissemination packages and tools designed,...
# 36   New dissemination packages and tools designed,...
# 37   New dissemination packages and tools designed,...
# 38   Project Development Objective: Increase the av...
# 39        Promising technologies identified and tested
# 40        Promising technologies identified and tested
# 41        Promising technologies identified and tested
# 42        Promising technologies identified and tested
# 43        Promising technologies identified and tested
# 44        Promising technologies identified and tested
# 45        Promising technologies identified and tested
# 46        Promising technologies identified and tested
# 47        Promising technologies identified and tested
# 48   Project Development Objective: Increase the av...
# 49        Promising technologies identified and tested
# 50        Promising technologies identified and tested
# 51        Promising technologies identified and tested
# 52        Promising technologies identified and tested
# 53        Promising technologies identified and tested
# 54        Promising technologies identified and tested
# 55        Promising technologies identified and tested
# 56        Promising technologies identified and tested
# 57        Promising technologies identified and tested
# 58        Promising technologies identified and tested
# 59        Promising technologies identified and tested
# 60        Promising technologies identified and tested
# 61        Promising technologies identified and tested
# 62        Promising technologies identified and tested
# 63        Promising technologies identified and tested
# 64        Promising technologies identified and tested
# 65        Promising technologies identified and tested
# 66        Promising technologies identified and tested
# 67        Promising technologies identified and tested
# 68        Promising technologies identified and tested
# 69        Promising technologies identified and tested
# 70        Promising technologies identified and tested
# 71        Promising technologies identified and tested
# 72        Promising technologies identified and tested
# 73        Promising technologies identified and tested
# 74        Promising technologies identified and tested
# 75        Promising technologies identified and tested
# 76        Promising technologies identified and tested
# 77        Promising technologies identified and tested
# 78        Promising technologies identified and tested
# 79        Promising technologies identified and tested
# 80        Promising technologies identified and tested
# 81        Promising technologies identified and tested
# 82        Promising technologies identified and tested
# 83        Promising technologies identified and tested
# 84        Promising technologies identified and tested
# 85        Promising technologies identified and tested
# 86        Promising technologies identified and tested
# 87        Promising technologies identified and tested
# 88        Promising technologies identified and tested
# 89        Promising technologies identified and tested
# 90        Promising technologies identified and tested
# 91        Promising technologies identified and tested
# 92        Promising technologies identified and tested
# 93        Promising technologies identified and tested
# 94        Promising technologies identified and tested
# 95        Promising technologies identified and tested
# 96        Promising technologies identified and tested
# 97        Promising technologies identified and tested
# 98        Promising technologies identified and tested
# 99   Project Development Objective: Increase the av...
# 100  Project Development Objective: Increase the av...
# 101  Project Development Objective: Increase the av...
# 102  Project Development Objective: Increase the av...
# 103  Project Development Objective: Increase the av...
# 104  Project Development Objective: Increase the av...
# 105  Project Development Objective: Increase the av...
# 106       Promising technologies identified and tested
# 107       Promising technologies identified and tested
# 108       Promising technologies identified and tested
# 109       Promising technologies identified and tested
# 110       Promising technologies identified and tested
# 111       Promising technologies identified and tested
# 112  New dissemination packages and tools designed,...
# 113  New dissemination packages and tools designed,...
# 114       Promising technologies identified and tested
# 115       Promising technologies identified and tested
# 116       Promising technologies identified and tested
# 117       Promising technologies identified and tested
# 118  New dissemination packages and tools designed,...
# 119  New dissemination packages and tools designed,...
# 120  New dissemination packages and tools designed,...
# 121  Project Development Objective: Increase the av...
# 122  Project Development Objective: Increase the av...
# 123       Promising technologies identified and tested
# 124       Promising technologies identified and tested
# 125       Promising technologies identified and tested
# 126       Promising technologies identified and tested
# 127       Promising technologies identified and tested
# 128       Promising technologies identified and tested
# 129       Promising technologies identified and tested
# 130  New dissemination packages and tools designed,...
# 131  New dissemination packages and tools designed,...
# 132  New dissemination packages and tools designed,...
# 133  New dissemination packages and tools designed,...
# 134  New dissemination packages and tools designed,...
# 135       Promising technologies identified and tested
# 136       Promising technologies identified and tested
# 137       Promising technologies identified and tested
# 138       Promising technologies identified and tested
# 139       Promising technologies identified and tested
# 140  New dissemination packages and tools designed,...
# 141       Promising technologies identified and tested
# 142  New dissemination packages and tools designed,...
# 143  New dissemination packages and tools designed,...
# 144  New dissemination packages and tools designed,...
# 145  New dissemination packages and tools designed,...
# 146  New dissemination packages and tools designed,...
# 147  New dissemination packages and tools designed,...
# 148  New dissemination packages and tools designed,...
# 149       Promising technologies identified and tested
# 150                                  Promising results
# 151                                  Promising results
# 152                                  Promising results
# 153                                  Promising results
# 154                                  Promising results
# 155                                  Promising results
# 156                                  Promising results
# 157                                  Promising results
# 158                                  Promising results
# 159                                  Promising results
# 160                                  Promising results
# 161                                  Promising results
# 162                                  Promising results
# 163                                  Promising results
# 164                                  Promising results
# 165                                  Promising results
# 166                                  Promising results
# 167                                  Promising results
# 168                                  Promising results
# 169                                  Promising results
# 170                                  Promising results
# 171                                  Promising results
# 172                                  Promising results
# 173                                  Promising results
# 174                                  Promising results
# 175                                  Promising results
# 176                                  Promising results
# 177                                  Promising results
# 178                                  Promising results
# 179                                  Promising results
# 180                                  Promising results
# 181                                  Promising results
# 182                                  Promising results
# 183                                  Promising results
# 184                                  Promising results
# 185                                  Promising results
# 186                                  Promising results
# 187                                  Promising results
# 188                                  Promising results
# 189                                  Promising results
# 190                                  Promising results
# 191                                  Promising results
# 192                                  Promising results
# 193                                  Promising results
# 194                                  Promising results
# 195                                  Promising results
# 196                                  Promising results
# 197                                  Promising results
# 198       Promising technologies identified and tested
# 199       Promising technologies identified and tested
# 200       Promising technologies identified and tested
# 201       Promising technologies identified and tested
# 202       Promising technologies identified and tested
# 203       Promising technologies identified and tested
# 204       Promising technologies identified and tested
# 205       Promising technologies identified and tested
# 206       Promising technologies identified and tested
# 207       Promising technologies identified and tested
# 208       Promising technologies identified and tested
# 209       Promising technologies identified and tested
# 210       Promising technologies identified and tested
# 211       Promising technologies identified and tested
# 212       Promising technologies identified and tested
# 213       Promising technologies identified and tested
# 214       Promising technologies identified and tested
# 215  New dissemination packages and tools designed,...
# 216  New dissemination packages and tools designed,...
# 217  New dissemination packages and tools designed,...
# 218  New dissemination packages and tools designed,...
# 219  New dissemination packages and tools designed,...
# 220  New dissemination packages and tools designed,...
# 221  New dissemination packages and tools designed,...
# 222  New dissemination packages and tools designed,...
# 223  New dissemination packages and tools designed,...
# 224  New dissemination packages and tools designed,...
# 225  New dissemination packages and tools designed,...
#
#                                              indicator  \
# 0    PDO 1 Number of technologies that are being ma...
# 1    PDO 4 Number of direct project beneficiaries (...
# 2    PDO 4 Number of direct project beneficiaries (...
# 3    Number of improved agronomic practices develop...
# 4    Number of improved agronomic practices develop...
# 5    Number of improved agronomic practices develop...
# 6    Number of improved agronomic practices develop...
# 7    Number of improved pest management practices d...
# 8    Number of improved pest management practices d...
# 9    Number of improved disease management practice...
# 10   Number of improved disease management practice...
# 11   Number of improved disease management practice...
# 12   Number of improved water management practices ...
# 13   Number of labour saving technologies developed...
# 14                   Number of trial sites established
# 15                   Number of trial sites established
# 16                Number of demonstrations established
# 17                Number of demonstrations established
# 18   Number of farmers participating in on-farm par...
# 19   Number of farmers participating in on-farm par...
# 20                      Number of field days conducted
# 21   Number of farmers participating in field days ...
# 22   Number of farmers participating in field days ...
# 23      Number of fairs held to show case technologies
# 24      Number of fairs held to show case technologies
# 25      Number of fairs held to show case technologies
# 26              Number of participants attending fairs
# 27              Number of participants attending fairs
# 28              Number of participants attending fairs
# 29               Number of extension personnel trained
# 30               Number of extension personnel trained
# 31               Number of extension personnel trained
# 32                      Number of lead farmers trained
# 33                      Number of lead farmers trained
# 34                   Number of IEC materials published
# 35   Number of sms messages dispatched to lead farm...
# 36             Number of sms responses by lead farmers
# 37       Number of TV documentaries produced and aired
# 38   PDO 1 Number of technologies that are being ma...
# 39   Number of improved agronomic practices develop...
# 40   Number of improved agronomic practices develop...
# 41   Number of improved agronomic practices develop...
# 42   Number of improved agronomic practices develop...
# 43   Number of improved agronomic practices develop...
# 44   Number of improved agronomic practices develop...
# 45   Number of improved agronomic practices develop...
# 46   Number of improved agronomic practices develop...
# 47   Number of improved agronomic practices develop...
# 48   PDO 1 Number of technologies that are being ma...
# 49   Number of post-harvest technologies identified...
# 50   Number of post-harvest technologies identified...
# 51   Number of post-harvest technologies identified...
# 52   Number of post-harvest technologies identified...
# 53   Number of accessions characterized on molecula...
# 54   Number of accessions characterized on molecula...
# 55   Number of accessions characterized on molecula...
# 56   Number of accessions characterized on molecula...
# 57   Number of accessions properly characterised an...
# 58   Number of accessions properly characterised an...
# 59   Number of accessions properly characterised an...
# 60   Number of accessions properly characterised an...
# 61   Number of lines deposited with the national ge...
# 62   Number of lines deposited with the national ge...
# 63   Number of lines deposited with the national ge...
# 64   Number of lines deposited with the national ge...
# 65   Number of lines duplicated with the SADC Plant...
# 66   Number of lines duplicated with the SADC Plant...
# 67   Number of lines duplicated with the SADC Plant...
# 68   Number of lines duplicated with the SADC Plant...
# 69         Number of improved maize varieties released
# 70         Number of improved maize varieties released
# 71         Number of improved maize varieties released
# 72          Number of improved rice varieties released
# 73          Number of improved rice varieties released
# 74          Number of improved rice varieties released
# 75        Number of improved legume varieties released
# 76        Number of improved legume varieties released
# 77        Number of improved legume varieties released
# 78        Number of improved legume varieties released
# 79        Number of improved legume varieties released
# 80        Number of improved legume varieties released
# 81   Number of improved agronomic practices develop...
# 82   Number of improved agronomic practices develop...
# 83   Number of improved agronomic practices develop...
# 84   Number of improved agronomic practices develop...
# 85   Number of improved agronomic practices develop...
# 86   Number of improved agronomic practices develop...
# 87   Number of improved disease management practice...
# 88   Number of improved disease management practice...
# 89   Number of improved disease management practice...
# 90   Number of improved postharvest storage technol...
# 91   Number of improved postharvest storage technol...
# 92   Number of improved postharvest storage technol...
# 93   Number of improved processing technologies dev...
# 94   Number of improved processing technologies dev...
# 95   Number of improved processing technologies dev...
# 96   Number of labour saving technologies developed...
# 97   Number of labour saving technologies developed...
# 98   Number of labour saving technologies developed...
# 99   PDO 1 Number of technologies that are being ma...
# 100  PDO 1 Number of technologies that are being ma...
# 101  PDO 1 Number of technologies that are being ma...
# 102  PDO 1 Number of technologies that are being ma...
# 103  PDO 1 Number of technologies that are being ma...
# 104  PDO 1 Number of technologies that are being ma...
# 105  PDO 1 Number of technologies that are being ma...
# 106  Number of improved pest management practices d...
# 107  Number of improved pest management practices d...
# 108  Number of improved pest management practices d...
# 109  Number of improved water management practices ...
# 110  Number of improved water management practices ...
# 111      Number of improved cassava varieties released
# 112                  Number of trial sites established
# 113                  Number of trial sites established
# 114  Number of germplasm (inbreds/hybrids/OPVs, gen...
# 115  Number of germplasm (inbreds/hybrids/OPVs, gen...
# 116  Number of germplasm (inbreds/hybrids/OPVs, gen...
# 117  Number of germplasm (inbreds/hybrids/OPVs, gen...
# 118            Number of sms responses by lead farmers
# 119            Number of sms responses by lead farmers
# 120            Number of sms responses by lead farmers
# 121  PDO 1 Number of technologies that are being ma...
# 122  PDO 1 Number of technologies that are being ma...
# 123  Number of improved disease management practice...
# 124  Number of improved water management practices ...
# 125  Number of improved water management practices ...
# 126  Number of improved water management practices ...
# 127  Number of improved water management practices ...
# 128  Number of improved water management practices ...
# 129  Number of improved water management practices ...
# 130                  Number of trial sites established
# 131                     Number of field days conducted
# 132              Number of extension personnel trained
# 133              Number of extension personnel trained
# 134              Number of extension personnel trained
# 135  Number of improved pest management practices d...
# 136  Number of improved postharvest storage technol...
# 137  Number of improved postharvest storage technol...
# 138  Number of improved processing technologies dev...
# 139  Number of accessions characterized on a phenot...
# 140               Number of demonstrations established
# 141  Number of accessions characterized on a phenot...
# 142                     Number of field days conducted
# 143                     Number of field days conducted
# 144                     Number of field days conducted
# 145     Number of fairs held to show case technologies
# 146     Number of fairs held to show case technologies
# 147  Number of farmers participating in on-farm par...
# 148  Number of farmers participating in on-farm par...
# 149  Number of accessions characterized on a phenot...
# 150  Number of germplasm (inbreds/hybrids/OPVs, gen...
# 151  Number of germplasm (inbreds/hybrids/OPVs, gen...
# 152  Number of germplasm (inbreds/hybrids/OPVs, gen...
# 153  Number of germplasm (inbreds/hybrids/OPVs, gen...
# 154  Number of accessions characterized on molecula...
# 155  Number of accessions characterized on molecula...
# 156  Number of accessions characterized on molecula...
# 157  Number of accessions characterized on molecula...
# 158  Number of lines duplicated with the SADC Plant...
# 159  Number of lines duplicated with the SADC Plant...
# 160  Number of lines duplicated with the SADC Plant...
# 161  Number of lines duplicated with the SADC Plant...
# 162         Number of improved rice varieties released
# 163         Number of improved rice varieties released
# 164         Number of improved rice varieties released
# 165  Number of improved water management practices ...
# 166  Number of improved water management practices ...
# 167  Number of improved water management practices ...
# 168  Number of improved water management practices ...
# 169  Number of improved water management practices ...
# 170  Number of improved water management practices ...
# 171  Number of improved water management practices ...
# 172  Number of improved water management practices ...
# 173  Number of improved postharvest storage technol...
# 174  Number of improved postharvest storage technol...
# 175  Number of improved postharvest storage technol...
# 176  Number of improved postharvest storage technol...
# 177  Number of improved postharvest storage technol...
# 178  Number of improved postharvest storage technol...
# 179  Number of improved postharvest storage technol...
# 180  Number of improved postharvest storage technol...
# 181  Number of improved processing technologies dev...
# 182  Number of improved processing technologies dev...
# 183  Number of improved processing technologies dev...
# 184  Number of improved processing technologies dev...
# 185  Number of improved processing technologies dev...
# 186  Number of improved processing technologies dev...
# 187  Number of improved processing technologies dev...
# 188  Number of improved processing technologies dev...
# 189  Number of labour saving technologies developed...
# 190  Number of labour saving technologies developed...
# 191  Number of labour saving technologies developed...
# 192  Number of labour saving technologies developed...
# 193  Number of labour saving technologies developed...
# 194  Number of labour saving technologies developed...
# 195  Number of labour saving technologies developed...
# 196  Number of labour saving technologies developed...
# 197      Number of improved cassava varieties released
# 198  Number of improved pest management practices d...
# 199  Number of accessions characterized on a phenot...
# 200  Number of improved processing technologies dev...
# 201  Number of improved processing technologies dev...
# 202  Number of improved processing technologies dev...
# 203  Number of improved processing technologies dev...
# 204  Number of improved processing technologies dev...
# 205  Number of labour saving technologies developed...
# 206  Number of labour saving technologies developed...
# 207  Number of labour saving technologies developed...
# 208  Number of labour saving technologies developed...
# 209  Number of labour saving technologies developed...
# 210  Number of improved postharvest storage technol...
# 211  Number of improved postharvest storage technol...
# 212  Number of improved postharvest storage technol...
# 213  Number of improved postharvest storage technol...
# 214  Number of improved postharvest storage technol...
# 215                  Number of trial sites established
# 216                  Number of trial sites established
# 217                  Number of trial sites established
# 218                  Number of trial sites established
# 219             Number of participants attending fairs
# 220                     Number of lead farmers trained
# 221  Number of farmers participating in on-farm par...
# 222  Number of farmers participating in on-farm par...
# 223  Number of farmers participating in on-farm par...
# 224  Number of farmers participating in on-farm par...
# 225               Number of demonstrations established
#
#                                         dimension_name  \
# 0                    improved grain storage structures
# 1                                                  410
# 2                                                  410
# 3                                   Agronomic practice
# 4                                   Agronomic practice
# 5                                   Agronomic practice
# 6                                   Agronomic practice
# 7                        Pest and management practices
# 8                        Pest and management practices
# 9                               Disease and management
# 10                              Disease and management
# 11                              Disease and management
# 12                                            Practice
# 13                                                Type
# 14                                 Trial Sites Country
# 15                                 Trial Sites Country
# 16                                 Trial Sites Country
# 17                                 Trial Sites Country
# 18                                              Gender
# 19                                              Gender
# 20                                                 289
# 21                                                 410
# 22                                                 410
# 23                                        Type of fair
# 24                                                 289
# 25                                                 289
# 26                                                 410
# 27                                                 410
# 28                                        Type of fair
# 29                                                 410
# 30                                                 410
# 31                                        subject area
# 32                                                 410
# 33                                                 410
# 34                                             country
# 35                                             country
# 36                                                 289
# 37                                             country
# 38             Technology Generation and Dissemination
# 39                                                Type
# 40                                                Type
# 41                                                Type
# 42                                                Type
# 43                                                Type
# 44                                                Type
# 45                                                Type
# 46                                                Type
# 47                                                Type
# 48                       Number of technologies tested
# 49                                                 289
# 50                                                 289
# 51                                                 289
# 52                                                 289
# 53                                                 289
# 54                                                 289
# 55                                                 289
# 56                                                 289
# 57                                                 289
# 58                                                 289
# 59                                                 289
# 60                                                 289
# 61                                                 289
# 62                                                 289
# 63                                                 289
# 64                                                 289
# 65                                                 289
# 66                                                 289
# 67                                                 289
# 68                                                 289
# 69                                             country
# 70                                          maize type
# 71                                          maize type
# 72                                             country
# 73                                       Type of Maize
# 74                                       Type of Maize
# 75                                             country
# 76                                           Crop type
# 77                                           Crop type
# 78                                           Crop type
# 79                                           Crop type
# 80                                           Crop type
# 81                         Type of agronomic practices
# 82                         Type of agronomic practices
# 83                         Type of agronomic practices
# 84                         Type of agronomic practices
# 85                         Type of agronomic practices
# 86                         Type of agronomic practices
# 87                   Type of pest management practices
# 88                   Type of pest management practices
# 89                   Type of pest management practices
# 90                             Commodity and crop type
# 91                             Commodity and crop type
# 92                             Commodity and crop type
# 93                             Commodity and crop type
# 94                             Commodity and crop type
# 95                             Commodity and crop type
# 96                             Commodity and crop type
# 97                             Commodity and crop type
# 98                             Commodity and crop type
# 99                                  Type of technology
# 100                                 Type of technology
# 101                                 Type of technology
# 102                                 Type of technology
# 103                                 Type of technology
# 104                                 Type of technology
# 105                                 Type of technology
# 106                  Type of pest management practices
# 107                  Type of pest management practices
# 108                  Type of pest management practices
# 109                            Commodity and crop type
# 110                            Commodity and crop type
# 111                                            country
# 112                           Type of research project
# 113                           Type of research project
# 114                                                289
# 115                                                289
# 116                                                289
# 117                                                289
# 118                                                289
# 119                                                289
# 120                                                289
# 121  creating awareness on Maize Lethal Necrosis Di...
# 122      Surviellance on Maize Lethal Necrosis Disease
# 123                  Type of pest management practices
# 124                            Commodity and crop type
# 125                            Commodity and crop type
# 126                            Commodity and crop type
# 127                            Commodity and crop type
# 128                            Commodity and crop type
# 129                            Commodity and crop type
# 130                                               Type
# 131                                           Location
# 132                                               Type
# 133                                       subject area
# 134                                       subject area
# 135                      Pest and management practices
# 136                                               Type
# 137                                               Type
# 138                                               Type
# 139                                                289
# 140                                               1342
# 141                                                289
# 142                                                289
# 143                                                289
# 144                                                289
# 145                                                289
# 146                                                289
# 147                         Type of farmer per country
# 148                         Type of farmer per country
# 149                                                289
# 150                                                289
# 151                                                289
# 152                                                289
# 153                                                289
# 154                                                289
# 155                                                289
# 156                                                289
# 157                                                289
# 158                                                289
# 159                                                289
# 160                                                289
# 161                                                289
# 162                                            country
# 163                                      Type of Maize
# 164                                      Type of Maize
# 165                            Commodity and crop type
# 166                            Commodity and crop type
# 167                            Commodity and crop type
# 168                            Commodity and crop type
# 169                            Commodity and crop type
# 170                            Commodity and crop type
# 171                            Commodity and crop type
# 172                            Commodity and crop type
# 173                            Commodity and crop type
# 174                            Commodity and crop type
# 175                            Commodity and crop type
# 176                            Commodity and crop type
# 177                            Commodity and crop type
# 178                            Commodity and crop type
# 179                            Commodity and crop type
# 180                            Commodity and crop type
# 181                            Commodity and crop type
# 182                            Commodity and crop type
# 183                            Commodity and crop type
# 184                            Commodity and crop type
# 185                            Commodity and crop type
# 186                            Commodity and crop type
# 187                            Commodity and crop type
# 188                            Commodity and crop type
# 189                            Commodity and crop type
# 190                            Commodity and crop type
# 191                            Commodity and crop type
# 192                            Commodity and crop type
# 193                            Commodity and crop type
# 194                            Commodity and crop type
# 195                            Commodity and crop type
# 196                            Commodity and crop type
# 197                                            country
# 198                  Type of pest management practices
# 199                                                289
# 200                            Commodity and crop type
# 201                            Commodity and crop type
# 202                            Commodity and crop type
# 203                            Commodity and crop type
# 204                            Commodity and crop type
# 205                            Commodity and crop type
# 206                            Commodity and crop type
# 207                            Commodity and crop type
# 208                            Commodity and crop type
# 209                            Commodity and crop type
# 210                            Commodity and crop type
# 211                            Commodity and crop type
# 212                            Commodity and crop type
# 213                            Commodity and crop type
# 214                            Commodity and crop type
# 215                                                289
# 216                                                289
# 217                                                289
# 218                                                289
# 219                                       Type of fair
# 220                                       subject area
# 221                                                410
# 222                                                410
# 223                                        Farmer type
# 224                                        Farmer type
# 225                                               Type
#
#                                              commodity  CA-MW  CA-MZ  CA-ZA  \
# 0                                                    3      0      0      6
# 1                                     Male Lead Farmer      0      0   1089
# 2                                   Female Lead Farmer      0      0    765
# 3                                      Land Management      0      0     15
# 4                                      Weed Management      0      0      5
# 5                                     Water Management      0      0     10
# 6                                        Crop Rotation      0      0      5
# 7                                             Chemical      0      0      4
# 8                                             Cultural      0      0      4
# 9                                             Chemical      0      0      4
# 10                                            Physical      0      0      4
# 11                                            Cultural      0      0      5
# 12                     Moisture Conservation Practices      0      0     24
# 13                                          Production      0      0     12
# 14                                             On Farm      0     33      0
# 15                                          On Station      0      5      0
# 16                                             On Farm      0      0      0
# 17                                          On Station      0      0      0
# 18                                                Male      0     20      0
# 19                                              Female      0     43      0
# 20                                             Legumes      0      3      0
# 21                                                Male      0    238   2012
# 22                                              Female      0    112    929
# 23                                    Agriculture Show      0      0      9
# 24                                               Maize      0      0      0
# 25                                             Legumes      0      0      0
# 26                                                Male      0      0    157
# 27                                              Female      0      0    145
# 28                                    Agriculture Show      0      0    200
# 29                                                Male      0     21     30
# 30                                              Female      0      3     14
# 31                                 Agronomic Practices      0      0     44
# 32                                                Male      0     20    121
# 33                                              Female      0     43    190
# 34                                     Country Project      0      8      0
# 35                                     Country Project      0      0      0
# 36                                               Maize      0      0      0
# 37                                     Country Project      0      0      0
# 38   Biochar Technology  For Soil Improvement And I...      0      0     11
# 39   Biochar Kiln Development And Biochar Applicati...      0      0      5
# 40                                     Land Management      0      0      1
# 41                           Fertilizer Recommendation      0      0      1
# 42                                       Planting Time      0      0      1
# 43                                     Weed Management      0      0      2
# 44                                Nutrition Management      0      0      0
# 45                                    Water Management      0      0      0
# 46                                  Harvest Management      0      0      0
# 47                                       Crop Rotation      0      0      2
# 48                              Number Of Technologies      0      0      4
# 49                                               Maize      0      0      0
# 50                                                Rice      0      0      0
# 51                                             Legumes      0      0      0
# 52                                             Cassava      0      0      0
# 53                                               Maize      0      0      0
# 54                                                Rice      0    180      0
# 55                                             Legumes      0      0      0
# 56                                             Cassava      0      0      0
# 57                                               Maize    254      0      0
# 58                                                Rice      0      0      0
# 59                                             Legumes      0      0      0
# 169      0      0      0       0       0
# 170      0      0      0       0       0
# 171      0      0      0       0       0
# 172      0      0      0       0       0
# 173      0      0      0       0       0
# 174      0      0      0       0       0
# 175      0      0      0       0       0
# 176      0      0      0       0       0
# 177      0      0      0       0       0
# 178      0      0      0       0       0
# 179      0      0      0       0       0
# 180      0      0      0       0       0
# 181      0      0      0       0       0
# 182      0      0      0       0       0
# 183      0      0      0       0       0
# 184      0      0      0       0       0
# 185      0      0      0       0       0
# 186      0      0      0       0       0
# 187      0      0      0       0       0
# 188      0      0      0       0       0
# 189      0      0      0       0       0
# 190      0      0      0       0       0
# 191      0      0      0       0       0
# 192      0      0      0       0       0
# 193      0      0      0       0       0
# 194      0      0      0       0       0
# 195      0      0      0       0       0
# 196      0      0      0       0       0
# 197      0      0      0       0       0
# 198      0      0      0       0       0
# 199      0      0      0       0       0
# 200      0      0      0       0       0
# 201      0      0      0       0       0
# 202      0      0      0       0       0
# 203      0      0      0       0       0
# 204      0      0      0       0       0
# 205      0      0      0       0       0
# 206      0      0      0       0       0
# 207      0      0      0       0       0
# 208      0      0      0       0       0
# 209      0      0      0       0       0
# 210      0      0      0       0       0
# 211      0      0      0       0       0
# 212      0      0      0       0       0
# 213      0      0      0       0       0
# 214      0      0      0       0       0
# 215      0      0      0       0       0
# 216      0      0      0       0       0
# 217      0      0      0       0       0
# 218      0      0      0       0       0
# 219      0      0      0       0     102
# 220      0      0      0       0     311
# 221      0      0      0       0      10
# 222      0      0      0       0      20
# 223      0      0      0       0      15
# 224      0      0      0       0      15
# 225      0      0      0       0       5

# %% [markdown]
# ### Defining Attribute Values

# %%
array = pd.concat([disaggregations_merged,targets],sort=False)
array = array.sort_values(by=['result','indicator_id','dimension_id','id'])
array = array.merge(periods_short,how='inner',left_on='period',right_on='id',suffixes=('_data','_period')).sort_values(['id_data','indicator_id','dimension_name'])

# %%
array['variable'] = array.apply(lambda x: {
    'id':x['id_data'],
    'result':x['result'],
    'country':x['country'],
    'type':x['type'],
    'period':x['period'],
    'date':x['period_date'],
    'indicator_id':x['indicator_id'],
    'indicator_name':x['indicator'],
    'dimension':x['dimension_id'],
    'dimension_name':x['dimension_name'],
    'commodity':x['commodity'],
    'value': x['value'],
},axis=1)
array = array[pd.notnull(array['period_end'])]

# %%
array['cumulative'] = array['period_end'].apply(lambda x: True if x.split('-')[1] == '12' else False)
array = array[array['cumulative'] == True].drop(columns=['cumulative'])
array = array[array['period_date'] == FILTER_DATE].drop(columns=['period','period_start','period_end','is_yearly'])
if FILTER_DATE_TYPE == 'yearly':
    array['year'] = array['period_date'].apply(lambda x: x.split(' - ')[0].split('-')[0])
    array = array[array['year'] == FILTER_DATE].drop(columns=['year','period_date'])
else:
    array = ajax[ajax['period_date'] == FILTER_DATE].drop(columns=['period_date'])

# %%
array_group =  ['result','project_title','indicator_id','indicator','dimension_id','dimension_name','id_data','commodity','country','type']
array_sort = ['result','indicator_id','dimension_id','id_data']

# %%
def group_attribute(a):
    data = []
    for b in a:
        data.append(b)
    return(data)

# %%
array = array.groupby(array_group)['variable'].apply(group_attribute).reset_index()
#array = array.groupby(array_group).first().unstack('type').unstack('country').sort_values(array_sort)

# %%
array

# %%
array = array.groupby(level=[1,3,5,7],sort=False).first()
array = pd.DataFrame(array['variable'].to_records())
array = array.rename(columns={
    "('Cumulative Actual Values', 'Malawi')": "CA-MW-D",
    "('Cumulative Actual Values', 'Mozambique')": "CA-MZ-D",
    "('Cumulative Actual Values', 'Zambia')": "CA-ZA-D",
    "('Y4 RCoLs Targets', 'Malawi')":"TG-MW-D",
    "('Y4 RCoLs Targets', 'Mozambique')":"TG-MZ-D",
    "('Y4 RCoLs Targets', 'Zambia')":"TG-ZA-D"
})

# %%
array = array.drop(columns=['project_title','indicator','commodity','dimension_name'])
array = pd.merge(ajax, array, left_index=True, right_index=True)

# %%
array = array.replace({np.nan: None})

# %%
project = list(pd.DataFrame(results_framework).groupby('title').first().reset_index()['title'])

# %%
indicator_title = list(pd.DataFrame(indicators).groupby('title').first().reset_index()['title'])

# %%
indicator_var = pd.DataFrame(indicators).groupby('title').first().reset_index()[['title','id','description']]

# %%
indicator_var

# %% [markdown]
# ## Generate Results

# %% [markdown]
# ### Merge Result Period

# %%
resutls = pd.concat([disaggregations_merged,targets],sort=False)
resutls = resutls.sort_values(by=['indicator_id','dimension_name','id'])

# %%
resutls['commodity'] = '• ' + resutls['commodity']
resutls['indicator'] = '+ ' + resutls['indicator']
resutls['project_title'] = '### ' + resutls['project_title']

# %%
results = resutls.merge(periods_short, how='inner', left_on='period', right_on='id', suffixes=('_data','_period'))
remove_columns = [
    'id_data',
    'period_end',
    'period_start',
    'id_period',
    'indicator_id',
    'id_period',
    'period',
    'dimension_name'
]
results = results.drop(columns=remove_columns)

# %% [markdown]
# ## Filter Parameters

# %% [markdown]
# ### Filter Date

# %%
results = results[results['period_date'] == FILTER_DATE]

# %% [markdown]
# ### Filter Country

# %%
results = results[results['country'].isin(FILTER_COUNTRY)]

# %% [markdown]
# ### Set Grouping

# %%
group_table = ['project_title','indicator','commodity','country','type']

# %%
results = results.drop(columns=['period_date','is_yearly'])

# %%
original = resutls.groupby(['project_title',
                            'indicator',
                            'indicator_id',
                            'commodity',
                            'dimension_name',
                            'country',
                            'type']).first()

# %%
original = original.drop(columns=['id','period','result','dimension_id']).sort_values(by=[
    'project_title',
    'indicator_id',
    'dimension_name'])

# %%
results = results.groupby(group_table).first().unstack('type').unstack('country').fillna(0)

# %%
indicator_sum = results.sum(level=[0,1])
indicator_sum = indicator_sum.stack().stack().reset_index().rename(columns={0:'value'}).dropna()
indicator_sum['commodity'] = ''
results = results.stack().stack().reset_index()
results = results.append(indicator_sum, sort='False')
results = results.groupby(group_table).first().unstack('type').unstack('country').fillna(0)

# %%
results = results.astype(int)

# %%
project_title = results.sum(level=[0])
project_title = project_title.stack().stack().reset_index()
project_title['value'] = ''
project_title['indicator'] = ''
project_title['commodity'] = ''
results = results.stack().stack().reset_index()
results = results.append(project_title, sort='False')

# %%
results = results.drop(columns='result').groupby(group_table).first().unstack('type').unstack('country').fillna(0)

# %%
html_output = 'file_name.html'
results.to_html(html_output)

# %% [markdown]
# ## Beautify HTML

# %%
from bs4 import BeautifulSoup as bs

# %%
variable_name = 'PDO Level Results Indicators'

# %%
with open(html_output) as htm:
    html = htm.read()
    soup = bs(html)

# %%
soup.find('table')['border'] = 0
soup.find('table')['class'] = "table"

# %%
def remove_all_attrs_except(sp):
    whitelist = ['border','table']
    blacklist = ['project_title','indicator','commodity','value','country']
    header = ['Cumulative Actual Values','Y4 RCoLs Targets']
    country = ['Malawi','Zambia','Mozambique']
    for tag in sp.find_all(True):
        if tag.name == 'table':
            tag['id'] = 'rsrtable'
        if tag.name not in whitelist:
            tag.attrs = {}
        if tag.name == 'th':
            if '•' in tag.text:
                text = str(tag.text).replace('•','')
                tag.string.replace_with(bs(text))
                tag['style']='padding-left:50'
            if '+' in tag.text:
                text = str(tag.text).replace('+','')
                tag.string.replace_with(bs(text))
                tag['style']='padding-left:30'
            if '###' in tag.text:
                text = str(tag.text).replace('###','')
                tag.string.replace_with(bs(text))
                if HTML_TYPE == 'print':
                    tag['colspan'] = 7
                else:
                    tag.decompose()
        if tag.text == '0':
            tag.string.replace_with('-')
            tag['class'] = 'text-right'
        if tag.text == '':
            tag.decompose()
        if tag.text in blacklist:
            tag.decompose()
        if tag.text == 'type':
            tag.string.replace_with(bs(variable_name))
            tag['rowspan'] = 2
        if tag.text in header:
            tag['colspan'] = 3
            tag['class'] = 'text-center'
        if tag.text in country:
            tag['class'] = 'text-center'
        if tag.text == "actual_value":
            tag.insert_before(soup.new_tag("th"))
        try:
            float(tag.text)
            tag['class'] = 'text-right'
        except:
            pass
    return sp

# %%
soup = remove_all_attrs_except(soup)

# %%
new_head = soup.new_tag("head")
soup.html.append(new_head)

css = soup.new_tag("link", 
                   rel="stylesheet", 
                   href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css", 
                   integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm",
                   crossorigin="anonymous")
datatable_css = soup.new_tag("link", 
                   rel="stylesheet", 
                   href="https://cdn.datatables.net/v/bs4/jq-3.3.1/dt-1.10.18/b-1.5.6/b-flash-1.5.6/fh-3.1.4/r-2.2.2/rg-1.1.0/datatables.min.css" 
)
soup.head.append(css)
soup.head.append(datatable_css)

# %%
table = bs(str(soup.body.table))
soup.html.body.decompose()

# %%
for i, tr in enumerate(table.html.body.table.find_all('tr')):
    if tr.contents == ['\n']:
        tr.decompose()

# %%
new_body = soup.new_tag("body")
soup.html.append(new_body)
soup.body.append(table.html.body.table)

# %%
datatable_js = soup.new_tag("script", 
                   type="text/javascript", 
                   src="https://cdn.datatables.net/v/bs4/jq-3.3.1/dt-1.10.18/b-1.5.6/b-flash-1.5.6/fh-3.1.4/r-2.2.2/rg-1.1.0/datatables.min.js" 
)

# %%
custom_js = soup.new_tag("script", 
                   type="text/javascript", 
                   src="/table.js" 
)

# %%
soup.head.append(datatable_js)
soup.body.append(custom_js)

# %%
with open("file_name_edit.html", "w") as outf:
    outf.write(str(soup))
