# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#General-Functions-and-Env" data-toc-modified-id="General-Functions-and-Env-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>General Functions and Env</a></span></li><li><span><a href="#Tracking-Child-Projects" data-toc-modified-id="Tracking-Child-Projects-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Tracking Child Projects</a></span></li><li><span><a href="#Getting-All-Results-Framework" data-toc-modified-id="Getting-All-Results-Framework-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Getting All Results Framework</a></span></li><li><span><a href="#Parent-Only" data-toc-modified-id="Parent-Only-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Parent Only</a></span></li></ul></div>

# %%
import json
import requests
import pandas as pd
import logging
from datetime import datetime

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## General Functions and Env

# %%
URL = 'https://rsr.akvo.org/rest/v1/'
API_KEY = '7d9a17639015b614a8026868dcc0f90fe38a4268'
PROJECT_ID = '7283'
FMT = '/?format=json&limit=1'
FMT100 = '/?format=json&limit=100'

# %%
headers = {
    'content-type': 'application/json',
    'Authorization': 'Token {}'.format(API_KEY)
}

# %%
def get_response(endpoint, param, value):
    uri = '{}{}{}&{}={}'.format(URL, endpoint, FMT100, param, value)
    print(get_time() + ' GETTING DATA FROM' + uri)
    data = requests.get(uri, headers=headers)
    data = data.json()
    return data

# %%
def get_time():
    now = datetime.now().time().strftime("%H:%M:%S")
    return now

# %%
get_response('related_project','related_project',PROJECT_ID)
# Out:
# 07:54:14 GETTING DATA FROMhttps://rsr.akvo.org/rest/v1/related_project/?format=json&limit=100&related_project=7283
# {'count': 5,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 3776,
#    'related_project': 7283,
#    'related_project_name': 'APPSA R&D Projects',
#    'related_project_show_link': '<a href="/en/project/7283/">APPSA R&D Projects</a>',
#    'relation_label': '1 - Parent',
#    'related_iati_id': '',
#    'relation': '1',
#    'project': 7950},
#   {'id': 3016,
#    'related_project': 7283,
#    'related_project_name': 'APPSA R&D Projects',
#    'related_project_show_link': '<a href="/en/project/7283/">APPSA R&D Projects</a>',
#    'relation_label': '1 - Parent',
#    'related_iati_id': '',
#    'relation': '1',
#    'project': 7308},
#   {'id': 3019,
#    'related_project': 7283,
#    'related_project_name': 'APPSA R&D Projects',
#    'related_project_show_link': '<a href="/en/project/7283/">APPSA R&D Projects</a>',
#    'relation_label': '1 - Parent',
#    'related_iati_id': '',
#    'relation': '1',
#    'project': 7306},
#   {'id': 3030,
#    'related_project': 7283,
#    'related_project_name': 'APPSA R&D Projects',
#    'related_project_show_link': '<a href="/en/project/7283/">APPSA R&D Projects</a>',
#    'relation_label': '1 - Parent',
#    'related_iati_id': '',
#    'relation': '1',
#    'project': 7298},
#   {'id': 3149,
#    'related_project': 7283,
#    'related_project_name': 'APPSA R&D Projects',
#    'related_project_show_link': '<a href="/en/project/7283/">APPSA R&D Projects</a>',
#    'relation_label': '1 - Parent',
#    'related_iati_id': '',
#    'relation': '1',
#    'project': 7282}]}

# %% [markdown]
# ## Tracking Child Projects

# %%
all_childs = []

# %%
def trace_childrens(project_id):
    related = get_response('related_project','related_project',project_id)        
    if len(related['results']) > 0:
        for result in related['results']:
            all_childs.append(result)
            trace_childrens(result['project'])

# %%
trace_childrens(PROJECT_ID)
# Out:
# 07:54:15 GETTING DATA FROMhttps://rsr.akvo.org/rest/v1/related_project/?format=json&limit=100&related_project=
# 0     80670  [{'id': 287017, 'data': [], 'parent_period': 9...
# 1     80671  [{'id': 287024, 'data': [], 'parent_period': 9...
# 2     80672  [{'id': 287031, 'data': [], 'parent_period': 9...
# 3     80673  [{'id': 287038, 'data': [], 'parent_period': 9...
# 4     80674  [{'id': 287052, 'data': [], 'parent_period': 2...
# ...     ...                                                ...
# 3373  79587  [{'id': 285136, 'data': [], 'parent_period': 2...
# 3374  79589  [{'id': 285157, 'data': [], 'parent_period': 2...
# 3375  79590  [{'id': 285171, 'data': [], 'parent_period': 2...
# 3376  79591  [{'id': 285178, 'data': [], 'parent_period': 2...
# 3377  79592  [{'id': 285192, 'data': [], 'parent_period': 2...
#
#       parent_indicator  children_aggregate_percentage  \
# 0              47749.0                          False
# 1              47753.0                           True
# 2              47750.0                          False
# 3              47751.0                          False
# 4              79616.0                          False
# ...                ...                            ...
# 3373           77547.0                          False
# 3374           77549.0                          False
# 3375           77550.0                          False
# 3376           77551.0                          False
# 3377           77552.0                          False
#
#                                         dimension_names labels  \
# 0     [{'id': 540, 'values': [{'id': 1232, 'value': ...     []
# 1     [{'id': 536, 'values': [{'id': 1217, 'value': ...     []
# 2     [{'id': 540, 'values': [{'id': 1232, 'value': ...     []
# 3     [{'id': 541, 'values': [{'id': 1239, 'value': ...     []
# 4     [{'id': 1653, 'values': [{'id': 9892, 'value':...     []
# ...                                                 ...    ...
# 3373                                                 []     []
# 3374                                                 []     []
# 3375                                                 []     []
# 3376                                                 []     []
# 3377                                                 []     []
#
#                                                   title  type measure  \
# 0     PDO 1 Number of technologies that are being ma...     1       1
# 1     PDO 2 Proportion of Lead Farmers in targeted a...     1       2
# 2     PDO 3 Number of technologies generated or prom...     1       1
# 3     PDO 4 Number of direct project beneficiaries (...     1       1
# 4     5. Number of collaborative research and develo...     1       1
# ...                                                 ...   ...     ...
# 3373  Number of technologies released by a RCoL in t...     1       1
# 3374  Number of improved technologies (varieties/man...     1       1
# 3375  Proportion of participatory research projects ...     1       2
# 3376  Number of R&D consultative meetings with stake...     1       1
# 3377  Number of National Steering Committee meetings...     1       1
#
#      ascending                                        description  \
# 0         None  Technology refers to the tools, methods or mac...
# 1         None  Lead farmers represent a group of innovative a...
# 2         None  “Technology generated” - innovation developed....
# 3         None  Direct beneficiaries refers to the persons (e....
# 4         True
# ...        ...                                                ...
# 3373      None  Certified seed varieties, agronomic and postha...
# 3374      None  An innovation platform is a space for learning...
# 3375      None  Participatory research comprises a range of me...
# 3376      None  A consultative meeting is a forum where stakeh...
# 3377      None  A steering committee is a committee that decid...
#
#       baseline_year baseline_value baseline_comment  order  default_periods  \
# 0            2013.0              0                     NaN            False
# 1            2013.0              0                     NaN            False
# 2               NaN                                    NaN            False
# 3            2013.0              0                     NaN            False
# 4            2013.0              0                     0.0            False
# ...             ...            ...              ...    ...              ...
# 3373         2013.0              0                     NaN            False
# 3374         2013.0              0                     NaN            False
# 3375         2013.0              0                     NaN            False
# 3376         2013.0              0                     NaN            False
# 3377         2013.0              0                     NaN            False
#
#       export_to_iati  result
# 0               True   36985
# 1               True   36985
# 2               True   36985
# 3               True   36985
# 4               True   36986
# ...              ...     ...
# 3373            True   36591
# 3374            True   36592
# 3375            True   36592
# 3376            True   36592
# 3377            True   36592
#
# [3378 rows x 18 columns]

# %%
all_periods = pd.DataFrame(parent_indicators_period)

# %%
all_periods.to_csv('all_periods_'+PROJECT_ID+'.csv')

# %%
all_periods = all_periods.to_dict('records')

# %%
all_periods[all_periods['target_value'] != ''].shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8116fc9207ec> in <module>()
# ----> 1 all_periods[all_periods['target_value'] != ''].shape
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ## Parent Only

# %%
results_indicator = get_response('results_framework','project',PROJECT_ID)['results']

# %%
indicators = [x['indicators'] for x in results_indicator]

# %%
indicators_data = []
for a in indicators:
    for x in a:
        indicators_data.append(x)

# %%
period_data = []
for a in indicators_data:
    for x in a['periods']:
        period_data.append(x)

# %%
period_list = pd.DataFrame(period_data)

# %%
period_list_id = list(period_list['id'])

# %%
len(period_list_id)

# %%
results_indicator

# %%
get_response(,'id',period_list_id[0])

# %%
results_indicator_df = pd.DataFrame(results_indicator)

# %%
results_indicator_df['child_projects'][0]

# %%
def get_children_id(x):
    for k,v in x.items():
        return k

# %%
def get_children_title(x):
    for k,v in x.items():
        return v

# %%
results_indicator_df['child_id'] = results_indicator_df['child_projects'].apply(get_children_id)

# %%
results_indicator_df['child_title'] = results_indicator_df['child_projects'].apply(get_children_title)

# %%
results_indicator = results_indicator_df.to_dict('records')

# %%
pd.DataFrame(results_indicator)

# %%
indicator_periods = []

# %%
for result in results_indicator:
    for indicator in result['indicators']:
        parent_indicators.append(indicator)
        for period in indicator['periods']:
            period.update({'project_id':result['project']})
            period.update({'project_name':result['project_title']})
            period.update({'project_title':result['title']})
            period.update({'parent_project':result['parent_project']})
            period.update({'parent_result':result['parent_result']})
            period.update({'child_project_id':result['child_id']})
            period.update({'child_project_title':result['child_title']})
            indicator_periods.append(period)

# %%
indicator_periods = pd.DataFrame(indicator_periods)

# %%
indicator_periods[['period_end_year','period_end_month','period_end_date']] = indicator_periods['period_end'].str.split('-', expand=True)
indicator_periods[['period_start_year','period_start_month','period_start_date']] = indicator_periods['period_start'].str.split('-', expand=True)

# %%
period_start = indicator_periods.groupby('period_start_year').size().to_frame('size').reset_index()
period_end = indicator_periods.groupby('period_end_year').size().to_frame('size').reset_index()

# %%
period_start.to_dict('records')

# %%
period_end.to_dict('records')
