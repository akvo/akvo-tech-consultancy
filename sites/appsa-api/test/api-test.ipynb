# %% [markdown]
# ## Init Dependencies

# %%
import requests
import os
import pandas as pd
from datetime import datetime
import json

# %% [markdown]
# ### Workspace Setup

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %% [markdown]
# ## Set Static Variables

# %%
URL = 'http://rsr.akvo.org/rest/v1/'
PROJECT_ID = '7924'
RSR_TOKEN = os.environ['RSR_TOKEN']
FMT = '/?format=json&limit=1'
FMT100 = '/?format=json&limit=100'

# %% [markdown]
# ## Set Authentication

# %%
headers = {
    'content-type': 'application/json',
    'Authorization': RSR_TOKEN
}

# %% [markdown]
# ## Helper Functions

# %%
def get_response(endpoint, param, value):
    uri = '{}{}{}&{}={}'.format(URL, endpoint, FMT100, param, value)
    print(get_time() + ' Fetching - ' + uri)
    data = requests.get(uri, headers=headers)
    data = data.json()
    return data

# %%
def get_time():
    now = datetime.now().time().strftime("%H:%M:%S")
    return now

# %%
def get_sibling_id(x):
    for k,v in x.items():
        return k

# %%
def get_report_type(ps,pe):
    rt = {'is_yearly':False}
    psm = ps.split('-')[1]
    pem = pe.split('-')[1]
    if psm == '01' and pem == '12':
        rt = {'is_yearly':True}
    if psm == '01' and pem == '01':
        rt = {'is_yearly':True}
    return rt

# %%
def get_dimension_country(dv):
    dp = dv['value'].split(' - ')
    dv = {}
    if dp[0].lower() in ['zambia','malawi','mozambique']:
        dv.update({
            'commodity':'',
            'country':dp[0],
            'has_commodity':False,
            'has_country':True
        })
    else:
        dv.update({
            'commodity':dp[0],
            'country':'',
            'has_commodity':False,
            'has_country':True
        })
    if len(dp) == 2:
        dv.update({
            'commodity':dp[0],
            'country':dp[1],
            'has_commodity':True,
            'has_country':True
        })
    return dv

# %% [markdown]
# ## Find Related Project

# %%
related_project = get_response('related_project','related_project',PROJECT_ID)
# Out:
# 16:39:14 Fetching - http://rsr.akvo.org/rest/v1/related_project/?format=json&limit=100&related_project=7924

# %%
results_framework_list = list(pd.DataFrame(related_project['results'])['project'])

# %% [markdown]
# ### Trace All Children (Alternative)

# %%
all_results_framework = []
def trace_childrens(project_id):
    related = get_response('related_project','related_project',project_id)        
    if len(related['results']) > 0:
        for result in related['results']:
            all_results_framework.append(result)
            trace_childrens(result['project'])
    else:
        return all_results_framework

# %% [markdown]
# ### Concat Results Frameworks (Alternative)

# %%
def trace_onechildren():
    results_framework = []
    for i, rf in enumerate(results_framework_list):
        result_framework = get_response('results_framework','project',rf)['results']
        if i == 0:
            results_framework = result_framework
        else:
            for res in result_framework:
                results_framework.append(res)
    return results_framework

# %% [markdown]
# ### Only Parents

# %%
results_framework = []
def no_trace():
    results_framework = get_response('results_framework','project',PROJECT_ID)['results']
    return results_framework

# %%
results_framework = no_trace()
# Out:
# 16:58:38 Fetching - http://rsr.akvo.org/rest/v1/results_framework/?format=json&limit=100&project=7924

# %% [markdown]
# ## Begin Transformations

# %%
results_framework = pd.DataFrame(results_framework)

# %% [markdown]
# ### Remove Project Without Childs

# %%
results_framework['child_projects'] = results_framework['child_projects'].apply(get_sibling_id)

# %%
#results_framework = results_framework[results_framework['child_projects'].notnull()]

# %%
results_framework = results_framework.to_dict('records')

# %%
indicators = []
periods = []
dimension_names = []
dimension_values = []
data_disaggregations = []
for result_framework in results_framework:
    rf_id = {'result':result_framework['id']}
    for indicator in result_framework['indicators']:
        indicator_id = indicator['id']
        for period in indicator['periods']:
            is_yearly = get_report_type(period['period_start'],period['period_end'])
            period.update(is_yearly)
            period.update(rf_id)
            period.update({'indicator':indicator_id})
            periods.append(period)
            for data in period['data']:
                if len(data) > 0:
                    period_id = data['period']
                    for disaggregations in data['disaggregations']:
                        disaggregations.update({'data_id': data['id']})
                        disaggregations.update({'period_id': data['period']})
                        data_disaggregations.append(disaggregations)
        del indicator['periods']
        for dimension_name in indicator['dimension_names']:
            for dimension_value in dimension_name['values']:
                dimension_value.update(rf_id)
                dimension_update = get_dimension_country(dimension_value)
                dimension_value.update(dimension_update)
                dimension_values.append(dimension_value)
            del dimension_name['values']
            dimension_name.update(rf_id)
            dimension_name.update({'indicator':indicator_id})
            dimension_names.append(dimension_name)
        del indicator['dimension_names']
        indicators.append(indicator)

# %% [markdown]
# ### Joining Dimension Values with Data Disaggregations

# %%
dimension_values = pd.DataFrame(dimension_values).groupby(['id']).first().reset_index()

# %%
dimension_values
# Out:
#       id                                              value  name  \
# 0   1385                  Number of improved seed varieties   576
# 1   1386                                              Maize   576
# 2   1387                                               Rice   576
# 3   1388                                            Legumes   576
# 4   1389                                            Cassava   576
# 5   1390  Number of improved agronomic, pest and disease...   576
# 6   1391  Number of improved post-harvest storage, labor...   576
# 7   1392                                        Lead farmer   577
# 8   1393                                    Follower farmer   577
# 9   1394                                      Female farmer   577
# 10  1395            Total improved varieties newly released   578
# 11  1396                                              Maize   578
# 12  1397                                               Rice   578
# 13  1398                                            Legumes   578
# 14  1399                                            Cassava   578
# 15  1400  improved agronomic, pests /disease, and water ...   578
# 16  1401  Improved postharvest storage, processing, labo...   578
# 17  1402                                               Male   579
# 18  1403                                             Female   579
# 19  7379                 management and leadership training   575
# 20  7385               training in administrative processes   575
# 21  7390      technical research and dissemination training   575
# 22  9898                              Technology generation  1656
# 23  9899                           Technology dissemination  1656
# 24  9924                                      Number of PhD  1661
# 25  9925                               Number of female PhD  1661
# 26  9926                                      Number of MSc  1661
# 27  9927                               Number of female MSc  1661
# 28  9928                                      Number of BSc  1661
# 29  9929                               Number of female BSc  1661
#
#     parent_dimension_value  result  \
# 0                     1232   37006
# 1                     1233   37006
# 2                     1234   37006
# 3                     1235   37006
# 4                     1236   37006
# 5                     1237   37006
# 6                     1238   37006
# 7                     1239   37006
# 8                     1240   37006
# 9                     1241   37006
# 10                    1242   37007
# 11                    1243   37007
# 12                    1244   37007
# 13                    1245   37007
# 14                    1246   37007
# 15                    1247   37007
# 16                    1248   37007
# 17                    1249   37006
# 18                    1250   37006
# 19                    7376   37008
# 20                    7382   37008
# 21                    7387   37008
# 22                    9892   37007
# 23                    9893   37007
# 24                    9906   37008
# 25                    9907   37008
# 26                    9908   37008
# 27                    9909   37008
# 28                    9910   37008
# 29                    9911   37008
#
#                                             commodity country  has_commodity  \
# 0                   Number of improved seed varieties                  False
# 1                                               Maize                  False
# 2                                                Rice                  False
# 3                                             Legumes                  False
# 4                                             Cassava                  False
# 5   Number of improved agronomic, pest and disease...                  False
# 6   Number of improved post-harvest storage, labor...                  False
# 7                                         Lead farmer                  False
# 8                                     Follower farmer                  False
# 9                                       Female farmer                  False
# 10            Total improved varieties newly released                  False
# 11                                              Maize                  False
# 12                                               Rice                  False
# 13                                            Legumes                  False
# 14                                            Cassava                  False
# 15  improved agronomic, pests /disease, and water ...                  False
# 16  Improved postharvest storage, processing, labo...                  False
# 17                                               Male                  False
# 18                                             Female                  False
# 19                 management and leadership training                  False
# 20               training in administrative processes                  False
# 21      technical research and dissemination training                  False
# 22                              Technology generation                  False
# 23                           Technology dissemination                  False
# 24                                      Number of PhD                  False
# 25                               Number of female PhD                  False
# 26                                      Number of MSc                  False
# 27                               Number of female MSc                  False
# 28                                      Number of BSc                  False
# 29                               Number of female BSc                  False
#
#     has_country
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21         True
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29         True

# %%
data_disaggregations = pd.DataFrame(data_disaggregations).merge(dimension_values, how='inner', left_on='dimension_value', right_on='id')

# %%
data_disaggregations = data_disaggregations.rename(columns={
    'value_x':'aggr_value',
    'id_y':'id',
    'id_x':'data_id'
})

# %%
data_disaggregations
# Out:
#     data_id  dimension_name                  created_at  \
# 0      3892             576  2019-08-22T11:39:54.708977
# 1      3899             576  2019-08-22T11:41:10.613311
# 2      3910             576  2019-08-22T11:44:54.807644
# 3      3893             576  2019-08-22T11:39:54.735719
# 4      3900             576  2019-08-22T11:41:10.639458
# 5      3911             576  2019-08-22T11:44:54.832976
# 6      3894             576  2019-08-22T11:39:54.761077
# 7      3901             576  2019-08-22T11:41:10.664501
# 8      3912             576  2019-08-22T11:44:54.855823
# 9      3895             576  2019-08-22T11:39:54.787192
# 10     3902             576  2019-08-22T11:41:10.688992
# 11     3913             576  2019-08-22T11:44:54.879631
# 12     3896             576  2019-08-22T11:39:54.813867
# 13     3903             576  2019-08-22T11:41:10.714304
# 14     3914             576  2019-08-22T11:44:54.904445
# 15     3897             576  2019-08-22T11:39:54.839701
# 16     3904             576  2019-08-22T11:41:10.738771
# 17     3915             576  2019-08-22T11:44:54.928111
# 18     3898             576  2019-08-22T11:39:54.865906
# 19     3905             576  2019-08-22T11:41:10.763540
# 20     3916             576  2019-08-22T11:44:54.951984
# 21     3906            1656  2019-08-22T11:42:32.446162
# 22     3908            1656  2019-08-22T11:43:10.956623
# 23     3907            1656  2019-08-22T11:42:32.473170
# 24     3909            1656  2019-08-22T11:43:10.984820
# 25     3917             575  2019-08-22T11:48:08.090323
# 26     3918             575  2019-08-22T11:48:08.114385
# 27     3919             575  2019-08-22T11:48:08.140666
# 28     3920             579  2019-08-22T11:48:08.163380
# 29     3921             579  2019-08-22T11:48:08.189701
# 30     3922            1661  2019-08-22T11:49:55.968489
# 31     3923            1661  2019-08-22T11:49:55.993767
# 32     3924            1661  2019-08-22T11:49:56.018510
# 33     3925            1661  2019-08-22T11:49:56.044911
# 34     3926            1661  2019-08-22T11:49:56.070342
# 35     3927            1661  2019-08-22T11:49:56.096491
#
#               last_modified_at aggr_value numerator denominator narrative  \
# 0   2019-08-22T11:39:54.709009      55.00      None        None
# 1   2019-08-22T11:41:10.613338      11.00      None        None
# 2   2019-08-22T11:44:54.807691       3.00      None        None
# 3   2019-08-22T11:39:54.735750      12.00      None        None
# 4   2019-08-22T11:41:10.639499       4.00      None        None
# 5   2019-08-22T11:44:54.833004       0.00      None        None
# 6   2019-08-22T11:39:54.761105       9.00      None        None
# 7   2019-08-22T11:41:10.664528       3.00      None        None
# 8   2019-08-22T11:44:54.855854       2.00      None        None
# 9   2019-08-22T11:39:54.787229      34.00      None        None
# 10  2019-08-22T11:41:10.689020       4.00      None        None
# 11  2019-08-22T11:44:54.879682       0.00      None        None
# 12  2019-08-22T11:39:54.813898       0.00      None        None
# 13  2019-08-22T11:41:10.714331       0.00      None        None
# 14  2019-08-22T11:44:54.904471       0.00      None        None
# 15  2019-08-22T11:39:54.839734      15.00      None        None
# 16  2019-08-22T11:41:10.738800       0.00      None        None
# 17  2019-08-22T11:44:54.928139       1.00      None        None
# 18  2019-08-22T11:39:54.865938       2.00      None        None
# 19  2019-08-22T11:41:10.763567       0.00      None        None
# 20  2019-08-22T11:44:54.952012       0.00      None        None
# 21  2019-08-22T11:42:32.446190      13.00      None        None
# 22  2019-08-22T11:43:10.956671      33.00     33.00      100.00
# 23  2019-08-22T11:42:32.473198       9.00      None        None
# 24  2019-08-22T11:43:10.984857      46.00     46.00      100.00
# 25  2019-08-22T11:48:08.090357      23.00      None        None
# 26  2019-08-22T11:48:08.114410     460.00      None        None
# 27  2019-08-22T11:48:08.140694    1916.00      None        None
# 28  2019-08-22T11:48:08.163407    1391.00      None        None
# 29  2019-08-22T11:48:08.189728    1008.00      None        None
# 30  2019-08-22T11:49:55.968517       0.00      None        None
# 31  2019-08-22T11:49:55.993798       0.00      None        None
# 32  2019-08-22T11:49:56.018537       2.00      None        None
# 33  2019-08-22T11:49:56.044938       0.00      None        None
# 34  2019-08-22T11:49:56.070371       2.00      None        None
# 35  2019-08-22T11:49:56.096527       0.00      None        None
#
#     incomplete_data  dimension_value  update  data_id  period_id    id  \
# 0              True             1385   23093    23093     288162  1385
# 1              True             1385   23094    23094     288176  1385
# 2              True             1385   23098    23098     288218  1385
# 3              True             1386   23093    23093     288162  1386
# 4              True             1386   23094    23094     288176  1386
# 5              True             1386   23098    23098     288218  1386
# 6              True             1387   23093    23093     288162  1387
# 7              True             1387   23094    23094     288176  1387
# 8              True             1387   23098    23098     288218  1387
# 9              True             1388   23093    23093     288162  1388
# 10             True             1388   23094    23094     288176  1388
# 11             True             1388   23098    23098     288218  1388
# 12             True             1389   23093    23093     288162  1389
# 13             True             1389   23094    23094     288176  1389
# 14             True             1389   23098    23098     288218  1389
# 15             True             1390   23093    23093     288162  1390
# 16             True             1390   23094    23094     288176  1390
# 17             True             1390   23098    23098     288218  1390
# 18             True             1391   23093    23093     288162  1391
# 19             True             1391   23094    23094     288176  1391
# 20             True             1391   23098    23098     288218  1391
# 21            False             9898   23095    23095     288197  9898
# 22             True             9898   23096    23096     288204  9898
# 23            False             9899   23095    23095     288197  9899
# 24             True             9899   23096    23096     288204  9899
# 25            False             7379   23101    23101     288239  7379
# 26            False             7385   23101    23101     288239  7385
# 27            False             7390   23101    23101     288239  7390
# 28            False             1402   23101    23101     288239  1402
# 29            False             1403   23101    23101     288239  1403
# 30            False             9924   23102    23102     288246  9924
# 31            False             9925   23102    23102     288246  9925
# 32            False             9926   23102    23102     288246  9926
# 33            False             9927   23102    23102     288246  9927
# 34            False             9928   23102    23102     288246  9928
# 35            False             9929   23102    23102     288246  9929
#
#                                               value_y  name  \
# 0                   Number of improved seed varieties   576
# 1                   Number of improved seed varieties   576
# 2                   Number of improved seed varieties   576
# 3                                               Maize   576
# 4                                               Maize   576
# 5                                               Maize   576
# 6                                                Rice   576
# 7                                                Rice   576
# 8                                                Rice   576
# 9                                             Legumes   576
# 10                                            Legumes   576
# 11                                            Legumes   576
# 12                                            Cassava   576
# 13                                            Cassava   576
# 14                                            Cassava   576
# 15  Number of improved agronomic, pest and disease...   576
# 16  Number of improved agronomic, pest and disease...   576
# 17  Number of improved agronomic, pest and disease...   576
# 18  Number of improved post-harvest storage, labor...   576
# 19  Number of improved post-harvest storage, labor...   576
# 20  Number of improved post-harvest storage, labor...   576
# 21                              Technology generation  1656
# 22                              Technology generation  1656
# 23                           Technology dissemination  1656
# 24                           Technology dissemination  1656
# 25                 management and leadership training   575
# 26               training in administrative processes   575
# 27      technical research and dissemination training   575
# 28                                               Male   579
# 29                                             Female   579
# 30                                      Number of PhD  1661
# 31                               Number of female PhD  1661
# 32                                      Number of MSc  1661
# 33                               Number of female MSc  1661
# 34                                      Number of BSc  1661
# 35                               Number of female BSc  1661
#
#     parent_dimension_value  result  \
# 0                     1232   37006
# 1                     1232   37006
# 2                     1232   37006
# 3                     1233   37006
# 4                     1233   37006
# 5                     1233   37006
# 6                     1234   37006
# 7                     1234   37006
# 8                     1234   37006
# 9                     1235   37006
# 10                    1235   37006
# 11                    1235   37006
# 12                    1236   37006
# 13                    1236   37006
# 14                    1236   37006
# 15                    1237   37006
# 16                    1237   37006
# 17                    1237   37006
# 18                    1238   37006
# 19                    1238   37006
# 20                    1238   37006
# 21                    9892   37007
# 22                    9892   37007
# 23                    9893   37007
# 24                    9893   37007
# 25                    7376   37008
# 26                    7382   37008
# 27                    7387   37008
# 28                    1249   37006
# 29                    1250   37006
# 30                    9906   37008
# 31                    9907   37008
# 32                    9908   37008
# 33                    9909   37008
# 34                    9910   37008
# 35                    9911   37008
#
#                                             commodity country  has_commodity  \
# 0                   Number of improved seed varieties                  False
# 1                   Number of improved seed varieties                  False
# 2                   Number of improved seed varieties                  False
# 3                                               Maize                  False
# 4                                               Maize                  False
# 5                                               Maize                  False
# 6                                                Rice                  False
# 7                                                Rice                  False
# 8                                                Rice                  False
# 9                                             Legumes                  False
# 10                                            Legumes                  False
# 11                                            Legumes                  False
# 12                                            Cassava                  False
# 13                                            Cassava                  False
# 14                                            Cassava                  False
# 15  Number of improved agronomic, pest and disease...                  False
# 16  Number of improved agronomic, pest and disease...                  False
# 17  Number of improved agronomic, pest and disease...                  False
# 18  Number of improved post-harvest storage, labor...                  False
# 19  Number of improved post-harvest storage, labor...                  False
# 20  Number of improved post-harvest storage, labor...                  False
# 21                              Technology generation                  False
# 22                              Technology generation                  False
# 23                           Technology dissemination                  False
# 24                           Technology dissemination                  False
# 25                 management and leadership training                  False
# 26               training in administrative processes                  False
# 27      technical research and dissemination training                  False
# 28                                               Male                  False
# 29                                             Female                  False
# 30                                      Number of PhD                  False
# 31                               Number of female PhD                  False
# 32                                      Number of MSc                  False
# 33                               Number of female MSc                  False
# 34                                      Number of BSc                  False
# 35                               Number of female BSc                  False
#
#     has_country
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21         True
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29         True
# 30         True
# 31         True
# 32         True
# 33         True
# 34         True
# 35         True

# %% [markdown]
# ## Test periods

# %%
test = pd.DataFrame(periods)

# %%
test['empty_disagregation'] = test['disaggregation_targets'].apply(lambda x: 1 if len(x) > 1 else 0)

# %%
test = test[test['empty_disagregation'] == 1]

# %%
test = test.reset_index()

# %%
test['disaggregation_targets'][1]
# Out:
# [{'period': 288162, 'id': 166, 'value': 0.0, 'dimension_value': 1389},
#  {'period': 288162, 'id': 167, 'value': 4.0, 'dimension_value': 1391},
#  {'period': 288162, 'id': 168, 'value': 23.0, 'dimension_value': 1388},
#  {'period': 288162, 'id': 169, 'value': 17.0, 'dimension_value': 1390},
#  {'period': 288162, 'id': 170, 'value': 55.0, 'dimension_value': 1385},
#  {'period': 288162, 'id': 171, 'value': 8.0, 'dimension_value': 1387},
#  {'period': 288162, 'id': 172, 'value': 24.0, 'dimension_value': 1386}]

# %% [markdown]
# ### About Period

# %% [markdown]
# - Has many Data
# - Belongs to Indicator
# - Data has Many Disaggregation
#
# _Data Format_ :

# %%
with open('example_data_rsr_indicator.json') as example:
    print(example)

# %% [markdown]
# ### About Disaggregation Target

# %% [markdown]
# - Specific Per-projects
# - Doesn't have any effect to children or parent projects
# - Only for verification of Actual Value
# - Belongs to Period
# - Has many dimension value

# %% [markdown]
# ## Update Result Framework

# %%
periods_df = pd.DataFrame(periods)
periods_df = periods_df.groupby(['is_yearly','result']).size().to_frame('size').reset_index().to_dict('records')

# %%
reports_annual = []
reports_semester = []
reports_both = []

# %%
for period_df in periods_df:
    if period_df['is_yearly']:
        reports_annual.append(period_df['result'])
    else:
        reports_semester.append(period_df['result'])
for y in reports_annual:
    for s in reports_semester:
        if y == s:
            reports_both.append(y)
for m in reports_both:
    reports_annual.remove(m)
    reports_semester.remove(m)

# %%
reports_both
# Out:
# [37006]

# %%
results_framework_new = []
for rf in results_framework:
    report_type = 'both'
    if rf['id'] in reports_annual:
        report_type = 'annual'
    if rf['id'] in reports_semester:
        report_type = 'semeseter'
    rf.update({'report_type':report_type})
    #try:
    #    child_project = get_sibling_id(rf['child_projects'])
    #    rf.update({'child_projects': child_project})
    #except:
    #    rf.update({'child_projects': None})
    try:
        parent_project = get_sibling_id(rf['parent_project'])
        rf.update({'parent_project': parent_project})
    except:
        rf.update({'parent_project': None})
    del rf['indicators']
    results_framework_new.append(rf)

# %% [markdown]
# ### API Response

# %%
response = {
    'results_framework':results_framework_new,
    'indicators':indicators,
    'periods':periods,
    'dimension_names':dimension_names,
    'dimension_values':dimension_values,
    'dimension_data':data_disaggregations
}

# %%
d_indicators = pd.DataFrame(response['indicators'])

# %%
d_periods = pd.DataFrame(response['periods'])

# %%
d_periods['period_time'] = d_periods['period_start'] + ' - ' + d_periods['period_end']

# %%
d_periods = d_periods.groupby(['id',
                               'is_yearly',
                               'indicator',
                               'percent_accomplishment',
                               'period_time',
                               'target_value',
                               'actual_value']).size().to_frame('period_total').reset_index()

# %%
d_periods = d_periods.merge(d_indicators,
                            how='inner', 
                            left_on='indicator',
                            right_on='id').groupby(['id_x',
                                                    'id_y',
                                                    'title',
                                                    'period_time',
                                                    'description',
                                                    'indicator',
                                                    'target_value',
                                                    'percent_accomplishment',
                                                    'actual_value']).size().to_frame('total').reset_index()

# %%
d_periods = d_periods.drop(columns='id_y').rename(columns={'id_x':'id'})

# %%
d_periods
# Out:
#        id                                              title  \
# 0  288162  PDO 1 Number of technologies that are being ma...
# 1  288176  PDO 3 Number of technologies generated or prom...
# 2  288197  Number of collaborative research and developme...
# 3  288204  Percentage of collaborative research and devel...
# 4  288218  Total number of improved technologies formally...
# 5  288225  Percentage of APPSA funded R&D dissemination p...
# 6  288239        Number of staff trained per research center
# 7  288246  Total # of funded scholarship holder that have...
# 8  288274  Overall implementation performance of change m...
#
#                period_time                                        description  \
# 0  2017-01-01 - 2017-12-31  Technology refers to the tools, methods or mac...
# 1  2017-01-01 - 2017-12-31  “Technology generated” - innovation developed....
# 2  2017-01-01 - 2017-12-31
# 3  2017-01-01 - 2017-12-31
# 4  2017-01-01 - 2017-12-31
# 5  2017-01-01 - 2017-12-31
# 6  2017-01-01 - 2017-12-31
# 7  2017-01-01 - 2017-12-31
# 8  2017-01-01 - 2017-12-31
#
#    indicator target_value  percent_accomplishment actual_value  total
# 0      80788           76                    94.7        72.00      1
# 1      80790           15                   120.0        18.00      1
# 2      80792           30                    73.3        22.00      1
# 3      80793           80                    60.0         48.0      1
# 4      80795           43                     7.0         3.00      1
# 5      80796           30                   173.3         52.0      1
# 6      80798           47                  5104.3      2399.00      1
# 7      80799           25                    16.0         4.00      1
# 8      80803            4                    25.0         1.00      1

# %% [markdown]
# ## Output Schema

# %%
d_names = pd.DataFrame(response['dimension_names'])
d_names = d_names.rename(columns={'name':'disaggregation_type'})

# %%
d_results = pd.DataFrame(response['results_framework'])

# %%
d_names = d_names.merge(d_periods, how='inner', left_on='indicator', right_on='indicator')

# %%
d_names
# Out:
#    id_x       disaggregation_type  project  parent_dimension_name  result  \
# 0   576        Type of technology     7924                    540   37006
# 1   576        Type of technology     7924                    540   37006
# 2  1656  Type of research project     7924                   1653   37007
# 3  1656  Type of research project     7924                   1653   37007
# 4   576        Type of technology     7924                    540   37007
# 5   575          Type of training     7924                    539   37008
# 6   579               Gender RCoL     7924                    543   37008
# 7  1661       Type of scholarship     7924                   1658   37008
#
#    indicator    id_y                                              title  \
# 0      80788  288162  PDO 1 Number of technologies that are being ma...
# 1      80790  288176  PDO 3 Number of technologies generated or prom...
# 2      80792  288197  Number of collaborative research and developme...
# 3      80793  288204  Percentage of collaborative research and devel...
# 4      80795  288218  Total number of improved technologies formally...
# 5      80798  288239        Number of staff trained per research center
# 6      80798  288239        Number of staff trained per research center
# 7      80799  288246  Total # of funded scholarship holder that have...
#
#                period_time                                        description  \
# 0  2017-01-01 - 2017-12-31  Technology refers to the tools, methods or mac...
# 1  2017-01-01 - 2017-12-31  “Technology generated” - innovation developed....
# 2  2017-01-01 - 2017-12-31
# 3  2017-01-01 - 2017-12-31
# 4  2017-01-01 - 2017-12-31
# 5  2017-01-01 - 2017-12-31
# 6  2017-01-01 - 2017-12-31
# 7  2017-01-01 - 2017-12-31
#
#   target_value  percent_accomplishment actual_value  total
# 0           76                    94.7        72.00      1
# 1           15                   120.0        18.00      1
# 2           30                    73.3        22.00      1
# 3           80                    60.0         48.0      1
# 4           43                     7.0         3.00      1
# 5           47                  5104.3      2399.00      1
# 6           47                  5104.3      2399.00      1
# 7           25                    16.0         4.00      1

# %% [markdown]
# ### Childs Aggregation

# %%
d_data = pd.DataFrame(response['dimension_data']).drop(['result','value_y','has_commodity','has_country'], axis=1)

# %%
d_names = d_names[['id_y',
                   'indicator',
                   'title',
                   'description',
                   'disaggregation_type',
                   'period_time',
                   'target_value',
                   'actual_value',
                   'percent_accomplishment'
                  ]].rename(columns={'id_y':'period_id'})

# %%
d_data = d_names.merge(d_data, how='inner', left_on='period_id',right_on='period_id')

# %%
d_data = d_data[[
    'title',
    'description',
    'disaggregation_type',
    'period_time',
    'target_value',
    'actual_value',
    'percent_accomplishment',
    'commodity',
    'country',
    'aggr_value'
]].rename(columns={'commodity':'dimension'}).sort_index()

# %%
d_data.groupby([
    'title',
    'description',
    'disaggregation_type',
    'period_time',
    'target_value',
    'actual_value',
    'percent_accomplishment',
    'dimension',
    'country',
    'aggr_value'
]).first()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Number of collaborative research and development projects under implementation, , Type of research project, 2017-01-01 - 2017-12-31, 30, 22.00, 73.3, Technology dissemination, , 9.00), (Number of collaborative research and development projects under implementation, , Type of research project, 2017-01-01 - 2017-12-31, 30, 22.00, 73.3, Technology generation, , 13.00), (Number of staff trained per research center, , Gender RCoL, 2017-01-01 - 2017-12-31, 47, 2399.00, 5104.3, Female, , 1008.00), (Number of staff trained per research center, , Gender RCoL, 2017-01-01 - 2017-12-31, 47, 2399.00, 5104.3, Male, , 1391.00), (Number of staff trained per research center, , Gender RCoL, 2017-01-01 - 2017-12-31, 47, 2399.00, 5104.3, management and leadership training, , 23.00), (Number of staff trained per research center, , Gender RCoL, 2017-01-01 - 2017-12-31, 47, 2399.00, 5104.3, technical research and dissemination training, , 1916.00), (Number of staff trained per research center, , Gender RCoL, 2017-01-01 - 2017-12-31, 47, 2399.00, 5104.3, training in administrative processes, , 460.00), (Number of staff trained per research center, , Type of training, 2017-01-01 - 2017-12-31, 47, 2399.00, 5104.3, Female, , 1008.00), (Number of staff trained per research center, , Type of training, 2017-01-01 - 2017-12-31, 47, 2399.00, 5104.3, Male, , 1391.00), (Number of staff trained per research center, , Type of training, 2017-01-01 - 2017-12-31, 47, 2399.00, 5104.3, management and leadership training, , 23.00), (Number of staff trained per research center, , Type of training, 2017-01-01 - 2017-12-31, 47, 2399.00, 5104.3, technical research and dissemination training, , 1916.00), (Number of staff trained per research center, , Type of training, 2017-01-01 - 2017-12-31, 47, 2399.00, 5104.3, training in administrative processes, , 460.00), (PDO 1 Number of technologies that are being made available to farmers and other end users, Technology refers to the tools, methods or machinery that are used to support agricultural enterprise. There are many categories of agricultural technologies within the production to marketing value chain, and these include mechanical, biological, chemical, and agronomic innovations.  For APPSA new varieties denote those released in the past 5 years since the commencement of the program, i.e. from 2008 onwards.
#
# Availability will be measured by whether seed or agronomic and postharvest practices are being produced and distributed, or a technology has been or is being promoted by the public or private sector. Technologies will be disaggregated by commodity and according to whether they address a cross cutting priority – such as climate change adaptation, gender, nutrition.
# “Farmer”: an individual involved in crop and animal production for food, income or raw materials.
# “End User”: Consumers/companies that utilize crop and animal produce., Type of technology, 2017-01-01 - 2017-12-31, 76, 72.00, 94.7, Cassava, , 0.00), (PDO 1 Number of technologies that are being made available to farmers and other end users, Technology refers to the tools, methods or machinery that are used to support agricultural enterprise. There are many categories of agricultural technologies within the production to marketing value chain, and these include mechanical, biological, chemical, and agronomic innovations.  For APPSA new varieties denote those released in the past 5 years since the commencement of the program, i.e. from 2008 onwards.
#
# Availability will be measured by whether seed or agronomic and postharvest practices are being produced and distributed, or a technology has been or is being promoted by the public or private sector. Technologies will be disaggregated by commodity and according to whether they address a cross cutting priority – such as climate change adaptation, gender, nutrition.
# “Farmer”: an individual involved in crop and animal production for food, income or raw materials.
# “End User”: Consumers/companies that utilize crop and animal produce., Type of technology, 2017-01-01 - 2017-12-31, 76, 72.00, 94.7, Legumes, , 34.00), (PDO 1 Number of technologies that are being made available to farmers and other end users, Technology refers to the tools, methods or machinery that are used to support agricultural enterprise. There are many categories of agricultural technologies within the production to marketing value chain, and these include mechanical, biological, chemical, and agronomic innovations.  For APPSA new varieties denote those released in the past 5 years since the commencement of the program, i.e. from 2008 onwards.
#
# Availability will be measured by whether seed or agronomic and postharvest practices are being produced and distributed, or a technology has been or is being promoted by the public or private sector. Technologies will be disaggregated by commodity and according to whether they address a cross cutting priority – such as climate change adaptation, gender, nutrition.
# “Farmer”: an individual involved in crop and animal production for food, income or raw materials.
# “End User”: Consumers/companies that utilize crop and animal produce., Type of technology, 2017-01-01 - 2017-12-31, 76, 72.00, 94.7, Maize, , 12.00), (PDO 1 Number of technologies that are being made available to farmers and other end users, Technology refers to the tools, methods or machinery that are used to support agricultural enterprise. There are many categories of agricultural technologies within the production to marketing value chain, and these include mechanical, biological, chemical, and agronomic innovations.  For APPSA new varieties denote those released in the past 5 years since the commencement of the program, i.e. from 2008 onwards.
#
# Availability will be measured by whether seed or agronomic and postharvest practices are being produced and distributed, or a technology has been or is being promoted by the public or private sector. Technologies will be disaggregated by commodity and according to whether they address a cross cutting priority – such as climate change adaptation, gender, nutrition.
# “Farmer”: an individual involved in crop and animal production for food, income or raw materials.
# “End User”: Consumers/companies that utilize crop and animal produce., Type of technology, 2017-01-01 - 2017-12-31, 76, 72.00, 94.7, Number of improved agronomic, pest and disease, and water management  practices, , 15.00), (PDO 1 Number of technologies that are being made available to farmers and other end users, Technology refers to the tools, methods or machinery that are used to support agricultural enterprise. There are many categories of agricultural technologies within the production to marketing value chain, and these include mechanical, biological, chemical, and agronomic innovations.  For APPSA new varieties denote those released in the past 5 years since the commencement of the program, i.e. from 2008 onwards.
#
# Availability will be measured by whether seed or agronomic and postharvest practices are being produced and distributed, or a technology has been or is being promoted by the public or private sector. Technologies will be disaggregated by commodity and according to whether they address a cross cutting priority – such as climate change adaptation, gender, nutrition.
# “Farmer”: an individual involved in crop and animal production for food, income or raw materials.
# “End User”: Consumers/companies that utilize crop and animal produce., Type of technology, 2017-01-01 - 2017-12-31, 76, 72.00, 94.7, Number of improved post-harvest storage, labor-saving and processing technologies, , 2.00), (PDO 1 Number of technologies that are being made available to farmers and other end users, Technology refers to the tools, methods or machinery that are used to support agricultural enterprise. There are many categories of agricultural technologies within the production to marketing value chain, and these include mechanical, biological, chemical, and agronomic innovations.  For APPSA new varieties denote those released in the past 5 years since the commencement of the program, i.e. from 2008 onwards.
#
# Availability will be measured by whether seed or agronomic and postharvest practices are being produced and distributed, or a technology has been or is being promoted by the public or private sector. Technologies will be disaggregated by commodity and according to whether they address a cross cutting priority – such as climate change adaptation, gender, nutrition.
# “Farmer”: an individual involved in crop and animal production for food, income or raw materials.
# “End User”: Consumers/companies that utilize crop and animal produce., Type of technology, 2017-01-01 - 2017-12-31, 76, 72.00, 94.7, Number of improved seed varieties, , 55.00), (PDO 1 Number of technologies that are being made available to farmers and other end users, Technology refers to the tools, methods or machinery that are used to support agricultural enterprise. There are many categories of agricultural technologies within the production to marketing value chain, and these include mechanical, biological, chemical, and agronomic innovations.  For APPSA new varieties denote those released in the past 5 years since the commencement of the program, i.e. from 2008 onwards.
#
# Availability will be measured by whether seed or agronomic and postharvest practices are being produced and distributed, or a technology has been or is being promoted by the public or private sector. Technologies will be disaggregated by commodity and according to whether they address a cross cutting priority – such as climate change adaptation, gender, nutrition.
# “Farmer”: an individual involved in crop and animal production for food, income or raw materials.
# “End User”: Consumers/companies that utilize crop and animal produce., Type of technology, 2017-01-01 - 2017-12-31, 76, 72.00, 94.7, Rice, , 9.00), (PDO 3 Number of technologies generated or promoted by the Project in one country that are released in another country, “Technology generated” - innovation developed.
# “Technology promoted” - innovation made available.
# “Technology released in another country” - innovation available in at least two countries., Type of technology, 2017-01-01 - 2017-12-31, 15, 18.00, 120.0, Cassava, , 0.00), (PDO 3 Number of technologies generated or promoted by the Project in one country that are released in another country, “Technology generated” - innovation developed.
# “Technology promoted” - innovation made available.
# “Technology released in another country” - innovation available in at least two countries., Type of technology, 2017-01-01 - 2017-12-31, 15, 18.00, 120.0, Legumes, , 4.00), (PDO 3 Number of technologies generated or promoted by the Project in one country that are released in another country, “Technology generated” - innovation developed.
# “Technology promoted” - innovation made available.
# “Technology released in another country” - innovation available in at least two countries., Type of technology, 2017-01-01 - 2017-12-31, 15, 18.00, 120.0, Maize, , 4.00), (PDO 3 Number of technologies generated or promoted by the Project in one country that are released in another country, “Technology generated” - innovation developed.
# “Technology promoted” - innovation made available.
# “Technology released in another country” - innovation available in at least two countries., Type of technology, 2017-01-01 - 2017-12-31, 15, 18.00, 120.0, Number of improved agronomic, pest and disease, and water management  practices, , 0.00), (PDO 3 Number of technologies generated or promoted by the Project in one country that are released in another country, “Technology generated” - innovation developed.
# “Technology promoted” - innovation made available.
# “Technology released in another country” - innovation available in at least two countries., Type of technology, 2017-01-01 - 2017-12-31, 15, 18.00, 120.0, Number of improved post-harvest storage, labor-saving and processing technologies, , 0.00), (PDO 3 Number of technologies generated or promoted by the Project in one country that are released in another country, “Technology generated” - innovation developed.
# “Technology promoted” - innovation made available.
# “Technology released in another country” - innovation available in at least two countries., Type of technology, 2017-01-01 - 2017-12-31, 15, 18.00, 120.0, Number of improved seed varieties, , 11.00), (PDO 3 Number of technologies generated or promoted by the Project in one country that are released in another country, “Technology generated” - innovation developed.
# “Technology promoted” - innovation made available.
# “Technology released in another country” - innovation available in at least two countries., Type of technology, 2017-01-01 - 2017-12-31, 15, 18.00, 120.0, Rice, , 3.00), (Percentage of collaborative research and development projects completed, , Type of research project, 2017-01-01 - 2017-12-31, 80, 48.0, 60.0, Technology dissemination, , 46.00), (Percentage of collaborative research and development projects completed, , Type of research project, 2017-01-01 - 2017-12-31, 80, 48.0, 60.0, Technology generation, , 33.00), (Total # of funded scholarship holder that have successfully completed long term training, , Type of scholarship, 2017-01-01 - 2017-12-31, 25, 4.00, 16.0, Number of BSc, , 2.00), (Total # of funded scholarship holder that have successfully completed long term training, , Type of scholarship, 2017-01-01 - 2017-12-31, 25, 4.00, 16.0, Number of MSc, , 2.00), (Total # of funded scholarship holder that have successfully completed long term training, , Type of scholarship, 2017-01-01 - 2017-12-31, 25, 4.00, 16.0, Number of PhD, , 0.00), (Total # of funded scholarship holder that have successfully completed long term training, , Type of scholarship, 2017-01-01 - 2017-12-31, 25, 4.00, 16.0, Number of female BSc, , 0.00), (Total # of funded scholarship holder that have successfully completed long term training, , Type of scholarship, 2017-01-01 - 2017-12-31, 25, 4.00, 16.0, Number of female MSc, , 0.00), (Total # of funded scholarship holder that have successfully completed long term training, , Type of scholarship, 2017-01-01 - 2017-12-31, 25, 4.00, 16.0, Number of female PhD, , 0.00), (Total number of improved technologies formally recommended by the national research center and subsequently formally promoted by the advisory services, , Type of technology, 2017-01-01 - 2017-12-31, 43, 3.00, 7.0, Cassava, , 0.00), (Total number of improved technologies formally recommended by the national research center and subsequently formally promoted by the advisory services, , Type of technology, 2017-01-01 - 2017-12-31, 43, 3.00, 7.0, Legumes, , 0.00), (Total number of improved technologies formally recommended by the national research center and subsequently formally promoted by the advisory services, , Type of technology, 2017-01-01 - 2017-12-31, 43, 3.00, 7.0, Maize, , 0.00), (Total number of improved technologies formally recommended by the national research center and subsequently formally promoted by the advisory services, , Type of technology, 2017-01-01 - 2017-12-31, 43, 3.00, 7.0, Number of improved agronomic, pest and disease, and water management  practices, , 1.00), (Total number of improved technologies formally recommended by the national research center and subsequently formally promoted by the advisory services, , Type of technology, 2017-01-01 - 2017-12-31, 43, 3.00, 7.0, Number of improved post-harvest storage, labor-saving and processing technologies, , 0.00), (Total number of improved technologies formally recommended by the national research center and subsequently formally promoted by the advisory services, , Type of technology, 2017-01-01 - 2017-12-31, 43, 3.00, 7.0, Number of improved seed varieties, , 3.00), (Total number of improved technologies formally recommended by the national research center and subsequently formally promoted by the advisory services, , Type of technology, 2017-01-01 - 2017-12-31, 43, 3.00, 7.0, Rice, , 2.00)]

# %% [markdown]
# ### All APPSA

# %%
d_values = pd.DataFrame(response['dimension_values']).drop(['result','value','has_commodity','has_country'], axis=1)

# %%
d_values = d_values.merge(d_names, how='inner', left_on='name', right_on='id')
d_values = d_values.merge(d_results, how='inner', left_on='result', right_on='id')

# %%
d_values = d_values.rename(columns={
    'title_x':'indicator_title',
    'title_y': 'title'
})

# %%
d_values = d_values.groupby(['title','indicator_title','period_time','actual_value','disaggregation_type','commodity','country','report_type','child_projects']).size().to_frame('size').sort_index().reset_index()

# %%
#FINAL d_values.groupby(['title','child_projects','report_type','indicator_title','size','actual_value','disaggregation_type','country','commodity','period_time']).first()

# %%
d_values.groupby(['title','child_projects','report_type','indicator_title','size','actual_value','disaggregation_type','country','commodity','period_time']).first()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Test Reports

# %%
test_report = d_values[['title','indicator_title','actual_value','disaggregation_type','commodity','country','period_time']]

# %%
test_report = test_report.groupby(['title','indicator_title','actual_value','period_time','disaggregation_type','commodity','country']).first()

# %%
test_report

# %%
#test_report.to_excel('test_final_with_zuhdil_060919.xlsx')
