# %%
import pandas as pd
import requests as r
from collections import Counter
import json
import re
import collections

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 999

# %%
def removeRegex(stc):
    stc = stc.replace('(','')
    stc = stc.replace(')','')
    return stc

# %%
def nested_dict():
    return collections.defaultdict(nested_dict)

# %%
FORMS_URL = "http://unep.localhost/json/unep-forms-with-variables.json"
COUNTRY_QUESTION = "Country"
COUNTRY_FILTER = "Member State"
DATA_SOURCE = "data-production_2020-03-16.csv"

# %%
def generate_code(x,y,t):
    for i, a in enumerate(x):
        code = y +'#' + str(i)
        if t == COUNTRY_QUESTION:
            a.update({
                'code':a['v']
            })
        else:
            a.update({
                'code':code
            })
    return x

# %%
dataframe = pd.read_csv('./source/' + DATA_SOURCE)
forms = pd.DataFrame(r.get(FORMS_URL).json())
forms['code'] = forms['q'].apply(lambda x:x.split(' ')[0].replace('.','').upper())
forms['a'] = forms.apply(lambda x: generate_code(x['a'], x['code'], x['s']), axis=1)
col_names = forms[['q','code']].to_dict('records')
col_names = {q['q']:q['code'] for q in col_names}

# %%
questions = forms['code'].to_list()
dataframe = dataframe.rename(columns=col_names)

# %%
#DEBUG
#dataframe = dataframe.loc[0:1]

# %%
def collect(sentence, options):
    data = []
    if sentence == sentence:
        sentence = removeRegex(sentence)
        for option in options:
            option_value = removeRegex(option['v'])
            if re.findall(option_value, str(sentence)):
                data.append(option['code'])
    return data

# %%
country_qcode = forms[forms['s'] == COUNTRY_QUESTION].reset_index()
country_qcode = country_qcode['code'][0]

# %%
metadatas = ['Unique Response Number','StartDate','CompletionDate']
questionlist = []
dataset = []
for index, row in dataframe.iterrows():
    cdata = {}
    for mdata in metadatas:
        cdata.update({mdata: row[mdata]})
    for qdata in list(dataframe):
        for q in questions:
            if qdata == q:
                qst = forms[forms['code'] == q]
                qtype = qst['t'].values[0]
                qopt = qst['a'].values[0]
                if qtype == "OPTIONS":
                    cdata.update({q: collect(row[q], qopt)})
                    questionlist.append(q)
                else:
                    cdata.update({q: row[q]})
    dataset.append(cdata)

# %%
baked = pd.DataFrame(dataset)

# %%
#qobject = {}
#for question in questionlist:
#    if question != country_qcode:
#        dataopt = {}
#        options = forms[forms['code'] == question]['a'].values[0]
#        for option in options:
#            country_value = option['code']
#            dataopt.update({country_value:0})
#        qobject.update({question:dataopt})

# %%
#results = nested_dict()
countrylist = forms[forms['code'] == country_qcode]['a'].values[0]
#for country in countrylist:
#    results.update({country['v']:qobject})

# %%
results = nested_dict()

# %%
for data in baked.to_dict('records'):
    for country in data[country_qcode]:
        for question in questionlist:
            if question != country_qcode:
                for answer in data[question]:
                    try:
                        results[country][question][answer] += 1
                    except:
                        results[country][question][answer] = 0

# %%
with open('./results/transformed-' + DATA_SOURCE.replace('csv','json'), 'w') as outfile:
    json.dump(results, outfile)

# %%
## INPUT CONNECTION

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
import numpy as np
from app.models import Countries, Groups, Values, CountryGroups, CountryValues
from app.connection import engine_url, write_data

# %%
engine_url = engine_url()
engine = create_engine(engine_url)
session = sessionmaker(bind=engine)()

# %%
values = forms[['q','s','t']].rename(columns={'q':'description','s':'name','t':'type'})
values['code'] = values['description'].apply(lambda x:x.split(' ')[0].replace('.','').upper())
values = values[values['name'] != COUNTRY_QUESTION].reset_index()
for value in values.to_dict('records'):
    value['parent_id'] = None
    value['units'] = None
    input_data = Values(value)
    write_data(session, input_data, value, False)

# %%
saved_values = pd.read_sql_table('values', engine_url)

# %%
child_values = forms[forms['t'] == 'OPTIONS'].reset_index()
child_values['code'] = child_values['q'].apply(lambda x:x.split(' ')[0].replace('.','').upper())

# %%
saved_values = saved_values.merge(child_values, on='code', how='left')
option_values = saved_values[saved_values['type'] == 'OPTIONS']
option_values = option_values[['id','type','code','units','description','a','color']].to_dict('records')

# %%
for option_value in option_values:
    for index, child in enumerate(option_value['a']):
        child_value = {
            'parent_id': option_value['id'],
            'units': option_value['units'],
            'code': option_value['code'] + '#' + str(index),
            'description': child['v'] + ' - ' + option_value['description'],
            'type': 'OPTION',
            'name': child['s']
        }
        input_data = Values(child_value)
        write_data(session, input_data, child_value, False)

# %%
unep_countries = pd.read_csv('./source/country_shapefile.csv')
unep_countries = unep_countries.rename(columns={'Terr_Name':'name','STATUS':'status'})

# %%
countries = unep_countries[unep_countries['status'] == 'Member State'].rename(columns={'ISO3_CODE':'code'})
countries = countries[['code','name','status']].to_dict('records')
for country in countries:
    input_data = Countries(country)
    write_data(session, input_data, country, False)

# %%
data_groups = pd.read_csv('./source/list_of_regional_seas_country.csv')
data_groups = data_groups[['Group','Country']].rename(columns={'Country':'name','Group':'group'})

# %%
# DEBUG GROUPS
countries = unep_countries[unep_countries['status'] == 'Member State'].rename(columns={'ISO3_CODE':'code'})
country_groups = countries.merge(data_groups, on='name', how='left', indicator=True)
groups = country_groups[country_groups['_merge'] == 'both'].groupby('group').first().reset_index()['group'].to_frame('name')
groups['parent_id'] = None

# %%
import wikipedia

# %%
def wiki(search):
    description = None
    #try:
    #    description = wikipedia.summary(search, sentences=1)
    #except:
    #    pass
    return description

def groupcode(x):
    x = x.replace('/',' ').replace('(','').replace(')','').split(' ')
    code = ''
    if len(x) == 1:
        x = x[0][0:3]
    for y in x:
        code += y[0].upper()
    return code

# %%
groups['description'] = groups['name'].apply(lambda x:wiki(x))
groups['code'] = groups['name'].apply(lambda x: groupcode(x))

# %%
for group in groups.to_dict('records'):
    input_data = Groups(group)
    write_data(session, input_data, group, False)

# %%
error_country = pd.DataFrame(countrylist)
error_country = error_country[['v']]
error_country = error_country.rename(columns={'v':'name'})
error_country = error_country.merge(unep_countries, on='name', how='left', indicator=True)
error_country = error_country[error_country['ISO3_CODE'] != error_country['ISO3_CODE']]
error_country.to_csv('./results/error-combined_source-and-shapefile.csv')

# %%
saved_groups = pd.read_sql_table('groups', engine_url)
country_groups = country_groups.rename(columns={'name':'country','group':'name','id':'group_id'})
country_groups = country_groups[country_groups['_merge'] == 'both'][['name','country']]
saved_groups = saved_groups.merge(country_groups, on='name', how='left', indicator=True).rename({'id':'group_id'})

# %%
saved_groups
# Out:
#      id parent_id             name code description                   country  \
# 0     1      None          Abidjan  ABI        None                      Togo
# 1     1      None          Abidjan  ABI        None              South Africa
# 2     2      None        Antarctic  ANT        None                 Australia
# 3     2      None        Antarctic  ANT        None                  Bulgaria
# 4     2      None        Antarctic  ANT        None                    Greece
# ..   ..       ...              ...  ...         ...                       ...
# 128  18      None  Wider Caribbean   WC        None                    Panama
# 129  18      None  Wider Caribbean   WC        None                  Suriname
# 130  18      None  Wider Caribbean   WC        None       Trinidad and Tobago
# 131  18      None  Wider Caribbean   WC        None  United States of America
# 132  18      None  Wider Caribbean   WC        None                 Venezuela
#
#     _merge
# 0     both
# 1     both
# 2     both
# 3     both
# 4     both
# ..     ...
# 128   both
# 129   both
# 130   both
# 131   both
# 132   both
#
# [133 rows x 7 columns]

# %%
saved_countries = pd.read_sql_table('countries', engine_url).rename(columns={'name':'country','id':'country_id'})
saved_countries = saved_countries[['country','country_id']]

# %%
saved_countries
# Out:
#                   country  country_id
# 0             Afghanistan           1
# 1                  Angola           2
# 2                 Albania           3
# 3                 Andorra           4
# 4    United Arab Emirates           5
# ..                    ...         ...
# 188          South Africa         189
# 189                Zambia         190
# 190              Zimbabwe         191
# 191                 Sudan         192
# 192           South Sudan         193
#
# [193 rows x 2 columns]

# %%
country_groups = saved_groups.merge(saved_countries, on='country',how='left')
country_groups = country_groups.rename(columns={'id':'group_id'})
country_groups = country_groups[['group_id','country_id']].to_dict('records')

# %%
for country_group in country_groups:
    input_data = CountryGroups(country_group)
    write_data(session, input_data, country_group, False)

# %%
for res in results:
    country = session.query(Countries).filter(Countries.name == res).first()
    data = {}
    if country:
        for question in results[res]:
            for answer in results[res][question]:
                option = session.query(Values).filter(Values.code == answer).first()
                country_value = {
                    'country_id':country.id,
                    'value_id':option.id,
                    'value':results[res][question][answer],
                    'description': None
                }
                input_data = CountryValues(country_value)
                write_data(session, input_data, country_value, False)

# %%
results
# Out:
# defaultdict(<function __main__.nested_dict()>,
#             {'France': defaultdict(<function __main__.nested_dict()>,
#                          {'9': defaultdict(<function __main__.nested_dict()>,
#                                       {'9#1': 947, '9#2': 315}),
#                           '9B': defaultdict(<function __main__.nested_dict()>,
#                                       {'9B#0': 631,
#                                        '9B#1': 947,
#                                        '9B#2': 631,
#                                        '9B#3': 473}),
#                           '9BII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BII#0': 631,
#                                        '9BII#1': 631,
#                                        '9BII#2': 631,
#                                        '9BII#3': 631,
#                                        '9BII#4': 631,
#                                        '9BII#5': 157}),
#                           '9BIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BIII#1': 631,
#                                        '9BIII#4': 473,
#                                        '9BIII#3': 157,
#                                        '9BIII#2': 157,
#                                        '9BIII#5': 315}),
#                           '11': defaultdict(<function __main__.nested_dict()>,
#                                       {'11#2': 947, '11#1': 315, '11#3': 157}),
#                           '12': defaultdict(<function __main__.nested_dict()>,
#                                       {'12#2': 1421,
#                                        '12#0': 631,
#                                        '12#1': 473}),
#                           '12D': defaultdict(<function __main__.nested_dict()>,
#                                       {'12D#0': 1105,
#                                        '12D#1': 473,
#                                        '12D#2': 631}),
#                           '13': defaultdict(<function __main__.nested_dict()>,
#                                       {'13#1': 315,
#                                        '13#0': 1105,
#                                        '13#2': 157}),
#                           '13B': defaultdict(<function __main__.nested_dict()>,
#                                       {'13B#2': 157}),
#                           '14': defaultdict(<function __main__.nested_dict()>,
#                                       {'14#1': 631, '14#2': 157, '14#0': 631}),
#                           '15': defaultdict(<function __main__.nested_dict()>,
#                                       {'15#2': 473,
#                                        '15#0': 631,
#                                        '15#3': 157,
#                                        '15#1': 157}),
#                           '17': defaultdict(<function __main__.nested_dict()>,
#                                       {'17#8': 947,
#                                        '17#9': 789,
#                                        '17#10': 473,
#                                        '17#11': 631,
#                                        '17#13': 315,
#                                        '17#1': 473,
#                                        '17#2': 473,
#                                        '17#3': 631,
#                                        '17#4': 473,
#                                        '17#5': 789,
#                                        '17#6': 789,
#                                        '17#7': 473}),
#                           '18': defaultdict(<function __main__.nested_dict()>,
#                                       {'18#1': 631,
#                                        '18#2': 315,
#                                        '18#3': 473,
#                                        '18#4': 789,
#                                        '18#5': 789,
#                                        '18#6': 789,
#                                        '18#7': 789,
#                                        '18#8': 473,
#                                        '18#9': 157,
#                                        '18#10': 157}),
#                           '19': defaultdict(<function __main__.nested_dict()>,
#                                       {'19#0': 1105,
#                                        '19#1': 789,
#                                        '19#2': 947,
#                                        '19#4': 315}),
#                           '20': defaultdict(<function __main__.nested_dict()>,
#                                       {'20#0': 473,
#                                        '20#1': 473,
#                                        '20#2': 473,
#                                        '20#3': 315,
#                                        '20#4': 631,
#                                        '20#5': 473,
#                                        '20#6': 947,
#                                        '20#8': 157}),
#                           '21': defaultdict(<function __main__.nested_dict()>,
#                                       {'21#0': 1105,
#                                        '21#2': 473,
#                                        '21#4': 315}),
#                           '21B': defaultdict(<function __main__.nested_dict()>,
#                                       {'21B#12': 947,
#                                        '21B#0': 315,
#                                        '21B#1': 315,
#                                        '21B#2': 315,
#                                        '21B#3': 315,
#                                        '21B#4': 315,
#                                        '21B#5': 157,
#                                        '21B#6': 315,
#                                        '21B#7': 315,
#                                        '21B#8': 315,
#                                        '21B#11': 315,
#                                        '21B#9': 157,
#                                        '21B#10': 157}),
#                           '22': defaultdict(<function __main__.nested_dict()>,
#                                       {'22#16': 631,
#                                        '22#0': 631,
#                                        '22#1': 315,
#                                        '22#8': 473,
#                                        '22#9': 473,
#                                        '22#10': 473,
#                                        '22#11': 315,
#                                        '22#13': 473,
#                                        '22#14': 631,
#                                        '22#15': 631,
#                                        '22#12': 157,
#                                        '22#2': 157,
#                                        '22#3': 157,
#                                        '22#4': 157,
#                                        '22#5': 157,
#                                        '22#6': 157,
#                                        '22#7': 315,
#                                        '22#17': 157}),
#                           '27': defaultdict(<function __main__.nested_dict()>,
#                                       {'27#1': 947,
#                                        '27#3': 947,
#                                        '27#2': 789,
#                                        '27#4': 473}),
#                           '28': defaultdict(<function __main__.nested_dict()>,
#                                       {'28#2': 473, '28#3': 947}),
#                           '10': defaultdict(<function __main__.nested_dict()>,
#                                       {'10#0': 473, '10#1': 315, '10#2': 315}),
#                           '13A': defaultdict(<function __main__.nested_dict()>,
#                                       {'13A#1': 473, '13A#0': 631}),
#                           '21C': defaultdict(<function __main__.nested_dict()>,
#                                       {'21C#2': 473,
#                                        '21C#1': 157,
#                                        '21C#4': 157}),
#                           '9C': defaultdict(<function __main__.nested_dict()>,
#                                       {'9C#2': 157,
#                                        '9C#3': 315,
#                                        '9C#6': 157,
#                                        '9C#9': 315,
#                                        '9C#0': 157,
#                                        '9C#1': 157,
#                                        '9C#4': 157,
#                                        '9C#5': 157,
#                                        '9C#8': 157}),
#                           '12B': defaultdict(<function __main__.nested_dict()>,
#                                       {'12B#0': 315,
#                                        '12B#1': 473,
#                                        '12B#2': 473}),
#                           '12C': defaultdict(<function __main__.nested_dict()>,
#                                       {'12C#0': 315,
#                                        '12C#1': 315,
#                                        '12C#2': 315}),
#                           '9D': defaultdict(<function __main__.nested_dict()>,
#                                       {'9D#0': 157,
#                                        '9D#3': 157,
#                                        '9D#4': 157,
#                                        '9D#6': 157}),
#                           '9DVIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9DVIII#0': 157}),
#                           '9CII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9CII#0': 157,
#                                        '9CII#1': 157,
#                                        '9CII#2': 157,
#                                        '9CII#3': 157,
#                                        '9CII#4': 157,
#                                        '9CII#5': 157,
#                                        '9CII#6': 157,
#                                        '9CII#7': 157,
#                                        '9CII#8': 157})}),
#              'Germany': defaultdict(<function __main__.nested_dict()>,
#                          {'9': defaultdict(<function __main__.nested_dict()>,
#                                       {'9#1': 473, '9#0': 631, '9#2': 473}),
#                           '9B': defaultdict(<function __main__.nested_dict()>,
#                                       {'9B#0': 473,
#                                        '9B#1': 473,
#                                        '9B#2': 473,
#                                        '9B#3': 473}),
#                           '9BII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BII#0': 473,
#                                        '9BII#1': 473,
#                                        '9BII#2': 473,
#                                        '9BII#3': 473,
#                                        '9BII#4': 473,
#                                        '9BII#6': 157,
#                                        '9BII#5': 157}),
#                           '9BIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BIII#1': 473,
#                                        '9BIII#4': 315,
#                                        '9BIII#0': 157,
#                                        '9BIII#2': 315,
#                                        '9BIII#5': 315}),
#                           '11': defaultdict(<function __main__.nested_dict()>,
#                                       {'11#2': 947,
#                                        '11#1': 1263,
#                                        '11#0': 157}),
#                           '12': defaultdict(<function __main__.nested_dict()>,
#                                       {'12#2': 315,
#                                        '12#0': 1895,
#                                        '12#3': 157}),
#                           '12D': defaultdict(<function __main__.nested_dict()>,
#                                       {'12D#0': 315,
#                                        '12D#1': 157,
#                                        '12D#2': 157}),
#                           '13': defaultdict(<function __main__.nested_dict()>,
#                                       {'13#1': 1263,
#                                        '13#0': 1105,
#                                        '13#2': 1105}),
#                           '13B': defaultdict(<function __main__.nested_dict()>,
#                                       {'13B#2': 157}),
#                           '14': defaultdict(<function __main__.nested_dict()>,
#                                       {'14#1': 1579,
#                                        '14#0': 473,
#                                        '14#2': 315}),
#                           '15': defaultdict(<function __main__.nested_dict()>,
#                                       {'15#2': 2053, '15#0': 315}),
#                           '17': defaultdict(<function __main__.nested_dict()>,
#                                       {'17#8': 315,
#                                        '17#9': 315,
#                                        '17#10': 157,
#                                        '17#11': 315,
#                                        '17#15': 1895,
#                                        '17#6': 315,
#                                        '17#7': 315,
#                                        '17#1': 157,
#                                        '17#2': 157,
#                                        '17#3': 157,
#                                        '17#4': 157,
#                                        '17#5': 157}),
#                           '18': defaultdict(<function __main__.nested_dict()>,
#                                       {'18#1': 315,
#                                        '18#2': 947,
#                                        '18#3': 473,
#                                        '18#4': 1105,
#                                        '18#5': 1421,
#                                        '18#6': 1421,
#                                        '18#7': 1263,
#                                        '18#8': 315,
#                                        '18#9': 473,
#                                        '18#10': 157}),
#                           '19': defaultdict(<function __main__.nested_dict()>,
#                                       {'19#0': 1579,
#                                        '19#1': 1421,
#                                        '19#2': 1421,
#                                        '19#3': 473,
#                                        '19#4': 315}),
#                           '20': defaultdict(<function __main__.nested_dict()>,
#                                       {'20#0': 1895,
#                                        '20#1': 2053,
#                                        '20#2': 2211,
#                                        '20#3': 947,
#                                        '20#4': 157,
#                                        '20#5': 473,
#                                        '20#6': 315,
#                                        '20#8': 157}),
#                           '21': defaultdict(<function __main__.nested_dict()>,
#                                       {'21#0': 1737,
#                                        '21#4': 631,
#                                        '21#2': 157}),
#                           '21B': defaultdict(<function __main__.nested_dict()>,
#                                       {'21B#12': 315,
#                                        '21B#0': 1105,
#                                        '21B#1': 1105,
#                                        '21B#2': 1263,
#                                        '21B#3': 1263,
#                                        '21B#4': 1105,
#                                        '21B#5': 1105,
#                                        '21B#6': 1263,
#                                        '21B#7': 1105,
#                                        '21B#8': 1105,
#                                        '21B#9': 1105,
#                                        '21B#11': 1105,
#                                        '21B#10': 157}),
#                           '22': defaultdict(<function __main__.nested_dict()>,
#                                       {'22#16': 315,
#                                        '22#17': 789,
#                                        '22#8': 947,
#                                        '22#0': 631,
#                                        '22#3': 473,
#                                        '22#9': 473,
#                                        '22#2': 315,
#                                        '22#18': 157,
#                                        '22#1': 157,
#                                        '22#4': 157,
#                                        '22#5': 157,
#                                        '22#6': 157,
#                                        '22#7': 157,
#                                        '22#14': 157,
#                                        '22#15': 157}),
#                           '27': defaultdict(<function __main__.nested_dict()>,
#                                       {'27#1': 315,
#                                        '27#3': 315,
#                                        '27#6': 1737,
#                                        '27#2': 315,
#                                        '27#4': 315}),
#                           '28': defaultdict(<function __main__.nested_dict()>,
#                                       {'28#2': 315,
#                                        '28#3': 315,
#                                        '28#0': 1263,
#                                        '28#5': 473}),
#                           '9A': defaultdict(<function __main__.nested_dict()>,
#                                       {'9A#0': 157, '9A#1': 473}),
#                           '12B': defaultdict(<function __main__.nested_dict()>,
#                                       {'12B#0': 1895, '12B#1': 1737}),
#                           '13A': defaultdict(<function __main__.nested_dict()>,
#                                       {'13A#0': 789,
#                                        '13A#2': 157,
#                                        '13A#1': 157}),
#                           '21C': defaultdict(<function __main__.nested_dict()>,
#                                       {'21C#2': 631,
#                                        '21C#4': 157,
#                                        '21C#1': 157}),
#                           '9D': defaultdict(<function __main__.nested_dict()>,
#                                       {'9D#2': 157,
#                                        '9D#3': 473,
#                                        '9D#6': 315,
#                                        '9D#7': 315,
#                                        '9D#8': 315}),
#                           '9DVIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9DVIII#0': 789}),
#                           '9C': defaultdict(<function __main__.nested_dict()>,
#                                       {'9C#0': 315,
#                                        '9C#13': 157,
#                                        '9C#3': 157,
#                                        '9C#6': 157,
#                                        '9C#7': 157}),
#                           '9BIIIB': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BIIIB#0': 157,
#                                        '9BIIIB#1': 157,
#                                        '9BIIIB#2': 157}),
#                           '10': defaultdict(<function __main__.nested_dict()>,
#                                       {'10#2': 315, '10#0': 157})}),
#              'Indonesia': defaultdict(<function __main__.nested_dict()>,
#                          {'9': defaultdict(<function __main__.nested_dict()>,
#                                       {'9#1': 1421, '9#0': 631, '9#2': 157}),
#                           '9B': defaultdict(<function __main__.nested_dict()>,
#                                       {'9B#0': 789,
#                                        '9B#1': 1263,
#                                        '9B#2': 1105,
#                                        '9B#3': 1105,
#                                        '9B#4': 473}),
#                           '9BII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BII#0': 789,
#                                        '9BII#1': 631,
#                                        '9BII#2': 789,
#                                        '9BII#3': 789,
#                                        '9BII#4': 789,
#                                        '9BII#6': 315,
#                                        '9BII#7': 157}),
#                           '9BIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BIII#1': 1105,
#                                        '9BIII#4': 631,
#                                        '9BIII#3': 473,
#                                        '9BIII#0': 315,
#                                        '9BIII#2': 631,
#                                        '9BIII#5': 631}),
#                           '11': defaultdict(<function __main__.nested_dict()>,
#                                       {'11#2': 1421,
#                                        '11#1': 473,
#                                        '11#4': 157,
#                                        '11#3': 315}),
#                           '12': defaultdict(<function __main__.nested_dict()>,
#                                       {'12#2': 1895,
#                                        '12#0': 1421,
#                                        '12#1': 1105,
#                                        '12#3': 157}),
#                           '12D': defaultdict(<function __main__.nested_dict()>,
#                                       {'12D#0': 1895,
#                                        '12D#1': 947,
#                                        '12D#2': 947,
#                                        '12D#3': 157}),
#                           '13': defaultdict(<function __main__.nested_dict()>,
#                                       {'13#1': 473,
#                                        '13#0': 1895,
#                                        '13#2': 157}),
#                           '13B': defaultdict(<function __main__.nested_dict()>,
#                                       {'13B#2': 157, '13B#0': 157}),
#                           '14': defaultdict(<function __main__.nested_dict()>,
#                                       {'14#1': 631,
#                                        '14#0': 1579,
#                                        '14#2': 157}),
#                           '15': defaultdict(<function __main__.nested_dict()>,
#                                       {'15#2': 473,
#                                        '15#0': 947,
#                                        '15#5': 157,
#                                        '15#1': 631,
#                                        '15#3': 157}),
#                           '17': defaultdict(<function __main__.nested_dict()>,
#                                       {'17#8': 1421,
#                                        '17#9': 1105,
#                                        '17#10': 631,
#                                        '17#11': 631,
#                                        '17#13': 315,
#                                        '17#2': 157,
#                                        '17#3': 631,
#                                        '17#4': 315,
#                                        '17#5': 1105,
#                                        '17#6': 1421,
#                                        '17#7': 1421,
#                                        '17#1': 473,
#                                        '17#14': 157,
#                                        '17#12': 157}),
#                           '18': defaultdict(<function __main__.nested_dict()>,
#                                       {'18#1': 473,
#                                        '18#2': 631,
#                                        '18#3': 947,
#                                        '18#4': 1579,
#                                        '18#5': 1737,
#                                        '18#6': 1737,
#                                        '18#7': 1421,
#                                        '18#8': 947,
#                                        '18#10': 157}),
#                           '19': defaultdict(<function __main__.nested_dict()>,
#                                       {'19#0': 2211,
#                                        '19#1': 2053,
#                                        '19#2': 2053,
#                                        '19#4': 157}),
#                           '20': defaultdict(<function __main__.nested_dict()>,
#                                       {'20#0': 789,
#                                        '20#1': 947,
#                                        '20#2': 947,
#                                        '20#3': 947,
#                                        '20#4': 315,
#                                        '20#5': 631,
#                                        '20#6': 1579,
#                                        '20#7': 157,
#                                        '20#8': 157}),
#                           '21': defaultdict(<function __main__.nested_dict()>,
#                                       {'21#0': 2211,
#                                        '21#2': 1105,
#                                        '21#4': 157}),
#                           '21B': defaultdict(<function __main__.nested_dict()>,
#                                       {'21B#12': 1737,
#                                        '21B#0': 789,
#                                        '21B#1': 789,
#                                        '21B#2': 789,
#                                        '21B#3': 789,
#                                        '21B#4': 473,
#                                        '21B#5': 473,
#                                        '21B#6': 315,
#                                        '21B#7': 789,
#                                        '21B#8': 789,
#                                        '21B#9': 631,
#                                        '21B#10': 315,
#                                        '21B#11': 789}),
#                           '22': defaultdict(<function __main__.nested_dict()>,
#                                       {'22#16': 789,
#                                        '22#0': 947,
#                                        '22#1': 473,
#                                        '22#8': 631,
#                                        '22#9': 473,
#                                        '22#10': 947,
#                                        '22#11': 631,
#                                        '22#13': 789,
#                                        '22#14': 789,
#                                        '22#15': 631,
#                                        '22#6': 315,
#                                        '22#18': 157,
#                                        '22#2': 157,
#                                        '22#3': 157,
#                                        '22#4': 157,
#                                        '22#5': 157,
#                                        '22#7': 157,
#                                        '22#12': 157,
#                                        '22#17': 315}),
#                           '27': defaultdict(<function __main__.nested_dict()>,
#                                       {'27#1': 947,
#                                        '27#3': 631,
#                                        '27#2': 1421,
#                                        '27#4': 631,
#                                        '27#7': 157}),
#                           '28': defaultdict(<function __main__.nested_dict()>,
#                                       {'28#2': 947,
#                                        '28#3': 1105,
#                                        '28#5': 315}),
#                           '10': defaultdict(<function __main__.nested_dict()>,
#                                       {'10#0': 947,
#                                        '10#1': 1105,
#                                        '10#2': 947}),
#                           '13A': defaultdict(<function __main__.nested_dict()>,
#                                       {'13A#1': 315,
#                                        '13A#0': 1105,
#                                        '13A#2': 315}),
#                           '21C': defaultdict(<function __main__.nested_dict()>,
#                                       {'21C#2': 1105, '21C#4': 157}),
#                           '9D': defaultdict(<function __main__.nested_dict()>,
#                                       {'9D#9': 157}),
#                           '9DVIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9DVIII#0': 157}),
#                           '9A': defaultdict(<function __main__.nested_dict()>,
#                                       {'9A#0': 315,
#                                        '9A#1': 631,
#                                        '9A#2': 473,
#                                        '9A#4': 473,
#                                        '9A#5': 473,
#                                        '9A#6': 315,
#                                        '9A#7': 315,
#                                        '9A#8': 473,
#                                        '9A#9': 315}),
#                           '12B': defaultdict(<function __main__.nested_dict()>,
#                                       {'12B#1': 1263,
#                                        '12B#0': 473,
#                                        '12B#2': 473,
#                                        '12B#3': 157}),
#                           '12C': defaultdict(<function __main__.nested_dict()>,
#                                       {'12C#0': 631,
#                                        '12C#1': 631,
#                                        '12C#2': 1105,
#                                        '12C#3': 157}),
#                           '9BIIIB': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BIIIB#0': 157,
#                                        '9BIIIB#1': 157,
#                                        '9BIIIB#2': 157}),
#                           '9C': defaultdict(<function __main__.nested_dict()>,
#                                       {'9C#1': 157,
#                                        '9C#2': 157,
#                                        '9C#3': 157,
#                                        '9C#4': 157,
#                                        '9C#8': 157}),
#                           '9CII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9CII#0': 157,
#                                        '9CII#2': 157,
#                                        '9CII#4': 157,
#                                        '9CII#5': 157})}),
#              'Switzerland': defaultdict(<function __main__.nested_dict()>,
#                          {'9': defaultdict(<function __main__.nested_dict()>,
#                                       {'9#1': 473}),
#                           '9B': defaultdict(<function __main__.nested_dict()>,
#                                       {'9B#0': 473,
#                                        '9B#1': 473,
#                                        '9B#2': 473,
#                                        '9B#3': 473}),
#                           '9BII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BII#0': 473,
#                                        '9BII#1': 473,
#                                        '9BII#2': 473,
#                                        '9BII#3': 473,
#                                        '9BII#4': 473,
#                                        '9BII#5': 157}),
#                           '9BIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BIII#1': 315,
#                                        '9BIII#4': 315,
#                                        '9BIII#3': 157,
#                                        '9BIII#2': 157,
#                                        '9BIII#5': 157}),
#                           '11': defaultdict(<function __main__.nested_dict()>,
#                                       {'11#2': 473, '11#1': 157}),
#                           '12': defaultdict(<function __main__.nested_dict()>,
#                                       {'12#2': 631}),
#                           '12D': defaultdict(<function __main__.nested_dict()>,
#                                       {'12D#0': 631,
#                                        '12D#1': 157,
#                                        '12D#2': 157}),
#                           '13': defaultdict(<function __main__.nested_dict()>,
#                                       {'13#1': 157, '13#0': 473}),
#                           '13B': defaultdict(<function __main__.nested_dict()>,
#                                       {'13B#2': 157}),
#                           '14': defaultdict(<function __main__.nested_dict()>,
#                                       {'14#1': 631}),
#                           '15': defaultdict(<function __main__.nested_dict()>,
#                                       {'15#2': 157, '15#0': 473}),
#                           '17': defaultdict(<function __main__.nested_dict()>,
#                                       {'17#8': 473,
#                                        '17#9': 473,
#                                        '17#10': 315,
#                                        '17#11': 473,
#                                        '17#13': 157,
#                                        '17#1': 157,
#                                        '17#2': 157,
#                                        '17#3': 157,
#                                        '17#4': 157,
#                                        '17#5': 157,
#                                        '17#6': 157,
#                                        '17#7': 157}),
#                           '18': defaultdict(<function __main__.nested_dict()>,
#                                       {'18#1': 473,
#                                        '18#2': 315,
#                                        '18#3': 473,
#                                        '18#4': 473,
#                                        '18#5': 473,
#                                        '18#6': 473,
#                                        '18#7': 473,
#                                        '18#8': 315,
#                                        '18#9': 157}),
#                           '19': defaultdict(<function __main__.nested_dict()>,
#                                       {'19#0': 631, '19#1': 631, '19#2': 631}),
#                           '20': defaultdict(<function __main__.nested_dict()>,
#                                       {'20#0': 157,
#                                        '20#1': 157,
#                                        '20#2': 157,
#                                        '20#3': 157,
#                                        '20#4': 157,
#                                        '20#5': 157,
#                                        '20#6': 631}),
#                           '21': defaultdict(<function __main__.nested_dict()>,
#                                       {'21#0': 631, '21#2': 315}),
#                           '21B': defaultdict(<function __main__.nested_dict()>,
#                                       {'21B#12': 631,
#                                        '21B#0': 157,
#                                        '21B#1': 157,
#                                        '21B#2': 157,
#                                        '21B#3': 157,
#                                        '21B#4': 157,
#                                        '21B#6': 157,
#                                        '21B#7': 157,
#                                        '21B#8': 157,
#                                        '21B#9': 157,
#                                        '21B#10': 157,
#                                        '21B#11': 157}),
#                           '22': defaultdict(<function __main__.nested_dict()>,
#                                       {'22#16': 315,
#                                        '22#0': 315,
#                                        '22#1': 315,
#                                        '22#8': 315,
#                                        '22#9': 315,
#                                        '22#10': 157,
#                                        '22#11': 157,
#                                        '22#13': 157,
#                                        '22#14': 315,
#                                        '22#15': 315,
#                                        '22#2': 157,
#                                        '22#3': 157,
#                                        '22#4': 157,
#                                        '22#5': 157,
#                                        '22#6': 157,
#                                        '22#7': 157}),
#                           '27': defaultdict(<function __main__.nested_dict()>,
#                                       {'27#1': 631,
#                                        '27#3': 631,
#                                        '27#2': 473,
#                                        '27#4': 315}),
#                           '28': defaultdict(<function __main__.nested_dict()>,
#                                       {'28#2': 157, '28#3': 473}),
#                           '10': defaultdict(<function __main__.nested_dict()>,
#                                       {'10#0': 315, '10#1': 157, '10#2': 157}),
#                           '13A': defaultdict(<function __main__.nested_dict()>,
#                                       {'13A#1': 473}),
#                           '21C': defaultdict(<function __main__.nested_dict()>,
#                                       {'21C#2': 315, '21C#1': 157}),
#                           '9D': defaultdict(<function __main__.nested_dict()>,
#                                       {'9D#0': 157,
#                                        '9D#3': 157,
#                                        '9D#4': 157,
#                                        '9D#6': 157}),
#                           '9DVIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9DVIII#0': 157})}),
#              'Other': defaultdict(<function __main__.nested_dict()>,
#                          {'9': defaultdict(<function __main__.nested_dict()>,
#                                       {'9#0': 631, '9#2': 631, '9#1': 157}),
#                           '9A': defaultdict(<function __main__.nested_dict()>,
#                                       {'9A#0': 315,
#                                        '9A#1': 315,
#                                        '9A#7': 157,
#                                        '9A#2': 157,
#                                        '9A#4': 157,
#                                        '9A#5': 157,
#                                        '9A#6': 157,
#                                        '9A#8': 157}),
#                           '10': defaultdict(<function __main__.nested_dict()>,
#                                       {'10#1': 1263,
#                                        '10#2': 157,
#                                        '10#0': 473}),
#                           '11': defaultdict(<function __main__.nested_dict()>,
#                                       {'11#0': 315,
#                                        '11#4': 631,
#                                        '11#2': 789,
#                                        '11#1': 631}),
#                           '12': defaultdict(<function __main__.nested_dict()>,
#                                       {'12#0': 1105,
#                                        '12#1': 789,
#                                        '12#2': 789,
#                                        '12#3': 789}),
#                           '12B': defaultdict(<function __main__.nested_dict()>,
#                                       {'12B#1': 631,
#                                        '12B#3': 157,
#                                        '12B#0': 473,
#                                        '12B#2': 315}),
#                           '12C': defaultdict(<function __main__.nested_dict()>,
#                                       {'12C#1': 315,
#                                        '12C#2': 631,
#                                        '12C#0': 315}),
#                           '13': defaultdict(<function __main__.nested_dict()>,
#                                       {'13#1': 789,
#                                        '13#2': 631,
#                                        '13#0': 1579}),
#                           '13B': defaultdict(<function __main__.nested_dict()>,
#                                       {'13B#4': 157}),
#                           '14': defaultdict(<function __main__.nested_dict()>,
#                                       {'14#2': 473,
#                                        '14#0': 1105,
#                                        '14#1': 631}),
#                           '15': defaultdict(<function __main__.nested_dict()>,
#                                       {'15#3': 157,
#                                        '15#2': 157,
#                                        '15#0': 1579,
#                                        '15#1': 315,
#                                        '15#4': 157}),
#                           '17': defaultdict(<function __main__.nested_dict()>,
#                                       {'17#13': 631,
#                                        '17#5': 473,
#                                        '17#8': 947,
#                                        '17#9': 315,
#                                        '17#10': 315,
#                                        '17#11': 473,
#                                        '17#1': 315,
#                                        '17#2': 315,
#                                        '17#3': 473,
#                                        '17#4': 315,
#                                        '17#6': 631,
#                                        '17#7': 631,
#                                        '17#14': 157,
#                                        '17#15': 157}),
#                           '18': defaultdict(<function __main__.nested_dict()>,
#                                       {'18#4': 789,
#                                        '18#7': 789,
#                                        '18#1': 157,
#                                        '18#2': 473,
#                                        '18#3': 315,
#                                        '18#5': 947,
#                                        '18#6': 789,
#                                        '18#8': 631,
#                                        '18#9': 473}),
#                           '19': defaultdict(<function __main__.nested_dict()>,
#                                       {'19#0': 1579,
#                                        '19#1': 1263,
#                                        '19#2': 1579,
#                                        '19#3': 631}),
#                           '20': defaultdict(<function __main__.nested_dict()>,
#                                       {'20#6': 1263,
#                                        '20#0': 947,
#                                        '20#1': 473,
#                                        '20#2': 789,
#                                        '20#3': 789,
#                                        '20#4': 473,
#                                        '20#5': 789,
#                                        '20#7': 157}),
#                           '21': defaultdict(<function __main__.nested_dict()>,
#                                       {'21#0': 2053,
#                                        '21#2': 789,
#                                        '21#3': 315}),
#                           '21B': defaultdict(<function __main__.nested_dict()>,
#                                       {'21B#1': 473,
#                                        '21B#12': 1579,
#                                        '21B#0': 315,
#                                        '21B#2': 315,
#                                        '21B#3': 315,
#                                        '21B#4': 157,
#                                        '21B#5': 315,
#                                        '21B#6': 315,
#                                        '21B#7': 315,
#                                        '21B#8': 315,
#                                        '21B#11': 315,
#                                        '21B#9': 157}),
#                           '22': defaultdict(<function __main__.nested_dict()>,
#                                       {'22#13': 473,
#                                        '22#0': 631,
#                                        '22#1': 473,
#                                        '22#2': 473,
#                                        '22#3': 315,
#                                        '22#6': 157,
#                                        '22#7': 315,
#                                        '22#8': 631,
#                                        '22#10': 315,
#                                        '22#11': 315,
#                                        '22#14': 631,
#                                        '22#9': 315,
#                                        '22#15': 631,
#                                        '22#18': 157,
#                                        '22#12': 157,
#                                        '22#16': 1105,
#                                        '22#17': 157}),
#                           '27': defaultdict(<function __main__.nested_dict()>,
#                                       {'27#6': 157,
#                                        '27#2': 1737,
#                                        '27#3': 947,
#                                        '27#1': 473,
#                                        '27#4': 157}),
#                           '28': defaultdict(<function __main__.nested_dict()>,
#                                       {'28#3': 1263,
#                                        '28#2': 473,
#                                        '28#0': 473,
#                                        '28#5': 157}),
#                           '9D': defaultdict(<function __main__.nested_dict()>,
#                                       {'9D#3': 473,
#                                        '9D#6': 473,
#                                        '9D#9': 473,
#                                        '9D#0': 157,
#                                        '9D#4': 157}),
#                           '12D': defaultdict(<function __main__.nested_dict()>,
#                                       {'12D#0': 789, '12D#1': 315}),
#                           '9DVIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9DVIII#0': 789, '9DVIII#2': 157}),
#                           '13A': defaultdict(<function __main__.nested_dict()>,
#                                       {'13A#1': 631, '13A#0': 947}),
#                           '21C': defaultdict(<function __main__.nested_dict()>,
#                                       {'21C#2': 1105}),
#                           '9C': defaultdict(<function __main__.nested_dict()>,
#                                       {'9C#0': 315,
#                                        '9C#3': 631,
#                                        '9C#4': 473,
#                                        '9C#2': 315,
#                                        '9C#6': 473,
#                                        '9C#9': 315,
#                                        '9C#1': 157,
#                                        '9C#8': 157}),
#                           '9B': defaultdict(<function __main__.nested_dict()>,
#                                       {'9B#3': 157}),
#                           '9CII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9CII#4': 157, '9CII#5': 157})}),
#              'All': defaultdict(<function __main__.nested_dict()>,
#                          {'9': defaultdict(<function __main__.nested_dict()>,
#                                       {'9#0': 789, '9#1': 157, '9#2': 315}),
#                           '9A': defaultdict(<function __main__.nested_dict()>,
#                                       {'9A#1': 315,
#                                        '9A#4': 473,
#                                        '9A#7': 157,
#                                        '9A#0': 157}),
#                           '10': defaultdict(<function __main__.nested_dict()>,
#                                       {'10#2': 157, '10#1': 315, '10#0': 473}),
# ...
#                                       {'9#1': 157}),
#                           '9B': defaultdict(<function __main__.nested_dict()>,
#                                       {'9B#0': 157, '9B#1': 157, '9B#2': 157}),
#                           '9BII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BII#0': 157,
#                                        '9BII#1': 157,
#                                        '9BII#2': 157,
#                                        '9BII#3': 157,
#                                        '9BII#4': 157}),
#                           '9BIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BIII#1': 157, '9BIII#4': 157}),
#                           '11': defaultdict(<function __main__.nested_dict()>,
#                                       {'11#2': 157}),
#                           '12': defaultdict(<function __main__.nested_dict()>,
#                                       {'12#0': 157, '12#1': 157, '12#2': 157}),
#                           '12B': defaultdict(<function __main__.nested_dict()>,
#                                       {'12B#2': 157}),
#                           '12C': defaultdict(<function __main__.nested_dict()>,
#                                       {'12C#2': 157}),
#                           '12D': defaultdict(<function __main__.nested_dict()>,
#                                       {'12D#2': 157}),
#                           '13': defaultdict(<function __main__.nested_dict()>,
#                                       {'13#0': 157}),
#                           '13A': defaultdict(<function __main__.nested_dict()>,
#                                       {'13A#0': 157}),
#                           '14': defaultdict(<function __main__.nested_dict()>,
#                                       {'14#0': 157}),
#                           '15': defaultdict(<function __main__.nested_dict()>,
#                                       {'15#2': 157}),
#                           '17': defaultdict(<function __main__.nested_dict()>,
#                                       {'17#2': 157,
#                                        '17#3': 157,
#                                        '17#5': 157,
#                                        '17#6': 157,
#                                        '17#7': 157,
#                                        '17#8': 157,
#                                        '17#9': 157}),
#                           '18': defaultdict(<function __main__.nested_dict()>,
#                                       {'18#4': 157,
#                                        '18#5': 157,
#                                        '18#6': 157,
#                                        '18#7': 157}),
#                           '19': defaultdict(<function __main__.nested_dict()>,
#                                       {'19#0': 157}),
#                           '20': defaultdict(<function __main__.nested_dict()>,
#                                       {'20#1': 157,
#                                        '20#2': 157,
#                                        '20#4': 157,
#                                        '20#5': 157}),
#                           '21': defaultdict(<function __main__.nested_dict()>,
#                                       {'21#0': 157}),
#                           '21B': defaultdict(<function __main__.nested_dict()>,
#                                       {'21B#12': 157}),
#                           '21C': defaultdict(<function __main__.nested_dict()>,
#                                       {'21C#2': 157}),
#                           '22': defaultdict(<function __main__.nested_dict()>,
#                                       {'22#0': 157,
#                                        '22#7': 157,
#                                        '22#8': 157,
#                                        '22#9': 157,
#                                        '22#10': 157,
#                                        '22#13': 157,
#                                        '22#14': 157,
#                                        '22#15': 157}),
#                           '27': defaultdict(<function __main__.nested_dict()>,
#                                       {'27#2': 157, '27#3': 157}),
#                           '28': defaultdict(<function __main__.nested_dict()>,
#                                       {'28#2': 157})}),
#              'United Kingdom of Great Britain and Northern Ireland': defaultdict(<function __main__.nested_dict()>,
#                          {'9': defaultdict(<function __main__.nested_dict()>,
#                                       {'9#1': 157}),
#                           '9B': defaultdict(<function __main__.nested_dict()>,
#                                       {'9B#0': 157, '9B#1': 157, '9B#2': 157}),
#                           '9BII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BII#0': 157,
#                                        '9BII#1': 157,
#                                        '9BII#2': 157,
#                                        '9BII#3': 157,
#                                        '9BII#4': 157}),
#                           '9BIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BIII#1': 157, '9BIII#4': 157}),
#                           '11': defaultdict(<function __main__.nested_dict()>,
#                                       {'11#2': 157}),
#                           '12': defaultdict(<function __main__.nested_dict()>,
#                                       {'12#0': 157, '12#1': 157, '12#2': 157}),
#                           '12B': defaultdict(<function __main__.nested_dict()>,
#                                       {'12B#2': 157}),
#                           '12C': defaultdict(<function __main__.nested_dict()>,
#                                       {'12C#2': 157}),
#                           '12D': defaultdict(<function __main__.nested_dict()>,
#                                       {'12D#2': 157}),
#                           '13': defaultdict(<function __main__.nested_dict()>,
#                                       {'13#0': 157}),
#                           '13A': defaultdict(<function __main__.nested_dict()>,
#                                       {'13A#0': 157}),
#                           '14': defaultdict(<function __main__.nested_dict()>,
#                                       {'14#0': 157}),
#                           '15': defaultdict(<function __main__.nested_dict()>,
#                                       {'15#2': 157}),
#                           '17': defaultdict(<function __main__.nested_dict()>,
#                                       {'17#2': 157,
#                                        '17#3': 157,
#                                        '17#5': 157,
#                                        '17#6': 157,
#                                        '17#7': 157,
#                                        '17#8': 157,
#                                        '17#9': 157}),
#                           '18': defaultdict(<function __main__.nested_dict()>,
#                                       {'18#4': 157,
#                                        '18#5': 157,
#                                        '18#6': 157,
#                                        '18#7': 157}),
#                           '19': defaultdict(<function __main__.nested_dict()>,
#                                       {'19#0': 157}),
#                           '20': defaultdict(<function __main__.nested_dict()>,
#                                       {'20#1': 157,
#                                        '20#2': 157,
#                                        '20#4': 157,
#                                        '20#5': 157}),
#                           '21': defaultdict(<function __main__.nested_dict()>,
#                                       {'21#0': 157}),
#                           '21B': defaultdict(<function __main__.nested_dict()>,
#                                       {'21B#12': 157}),
#                           '21C': defaultdict(<function __main__.nested_dict()>,
#                                       {'21C#2': 157}),
#                           '22': defaultdict(<function __main__.nested_dict()>,
#                                       {'22#0': 157,
#                                        '22#7': 157,
#                                        '22#8': 157,
#                                        '22#9': 157,
#                                        '22#10': 157,
#                                        '22#13': 157,
#                                        '22#14': 157,
#                                        '22#15': 157}),
#                           '27': defaultdict(<function __main__.nested_dict()>,
#                                       {'27#2': 157, '27#3': 157}),
#                           '28': defaultdict(<function __main__.nested_dict()>,
#                                       {'28#2': 157})}),
#              'Comoros': defaultdict(<function __main__.nested_dict()>,
#                          {'9': defaultdict(<function __main__.nested_dict()>,
#                                       {'9#1': 157}),
#                           '9B': defaultdict(<function __main__.nested_dict()>,
#                                       {'9B#1': 157}),
#                           '9BIII': defaultdict(<function __main__.nested_dict()>,
#                                       {'9BIII#1': 157}),
#                           '11': defaultdict(<function __main__.nested_dict()>,
#                                       {'11#3': 157}),
#                           '12': defaultdict(<function __main__.nested_dict()>,
#                                       {'12#0': 157, '12#2': 157}),
#                           '12B': defaultdict(<function __main__.nested_dict()>,
#                                       {'12B#0': 157,
#                                        '12B#1': 157,
#                                        '12B#2': 157}),
#                           '12D': defaultdict(<function __main__.nested_dict()>,
#                                       {'12D#0': 157,
#                                        '12D#1': 157,
#                                        '12D#2': 157}),
#                           '13': defaultdict(<function __main__.nested_dict()>,
#                                       {'13#0': 157}),
#                           '13A': defaultdict(<function __main__.nested_dict()>,
#                                       {'13A#0': 157}),
#                           '14': defaultdict(<function __main__.nested_dict()>,
#                                       {'14#0': 157}),
#                           '15': defaultdict(<function __main__.nested_dict()>,
#                                       {'15#1': 157}),
#                           '17': defaultdict(<function __main__.nested_dict()>,
#                                       {'17#1': 157,
#                                        '17#3': 157,
#                                        '17#4': 157,
#                                        '17#5': 157,
#                                        '17#6': 157,
#                                        '17#8': 157,
#                                        '17#9': 157,
#                                        '17#10': 157,
#                                        '17#11': 157}),
#                           '18': defaultdict(<function __main__.nested_dict()>,
#                                       {'18#10': 157}),
#                           '19': defaultdict(<function __main__.nested_dict()>,
#                                       {'19#4': 157}),
#                           '20': defaultdict(<function __main__.nested_dict()>,
#                                       {'20#6': 157}),
#                           '21': defaultdict(<function __main__.nested_dict()>,
#                                       {'21#4': 157}),
#                           '22': defaultdict(<function __main__.nested_dict()>,
#                                       {'22#16': 157}),
#                           '27': defaultdict(<function __main__.nested_dict()>,
#                                       {'27#1': 157}),
#                           '28': defaultdict(<function __main__.nested_dict()>,
#                                       {'28#2': 157})}),
#              'Cyprus': defaultdict(<function __main__.nested_dict()>,
#                          {'9': defaultdict(<function __main__.nested_dict()>,
#                                       {'9#2': 157}),
#                           '9C': defaultdict(<function __main__.nested_dict()>,
#                                       {'9C#0': 157,
#                                        '9C#3': 157,
#                                        '9C#4': 157,
#                                        '9C#6': 157}),
#                           '10': defaultdict(<function __main__.nested_dict()>,
#                                       {'10#0': 157, '10#1': 157}),
#                           '11': defaultdict(<function __main__.nested_dict()>,
#                                       {'11#2': 157}),
#                           '12': defaultdict(<function __main__.nested_dict()>,
#                                       {'12#0': 157, '12#1': 157}),
#                           '12B': defaultdict(<function __main__.nested_dict()>,
#                                       {'12B#1': 157, '12B#2': 157}),
#                           '12C': defaultdict(<function __main__.nested_dict()>,
#                                       {'12C#2': 157}),
#                           '13': defaultdict(<function __main__.nested_dict()>,
#                                       {'13#0': 157}),
#                           '13A': defaultdict(<function __main__.nested_dict()>,
#                                       {'13A#0': 157}),
#                           '14': defaultdict(<function __main__.nested_dict()>,
#                                       {'14#0': 157}),
#                           '15': defaultdict(<function __main__.nested_dict()>,
#                                       {'15#0': 157}),
#                           '17': defaultdict(<function __main__.nested_dict()>,
#                                       {'17#6': 157, '17#7': 157, '17#8': 157}),
#                           '18': defaultdict(<function __main__.nested_dict()>,
#                                       {'18#2': 157,
#                                        '18#3': 157,
#                                        '18#4': 157,
#                                        '18#5': 157,
#                                        '18#6': 157}),
#                           '19': defaultdict(<function __main__.nested_dict()>,
#                                       {'19#0': 157, '19#1': 157, '19#2': 157}),
#                           '20': defaultdict(<function __main__.nested_dict()>,
#                                       {'20#0': 157,
#                                        '20#2': 157,
#                                        '20#3': 157,
#                                        '20#5': 157}),
#                           '21': defaultdict(<function __main__.nested_dict()>,
#                                       {'21#0': 157}),
#                           '21B': defaultdict(<function __main__.nested_dict()>,
#                                       {'21B#0': 157,
#                                        '21B#1': 157,
#                                        '21B#2': 157,
#                                        '21B#3': 157,
#                                        '21B#5': 157,
#                                        '21B#6': 157,
#                                        '21B#7': 157,
#                                        '21B#8': 157,
#                                        '21B#9': 157,
#                                        '21B#11': 157}),
#                           '22': defaultdict(<function __main__.nested_dict()>,
#                                       {'22#8': 157,
#                                        '22#14': 157,
#                                        '22#15': 157}),
#                           '27': defaultdict(<function __main__.nested_dict()>,
#                                       {'27#2': 157, '27#4': 157}),
#                           '28': defaultdict(<function __main__.nested_dict()>,
#                                       {'28#2': 157})})})
