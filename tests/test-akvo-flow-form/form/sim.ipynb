# %%
import xmltodict
import json
import requests as r
from distutils import util

# %%
with open('data/356020954.xml') as fd:
    xmlData = xmltodict.parse(fd.read(), attr_prefix='')
    
webform = r.get('https://tech-consultancy.akvo.org/akvo-flow-web-api/seap/356020954/update')
jsonData = webform.json()

# %%
for attr in xmlData['survey']:
    print(attr,not isinstance(xmlData['survey'][attr],list))
# Out:
# name True
# defaultLanguageCode True
# version True
# app True
# surveyGroupId True
# surveyGroupName True
# surveyId True
# questionGroup False

# %%
jsonData
# Out:
# {'app': 'akvoflow-62',
#  'defaultLanguageCode': 'en',
#  'name': 'Survey Test',
#  'questionGroup': [{'heading': 'first group - common question types',
#    'question': [{'altText': {'language': 'id',
#       'text': 'teks bebas',
#       'type': 'translation'},
#      'help': {'altText': None,
#       'text': 'Curabitur ultrices vulputate odio, ac dapibus nibh ultrices sit amet. Fusce nec risus mauris. Curabitur vitae felis aliquam, suscipit odio sed, aliquam nibh. Ut et diam lacus.',
#       'type': 'tip'},
#      'id': '404840959',
#      'localeNameFlag': False,
#      'mandatory': True,
#      'order': '1',
#      'text': 'free text',
#      'type': 'free'},
#     {'altText': {'language': 'id',
#       'text': 'opsi (tunggal)',
#       'type': 'translation'},
#      'help': {'altText': None,
# ...

# %%
xmlData
# Out:
# OrderedDict([('survey',
#               OrderedDict([('name', 'Survey Test'),
#                            ('defaultLanguageCode', 'en'),
#                            ('version', '8.0'),
#                            ('app', 'akvoflow-62'),
#                            ('surveyGroupId', '380250954'),
#                            ('surveyGroupName', 'Test One'),
#                            ('surveyId', '356020954'),
#                            ('questionGroup',
#                             [OrderedDict([('repeatable', 'false'),
#                                           ('question',
#                                            [OrderedDict([('id', '404840959'),
#                                                          ('order', '1'),
#                                                          ('type', 'free'),
#                                                          ('mandatory', 'true'),
#                                                          ('localeNameFlag',
# ...

# %%
jsonData['name']
# Out:
# 'New form'

# %%
for element in xmlData['survey']:
    print(xmlData['survey'][element])
    index = element.replace('@','')
    if index in jsonData:
        print(index,'ok')
    else:
        print(index,'not ok')
# Out:
# New form
# name ok
# en
# defaultLanguageCode ok
# 4.0
# version ok
# akvoflow-62
# app ok
# 380250954
# surveyGroupId ok
# Test One
# surveyGroupName ok
# 356020954
# surveyId ok
# ...

# %%
xmlData['survey']
# Out:
# OrderedDict([('name', 'New form'),
#              ('defaultLanguageCode', 'en'),
#              ('version', '5.0'),
#              ('app', 'akvoflow-62'),
#              ('surveyGroupId', '380250954'),
#              ('surveyGroupName', 'Test One'),
#              ('surveyId', '356020954'),
#              ('questionGroup',
#               [OrderedDict([('repeatable', 'false'),
#                             ('question',
#                              [OrderedDict([('id', '404840959'),
#                                            ('order', '1'),
#                                            ('type', 'free'),
#                                            ('mandatory', 'true'),
#                                            ('localeNameFlag', 'false'),
#                                            ('help',
#                                             OrderedDict([('type', 'tip'),
#                                                          ('altText', None),
# ...

# %%
xmlData['survey']['questionGroup']
# Out:
# [OrderedDict([('repeatable', 'false'),
#               ('question',
#                [OrderedDict([('id', '404840959'),
#                              ('order', '1'),
#                              ('type', 'free'),
#                              ('mandatory', 'true'),
#                              ('localeNameFlag', 'false'),
#                              ('help',
#                               OrderedDict([('type', 'tip'),
#                                            ('altText', None),
#                                            ('text',
#                                             'Curabitur ultrices vulputate odio, ac dapibus nibh ultrices sit amet. Fusce nec risus mauris. Curabitur vitae felis aliquam, suscipit odio sed, aliquam nibh. Ut et diam lacus.')])),
#                              ('text', 'free text')]),
#                 OrderedDict([('id', '384550945'),
#                              ('order', '2'),
#                              ('type', 'option'),
# ...

# %%
for i in range(len(xmlData['survey']['questionGroup'])):
    print(bool(util.strtobool(xmlData['survey']['questionGroup'][i]['repeatable'])))
# Out:
# False
# False
# False

# %%
for i in range(len(xmlData['survey']['questionGroup'])):
    print(len(jsonData['questionGroup'][i]['question']))
# Out:
# 8
# 2
# 6

# %%
bool(util.strtobool(xmlData['survey']['questionGroup'][2]['repeatable']))
# Out:
# False

# %%
jsonData['questionGroup'][i]['repeatable']
# Out:
# False

# %%
bool(distutils.util.strtobool('false'))
# Out:
# False
